# %% [markdown]
# # Mie Scattering of a Lossless Dielectric Sphere
#
# A common reference calculation in computational electromagnetics for which an analytical solution is known is [Mie scattering](https://en.wikipedia.org/wiki/Mie_scattering) which involves computing the [scattering efficiency](http://www.thermopedia.com/content/956/) of a single, homogeneous sphere given an incident planewave. The scattered power of any object (absorbing or non) can be computed by surrounding it with a *closed* [DFT flux](https://meep.readthedocs.io/en/latest/Python_User_Interface/#flux-spectra) box (its size and orientation are irrelevant because of Poynting's theorem) and performing two simulations: (1) a normalization run involving an empty cell to save the incident fields from the source and (2) the scattering run with the object but first subtracting the incident fields in order to obtain just the scattered fields. This approach has already been described in [Transmittance Spectrum of a Waveguide Bend](https://meep.readthedocs.io/en/latest/Python_Tutorials/Basics#transmittance-spectrum-of-a-waveguide-bend).
#
# The scattering cross section is the scattered power in all directions divided by the incident intensity. The scattering efficiency, a dimensionless quantity, is the ratio of the scattering cross section to the cross sectional area of the sphere. In this demonstration, the sphere is a lossless dielectric with wavelength-independent refractive index of 2.0. This way, [subpixel smoothing](https://meep.readthedocs.io/en/latest/Subpixel_Smoothing) can improve accuracy at low resolutions which is important for reducing the size of this 3d simulation. The source is an $E_z$-polarized, planewave pulse (its `size` parameter fills the *entire* cell in 2d) spanning the broadband wavelength spectrum of 10% to 50% the circumference of the sphere. There is one subtlety: since the [planewave source extends into the PML](https://meep.readthedocs.io/en/latest/Perfectly_Matched_Layer/#planewave-sources-extending-into-pml) which surrounds the cell on all sides, `is_integrated=True` must be specified in the source object definition. A `k_point` of zero specifying periodic boundary conditions is necessary in order for the source to be infinitely extended. Also, given the [symmetry of the fields and the structure](https://meep.readthedocs.io/en/latest/Exploiting_Symmetry), two mirror symmery planes can be used to reduce the cell size by a factor of four. The simulation results are validated by comparing with the analytic theory obtained from the [PyMieScatt](https://pymiescatt.readthedocs.io/en/latest/) module (which you will have to install in order to run the script below).

# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
import json
import os

keyword = "Normal"
path = "SurfaceData/surfaceParams" + keyword + ".json"
def load_params(path = path):
    with open(path, "r") as f:
        return json.load(f)
params = load_params()

# Cell and resolution
pml_thickness = params["pml_thickness"]
monitor_size = params["monitor_size"]
half_x = params["halfWidth_x"]
half_y = params["halfWidth_y"]
half_z = params["halfWidth_z"]
cell_size = mp.Vector3(2*half_x + 2*pml_thickness,
                       2*half_y + 2*pml_thickness,
                       2*half_z + 2*pml_thickness)

omega = params["omega"]
betas = params["betas"]
# Material
epsilon1 = params["epsilon1"] 
substrate = mp.Medium(epsilon = epsilon1)
bumps = params["bumpData"]

## Must be at least 8 pixels per smallest wavelength, i.e. np.floor(8/wvl_min)
resolution = params["resolution"]

frq = params["omega"]/(2*np.pi)
wvl = 1 / frq

pml_layers = [mp.PML(thickness=pml_thickness)] 

def make_source(component):
    return [mp.Source(
        mp.GaussianSource(frequency=frq, fwidth=1, is_integrated=True),
        center=mp.Vector3(0, 0, half_z - 0.5),
        size=mp.Vector3(cell_size[0], cell_size[1], 0),
        component=component
    )]

def run_meep_simulation(sources):
    # Reference simulation (no bumps)
    sim = mp.Simulation(
        resolution=resolution,
        cell_size=cell_size,
        boundary_layers=pml_layers,
        sources=sources,
        k_point=mp.Vector3(),
    )

    box_x1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(x=-monitor_size/2), size=mp.Vector3(0, monitor_size, monitor_size)))
    box_x2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(x=+monitor_size/2), size=mp.Vector3(0, monitor_size, monitor_size)))
    box_y1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(y=-monitor_size/2), size=mp.Vector3(monitor_size, 0, monitor_size)))
    box_y2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(y=+monitor_size/2), size=mp.Vector3(monitor_size, 0, monitor_size)))
    box_z1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(z=-monitor_size/2), size=mp.Vector3(monitor_size, monitor_size, 0)))
    box_z2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(z=+monitor_size/2), size=mp.Vector3(monitor_size, monitor_size, 0)))

    sim.run(until_after_sources=60)

    box_x1_data = sim.get_flux_data(box_x1)
    box_x2_data = sim.get_flux_data(box_x2)
    box_y1_data = sim.get_flux_data(box_y1)
    box_y2_data = sim.get_flux_data(box_y2)
    box_z1_data = sim.get_flux_data(box_z1)
    box_z2_data = sim.get_flux_data(box_z2)

    box_x1_flux0 = mp.get_fluxes(box_x1)
    sim.reset_meep()

    # Structured simulation (with bumps)
    def material_function(p):
        z_surface = sum(
            b["height"] * np.exp(-((p.x - b["x0"])**2 + (p.y - b["y0"])**2) / (2 * b["sigma"]**2))
            for b in bumps
        )
        return substrate if p.z < z_surface else mp.air

    sim = mp.Simulation(
        resolution=resolution,
        cell_size=cell_size,
        boundary_layers=pml_layers,
        sources=sources,
        k_point=mp.Vector3(),
        default_material=material_function,
    )

    box_x1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(x=-monitor_size/2), size=mp.Vector3(0, monitor_size, monitor_size)))
    box_x2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(x=+monitor_size/2), size=mp.Vector3(0, monitor_size, monitor_size)))
    box_y1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(y=-monitor_size/2), size=mp.Vector3(monitor_size, 0, monitor_size)))
    box_y2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(y=+monitor_size/2), size=mp.Vector3(monitor_size, 0, monitor_size)))
    box_z1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(z=-monitor_size/2), size=mp.Vector3(monitor_size, monitor_size, 0)))
    box_z2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(z=+monitor_size/2), size=mp.Vector3(monitor_size, monitor_size, 0)))

    sim.load_minus_flux_data(box_x1, box_x1_data)
    sim.load_minus_flux_data(box_x2, box_x2_data)
    sim.load_minus_flux_data(box_y1, box_y1_data)
    sim.load_minus_flux_data(box_y2, box_y2_data)
    sim.load_minus_flux_data(box_z1, box_z1_data)
    sim.load_minus_flux_data(box_z2, box_z2_data)

    sim.run(until_after_sources=60) # maybe 20 is too little? 

    box_x1_flux = mp.get_fluxes(box_x1)
    box_x2_flux = mp.get_fluxes(box_x2)
    box_y1_flux = mp.get_fluxes(box_y1)
    box_y2_flux = mp.get_fluxes(box_y2)
    box_z1_flux = mp.get_fluxes(box_z1)
    box_z2_flux = mp.get_fluxes(box_z2)

    scatt_flux = (
        np.asarray(box_x1_flux)
        - np.asarray(box_x2_flux)
        + np.asarray(box_y1_flux)
        - np.asarray(box_y2_flux)
        + np.asarray(box_z1_flux)
        - np.asarray(box_z2_flux)
    )
    # Normalize by incident flux density (assuming monitor area = monitor_size²)
    intensity = np.asarray(box_x1_flux0) / (monitor_size)**2
    scatt_cross_section = np.divide(scatt_flux, intensity)
    # Meep flux convention: power leaving the box is positive
    scatt_eff = scatt_cross_section * -1 / (np.pi * 1**2) # r=1

    # Save individual components for later printing/plotting
    scatt_flux_components = {
        "X1": np.asarray(box_x1_flux)[0],
        "X2": np.asarray(box_x2_flux)[0],
        "Y1": np.asarray(box_y1_flux)[0],
        "Y2": np.asarray(box_y2_flux)[0],
        "Z1": np.asarray(box_z1_flux)[0],
        "Z2": np.asarray(box_z2_flux)[0],
        "scatt_total": scatt_flux[0],
    }


    return scatt_eff, scatt_flux_components

scatt_eff_list = []
flux_results = []

for beta in betas:
    print("beta = " + str(beta))
    cos2 = np.cos(beta)**2
    sin2 = np.sin(beta)**2

    sources_ex = make_source(mp.Ex)
    sources_ey = make_source(mp.Ey)

    Qx, flux_ex = run_meep_simulation(sources_ex)
    Qy, flux_ey = run_meep_simulation(sources_ey)

    Q_beta = cos2 * Qx + sin2 * Qy
    scatt_eff_list.append(Q_beta)

    # Combine flux components manually
    flux_combined = {
        "beta": np.degrees(beta),
        "X1": cos2 * flux_ex["X1"] + sin2 * flux_ey["X1"],
        "X2": cos2 * flux_ex["X2"] + sin2 * flux_ey["X2"],
        "Y1": cos2 * flux_ex["Y1"] + sin2 * flux_ey["Y1"],
        "Y2": cos2 * flux_ex["Y2"] + sin2 * flux_ey["Y2"],
        "Z1": cos2 * flux_ex["Z1"] + sin2 * flux_ey["Z1"],
        "Z2": cos2 * flux_ex["Z2"] + sin2 * flux_ey["Z2"],
        "scatt_total": cos2 * flux_ex["scatt_total"] + sin2 * flux_ey["scatt_total"]
    }

    flux_results.append(flux_combined)
# Out:
# beta = 0.0
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000806093 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.480322 s
# -----------
# Meep progress: 8.85/70.0 = 12.6% done in 4.0s, 27.7s to go
# on time step 177 (time=8.85), 0.0226232 s/step
# Meep progress: 21.950000000000003/70.0 = 31.4% done in 8.0s, 17.5s to go
# on time step 439 (time=21.95), 0.015312 s/step
# Meep progress: 35.45/70.0 = 50.6% done in 12.0s, 11.7s to go
# on time step 709 (time=35.45), 0.0148611 s/step
# Meep progress: 47.75/70.0 = 68.2% done in 16.0s, 7.5s to go
# on time step 955 (time=47.75), 0.0162649 s/step
# Meep progress: 60.1/70.0 = 85.9% done in 20.0s, 3.3s to go
# on time step 1202 (time=60.1), 0.0162392 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000475168 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 16.7454 s
# -----------
# Meep progress: 8.0/70.0 = 11.4% done in 4.0s, 31.1s to go
# on time step 160 (time=8), 0.0250654 s/step
# Meep progress: 20.200000000000003/70.0 = 28.9% done in 8.0s, 19.8s to go
# on time step 404 (time=20.2), 0.0164163 s/step
# Meep progress: 32.35/70.0 = 46.2% done in 12.0s, 14.0s to go
# on time step 647 (time=32.35), 0.0164781 s/step
# Meep progress: 44.1/70.0 = 63.0% done in 16.0s, 9.4s to go
# on time step 882 (time=44.1), 0.0170761 s/step
# Meep progress: 52.95/70.0 = 75.6% done in 20.0s, 6.5s to go
# on time step 1060 (time=53), 0.0225907 s/step
# Meep progress: 64.3/70.0 = 91.9% done in 24.0s, 2.1s to go
# on time step 1287 (time=64.35), 0.0176594 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000491858 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.518297 s
# -----------
# Meep progress: 7.800000000000001/70.0 = 11.1% done in 4.0s, 32.0s to go
# on time step 156 (time=7.8), 0.0257192 s/step
# Meep progress: 20.1/70.0 = 28.7% done in 8.0s, 19.9s to go
# on time step 402 (time=20.1), 0.0163119 s/step
# Meep progress: 32.300000000000004/70.0 = 46.1% done in 12.0s, 14.0s to go
# on time step 646 (time=32.3), 0.016423 s/step
# Meep progress: 44.5/70.0 = 63.6% done in 16.0s, 9.2s to go
# on time step 890 (time=44.5), 0.0164162 s/step
# Meep progress: 56.75/70.0 = 81.1% done in 20.0s, 4.7s to go
# on time step 1135 (time=56.75), 0.0163299 s/step
# Meep progress: 69.15/70.0 = 98.8% done in 24.0s, 0.3s to go
# on time step 1383 (time=69.15), 0.0161382 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000448942 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 17.9829 s
# -----------
# Meep progress: 8.15/70.0 = 11.6% done in 4.0s, 30.4s to go
# on time step 163 (time=8.15), 0.0245582 s/step
# Meep progress: 20.05/70.0 = 28.6% done in 8.0s, 20.0s to go
# on time step 401 (time=20.05), 0.0168401 s/step
# Meep progress: 30.900000000000002/70.0 = 44.1% done in 12.0s, 15.2s to go
# on time step 618 (time=30.9), 0.0184568 s/step
# Meep progress: 42.45/70.0 = 60.6% done in 16.0s, 10.4s to go
# on time step 849 (time=42.45), 0.0173197 s/step
# Meep progress: 54.550000000000004/70.0 = 77.9% done in 20.0s, 5.7s to go
# on time step 1091 (time=54.55), 0.0165588 s/step
# Meep progress: 66.4/70.0 = 94.9% done in 24.0s, 1.3s to go
# on time step 1328 (time=66.4), 0.0168905 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 0.2617993877991494
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000496149 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.513051 s
# -----------
# Meep progress: 8.4/70.0 = 12.0% done in 4.0s, 29.4s to go
# on time step 168 (time=8.4), 0.0238296 s/step
# Meep progress: 20.85/70.0 = 29.8% done in 8.0s, 18.9s to go
# on time step 417 (time=20.85), 0.0160912 s/step
# Meep progress: 33.35/70.0 = 47.6% done in 12.0s, 13.2s to go
# on time step 667 (time=33.35), 0.016064 s/step
# Meep progress: 40.7/70.0 = 58.1% done in 16.0s, 11.5s to go
# on time step 814 (time=40.7), 0.0272679 s/step
# Meep progress: 49.7/70.0 = 71.0% done in 20.0s, 8.2s to go
# on time step 995 (time=49.75), 0.0222001 s/step
# Meep progress: 59.300000000000004/70.0 = 84.7% done in 24.0s, 4.3s to go
# on time step 1187 (time=59.35), 0.0208658 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000803947 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 19.8722 s
# -----------
# Meep progress: 2.5500000000000003/70.0 = 3.6% done in 4.0s, 107.0s to go
# on time step 51 (time=2.55), 0.0793101 s/step
# Meep progress: 11.700000000000001/70.0 = 16.7% done in 8.1s, 40.3s to go
# on time step 234 (time=11.7), 0.0220659 s/step
# Meep progress: 16.85/70.0 = 24.1% done in 12.1s, 38.2s to go
# on time step 337 (time=16.85), 0.0390475 s/step
# Meep progress: 21.150000000000002/70.0 = 30.2% done in 16.1s, 37.3s to go
# on time step 423 (time=21.15), 0.0466755 s/step
# Meep progress: 25.650000000000002/70.0 = 36.6% done in 20.1s, 34.8s to go
# on time step 514 (time=25.7), 0.0444504 s/step
# Meep progress: 32.1/70.0 = 45.9% done in 24.2s, 28.5s to go
# on time step 643 (time=32.15), 0.0310175 s/step
# Meep progress: 38.35/70.0 = 54.8% done in 28.2s, 23.2s to go
# on time step 768 (time=38.4), 0.0321039 s/step
# Meep progress: 44.45/70.0 = 63.5% done in 32.2s, 18.5s to go
# on time step 890 (time=44.5), 0.0330878 s/step
# Meep progress: 52.650000000000006/70.0 = 75.2% done in 36.2s, 11.9s to go
# on time step 1055 (time=52.75), 0.0243527 s/step
# Meep progress: 61.300000000000004/70.0 = 87.6% done in 40.2s, 5.7s to go
# on time step 1228 (time=61.4), 0.0232644 s/step
# Meep progress: 69.55/70.0 = 99.4% done in 44.2s, 0.3s to go
# on time step 1394 (time=69.7), 0.0242029 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00141811 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.632131 s
# -----------
# Meep progress: 5.050000000000001/70.0 = 7.2% done in 4.0s, 51.6s to go
# on time step 101 (time=5.05), 0.0397441 s/step
# Meep progress: 14.5/70.0 = 20.7% done in 8.0s, 30.7s to go
# on time step 290 (time=14.5), 0.0212421 s/step
# Meep progress: 26.25/70.0 = 37.5% done in 12.0s, 20.1s to go
# on time step 525 (time=26.25), 0.0170603 s/step
# Meep progress: 38.400000000000006/70.0 = 54.9% done in 16.0s, 13.2s to go
# on time step 769 (time=38.45), 0.0164622 s/step
# Meep progress: 50.400000000000006/70.0 = 72.0% done in 20.0s, 7.8s to go
# on time step 1009 (time=50.45), 0.0166842 s/step
# Meep progress: 62.650000000000006/70.0 = 89.5% done in 24.1s, 2.8s to go
# on time step 1254 (time=62.7), 0.0163933 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000512123 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 16.7459 s
# -----------
# Meep progress: 6.45/70.0 = 9.2% done in 4.0s, 39.5s to go
# on time step 129 (time=6.45), 0.0310481 s/step
# Meep progress: 17.85/70.0 = 25.5% done in 8.0s, 23.4s to go
# on time step 357 (time=17.85), 0.0176092 s/step
# Meep progress: 28.900000000000002/70.0 = 41.3% done in 12.0s, 17.1s to go
# on time step 578 (time=28.9), 0.018137 s/step
# Meep progress: 40.900000000000006/70.0 = 58.4% done in 16.0s, 11.4s to go
# on time step 818 (time=40.9), 0.0167036 s/step
# Meep progress: 50.1/70.0 = 71.6% done in 20.1s, 8.0s to go
# on time step 1002 (time=50.1), 0.0218302 s/step
# Meep progress: 61.45/70.0 = 87.8% done in 24.1s, 3.3s to go
# on time step 1229 (time=61.45), 0.0176429 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 0.5235987755982988
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000357151 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.538717 s
# -----------
# Meep progress: 8.25/70.0 = 11.8% done in 4.0s, 30.0s to go
# on time step 165 (time=8.25), 0.0242888 s/step
# Meep progress: 20.1/70.0 = 28.7% done in 8.0s, 19.9s to go
# on time step 402 (time=20.1), 0.0169435 s/step
# Meep progress: 32.5/70.0 = 46.4% done in 12.0s, 13.9s to go
# on time step 650 (time=32.5), 0.0162128 s/step
# Meep progress: 44.800000000000004/70.0 = 64.0% done in 16.0s, 9.0s to go
# on time step 896 (time=44.8), 0.0162608 s/step
# Meep progress: 56.7/70.0 = 81.0% done in 20.1s, 4.7s to go
# on time step 1134 (time=56.7), 0.0168494 s/step
# Meep progress: 68.4/70.0 = 97.7% done in 24.1s, 0.6s to go
# on time step 1368 (time=68.4), 0.0171086 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000369072 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 23.4203 s
# -----------
# Meep progress: 5.15/70.0 = 7.4% done in 4.0s, 50.4s to go
# on time step 103 (time=5.15), 0.0388631 s/step
# Meep progress: 14.05/70.0 = 20.1% done in 8.0s, 31.9s to go
# on time step 281 (time=14.05), 0.0225172 s/step
# Meep progress: 23.1/70.0 = 33.0% done in 12.0s, 24.4s to go
# on time step 462 (time=23.1), 0.0221059 s/step
# Meep progress: 31.35/70.0 = 44.8% done in 16.0s, 19.8s to go
# on time step 627 (time=31.35), 0.0242704 s/step
# Meep progress: 42.6/70.0 = 60.9% done in 20.0s, 12.9s to go
# on time step 853 (time=42.65), 0.017772 s/step
# Meep progress: 53.25/70.0 = 76.1% done in 24.0s, 7.6s to go
# on time step 1066 (time=53.3), 0.0187961 s/step
# Meep progress: 65.2/70.0 = 93.1% done in 28.0s, 2.1s to go
# on time step 1305 (time=65.25), 0.0167638 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000388145 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.516886 s
# -----------
# Meep progress: 8.25/70.0 = 11.8% done in 4.0s, 29.9s to go
# on time step 165 (time=8.25), 0.0242471 s/step
# Meep progress: 21.1/70.0 = 30.1% done in 8.0s, 18.5s to go
# on time step 422 (time=21.1), 0.0155739 s/step
# Meep progress: 33.95/70.0 = 48.5% done in 12.0s, 12.8s to go
# on time step 679 (time=33.95), 0.0156181 s/step
# Meep progress: 46.550000000000004/70.0 = 66.5% done in 16.0s, 8.1s to go
# on time step 931 (time=46.55), 0.0158807 s/step
# Meep progress: 57.1/70.0 = 81.6% done in 20.0s, 4.5s to go
# on time step 1142 (time=57.1), 0.0190026 s/step
# Meep progress: 69.95/70.0 = 99.9% done in 24.0s, 0.0s to go
# on time step 1399 (time=69.95), 0.0155891 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000375032 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 17.0348 s
# -----------
# Meep progress: 8.5/70.0 = 12.1% done in 4.0s, 29.0s to go
# on time step 170 (time=8.5), 0.0235476 s/step
# Meep progress: 20.900000000000002/70.0 = 29.9% done in 8.0s, 18.8s to go
# on time step 418 (time=20.9), 0.0161443 s/step
# Meep progress: 33.2/70.0 = 47.4% done in 12.0s, 13.3s to go
# on time step 664 (time=33.2), 0.0162774 s/step
# Meep progress: 45.75/70.0 = 65.4% done in 16.0s, 8.5s to go
# on time step 915 (time=45.75), 0.0159726 s/step
# Meep progress: 58.2/70.0 = 83.1% done in 20.0s, 4.1s to go
# on time step 1164 (time=58.2), 0.016087 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 0.7853981633974483
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000432968 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.585525 s
# -----------
# Meep progress: 7.75/70.0 = 11.1% done in 4.0s, 32.2s to go
# on time step 155 (time=7.75), 0.0258252 s/step
# Meep progress: 20.1/70.0 = 28.7% done in 8.0s, 19.9s to go
# on time step 402 (time=20.1), 0.0162278 s/step
# Meep progress: 32.550000000000004/70.0 = 46.5% done in 12.0s, 13.8s to go
# on time step 651 (time=32.55), 0.0161062 s/step
# Meep progress: 44.85/70.0 = 64.1% done in 16.0s, 9.0s to go
# on time step 897 (time=44.85), 0.0162998 s/step
# Meep progress: 56.800000000000004/70.0 = 81.1% done in 20.0s, 4.7s to go
# on time step 1136 (time=56.8), 0.0167914 s/step
# Meep progress: 68.25/70.0 = 97.5% done in 24.1s, 0.6s to go
# on time step 1365 (time=68.25), 0.017506 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000356197 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 16.5367 s
# -----------
# Meep progress: 6.45/70.0 = 9.2% done in 4.0s, 39.4s to go
# on time step 129 (time=6.45), 0.031013 s/step
# Meep progress: 18.25/70.0 = 26.1% done in 8.0s, 22.7s to go
# on time step 365 (time=18.25), 0.0169935 s/step
# Meep progress: 30.0/70.0 = 42.9% done in 12.0s, 16.0s to go
# on time step 600 (time=30), 0.0170861 s/step
# Meep progress: 42.1/70.0 = 60.1% done in 16.0s, 10.6s to go
# on time step 843 (time=42.15), 0.016525 s/step
# Meep progress: 54.2/70.0 = 77.4% done in 20.0s, 5.8s to go
# on time step 1085 (time=54.25), 0.0165452 s/step
# Meep progress: 65.4/70.0 = 93.4% done in 24.0s, 1.7s to go
# on time step 1309 (time=65.45), 0.0179277 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000497103 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.61602 s
# -----------
# Meep progress: 3.8000000000000003/70.0 = 5.4% done in 4.0s, 70.0s to go
# on time step 76 (time=3.8), 0.0528828 s/step
# Meep progress: 11.600000000000001/70.0 = 16.6% done in 8.0s, 40.4s to go
# on time step 233 (time=11.65), 0.0255795 s/step
# Meep progress: 19.900000000000002/70.0 = 28.4% done in 12.1s, 30.4s to go
# on time step 398 (time=19.9), 0.0244452 s/step
# Meep progress: 28.05/70.0 = 40.1% done in 16.1s, 24.0s to go
# on time step 561 (time=28.05), 0.0245814 s/step
# Meep progress: 36.0/70.0 = 51.4% done in 20.1s, 19.0s to go
# on time step 720 (time=36), 0.0251862 s/step
# Meep progress: 45.5/70.0 = 65.0% done in 24.1s, 13.0s to go
# on time step 911 (time=45.55), 0.0210674 s/step
# Meep progress: 55.400000000000006/70.0 = 79.1% done in 28.1s, 7.4s to go
# on time step 1109 (time=55.45), 0.020233 s/step
# Meep progress: 65.15/70.0 = 93.1% done in 32.1s, 2.4s to go
# on time step 1304 (time=65.2), 0.0205901 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000316143 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 25.0538 s
# -----------
# Meep progress: 5.7/70.0 = 8.1% done in 4.0s, 45.2s to go
# on time step 114 (time=5.7), 0.0351253 s/step
# Meep progress: 15.15/70.0 = 21.6% done in 8.0s, 29.0s to go
# on time step 303 (time=15.15), 0.0212516 s/step
# Meep progress: 24.150000000000002/70.0 = 34.5% done in 12.0s, 22.8s to go
# on time step 483 (time=24.15), 0.0222654 s/step
# Meep progress: 33.6/70.0 = 48.0% done in 16.0s, 17.4s to go
# on time step 672 (time=33.6), 0.0211975 s/step
# Meep progress: 43.0/70.0 = 61.4% done in 20.1s, 12.6s to go
# on time step 860 (time=43), 0.0213348 s/step
# Meep progress: 53.1/70.0 = 75.9% done in 24.1s, 7.7s to go
# on time step 1063 (time=53.15), 0.0197896 s/step
# Meep progress: 62.5/70.0 = 89.3% done in 28.1s, 3.4s to go
# on time step 1251 (time=62.55), 0.0213895 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 1.0471975511965976
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000905037 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 1.42089 s
# -----------
# Meep progress: 5.3500000000000005/70.0 = 7.6% done in 4.0s, 48.5s to go
# on time step 107 (time=5.35), 0.037556 s/step
# Meep progress: 15.75/70.0 = 22.5% done in 8.0s, 27.6s to go
# on time step 315 (time=15.75), 0.0192325 s/step
# Meep progress: 25.8/70.0 = 36.9% done in 12.0s, 20.6s to go
# on time step 516 (time=25.8), 0.0199315 s/step
# Meep progress: 35.85/70.0 = 51.2% done in 16.0s, 15.3s to go
# on time step 717 (time=35.85), 0.0200064 s/step
# Meep progress: 45.45/70.0 = 64.9% done in 20.1s, 10.8s to go
# on time step 909 (time=45.45), 0.0209427 s/step
# Meep progress: 55.400000000000006/70.0 = 79.1% done in 24.1s, 6.3s to go
# on time step 1108 (time=55.4), 0.0201055 s/step
# Meep progress: 65.15/70.0 = 93.1% done in 28.1s, 2.1s to go
# on time step 1303 (time=65.15), 0.0207088 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000545979 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 18.726 s
# -----------
# Meep progress: 6.8500000000000005/70.0 = 9.8% done in 4.0s, 36.9s to go
# on time step 137 (time=6.85), 0.0292539 s/step
# Meep progress: 17.7/70.0 = 25.3% done in 8.0s, 23.7s to go
# on time step 354 (time=17.7), 0.0184547 s/step
# Meep progress: 26.3/70.0 = 37.6% done in 12.0s, 20.0s to go
# on time step 526 (time=26.3), 0.023289 s/step
# Meep progress: 34.9/70.0 = 49.9% done in 16.0s, 16.1s to go
# on time step 698 (time=34.9), 0.0233426 s/step
# Meep progress: 44.150000000000006/70.0 = 63.1% done in 20.1s, 11.7s to go
# on time step 883 (time=44.15), 0.0217431 s/step
# Meep progress: 53.1/70.0 = 75.9% done in 24.1s, 7.7s to go
# on time step 1062 (time=53.1), 0.0224298 s/step
# Meep progress: 63.050000000000004/70.0 = 90.1% done in 28.1s, 3.1s to go
# on time step 1261 (time=63.05), 0.0202018 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00103593 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.595023 s
# -----------
# Meep progress: 4.45/70.0 = 6.4% done in 4.0s, 59.0s to go
# on time step 89 (time=4.45), 0.0450026 s/step
# Meep progress: 15.450000000000001/70.0 = 22.1% done in 8.0s, 28.3s to go
# on time step 309 (time=15.45), 0.0182429 s/step
# Meep progress: 24.950000000000003/70.0 = 35.6% done in 12.0s, 21.7s to go
# on time step 499 (time=24.95), 0.0211743 s/step
# Meep progress: 33.550000000000004/70.0 = 47.9% done in 16.0s, 17.4s to go
# on time step 671 (time=33.55), 0.0232781 s/step
# Meep progress: 42.95/70.0 = 61.4% done in 20.1s, 12.6s to go
# on time step 859 (time=42.95), 0.0213312 s/step
# Meep progress: 52.45/70.0 = 74.9% done in 24.1s, 8.1s to go
# on time step 1049 (time=52.45), 0.0210639 s/step
# Meep progress: 63.900000000000006/70.0 = 91.3% done in 28.1s, 2.7s to go
# on time step 1279 (time=63.95), 0.0174658 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000478029 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 19.2431 s
# -----------
# Meep progress: 5.25/70.0 = 7.5% done in 4.0s, 49.6s to go
# on time step 105 (time=5.25), 0.0382884 s/step
# Meep progress: 13.8/70.0 = 19.7% done in 8.0s, 32.7s to go
# on time step 276 (time=13.8), 0.0234732 s/step
# Meep progress: 23.0/70.0 = 32.9% done in 12.0s, 24.6s to go
# on time step 460 (time=23), 0.0217834 s/step
# Meep progress: 34.7/70.0 = 49.6% done in 16.1s, 16.3s to go
# on time step 694 (time=34.7), 0.0171211 s/step
# Meep progress: 46.2/70.0 = 66.0% done in 20.1s, 10.3s to go
# on time step 924 (time=46.2), 0.0174422 s/step
# Meep progress: 54.650000000000006/70.0 = 78.1% done in 24.1s, 6.8s to go
# on time step 1093 (time=54.65), 0.0237617 s/step
# Meep progress: 62.300000000000004/70.0 = 89.0% done in 28.1s, 3.5s to go
# on time step 1246 (time=62.3), 0.0262175 s/step
# Meep progress: 66.15/70.0 = 94.5% done in 32.1s, 1.9s to go
# on time step 1323 (time=66.15), 0.0520706 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 1.308996938995747
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00120497 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.933115 s
# -----------
# Meep progress: 4.95/70.0 = 7.1% done in 4.0s, 52.8s to go
# on time step 99 (time=4.95), 0.0405687 s/step
# Meep progress: 16.150000000000002/70.0 = 23.1% done in 8.0s, 26.8s to go
# on time step 323 (time=16.15), 0.0178972 s/step
# Meep progress: 25.900000000000002/70.0 = 37.0% done in 12.0s, 20.5s to go
# on time step 518 (time=25.9), 0.0205853 s/step
# Meep progress: 31.25/70.0 = 44.6% done in 16.1s, 20.0s to go
# on time step 625 (time=31.25), 0.0379656 s/step
# Meep progress: 36.25/70.0 = 51.8% done in 20.1s, 18.7s to go
# on time step 725 (time=36.25), 0.0400419 s/step
# Meep progress: 46.400000000000006/70.0 = 66.3% done in 24.1s, 12.3s to go
# on time step 928 (time=46.4), 0.0197132 s/step
# Meep progress: 55.85/70.0 = 79.8% done in 28.1s, 7.1s to go
# on time step 1131 (time=56.55), 0.0197437 s/step
# Meep progress: 67.2/70.0 = 96.0% done in 32.1s, 1.3s to go
# on time step 1356 (time=67.8), 0.0178005 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000378847 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 18.4107 s
# -----------
# Meep progress: 2.6/70.0 = 3.7% done in 4.0s, 104.3s to go
# on time step 52 (time=2.6), 0.0773621 s/step
# Meep progress: 11.15/70.0 = 15.9% done in 8.0s, 42.4s to go
# on time step 223 (time=11.15), 0.0234172 s/step
# Meep progress: 21.5/70.0 = 30.7% done in 12.0s, 27.1s to go
# on time step 430 (time=21.5), 0.0193269 s/step
# Meep progress: 32.050000000000004/70.0 = 45.8% done in 16.1s, 19.0s to go
# on time step 641 (time=32.05), 0.0190652 s/step
# Meep progress: 43.2/70.0 = 61.7% done in 20.1s, 12.5s to go
# on time step 864 (time=43.2), 0.0179972 s/step
# Meep progress: 54.5/70.0 = 77.9% done in 24.1s, 6.9s to go
# on time step 1090 (time=54.5), 0.0178406 s/step
# Meep progress: 65.3/70.0 = 93.3% done in 28.1s, 2.0s to go
# on time step 1306 (time=65.3), 0.0185309 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000403881 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.558371 s
# -----------
# Meep progress: 7.050000000000001/70.0 = 10.1% done in 4.0s, 35.8s to go
# on time step 141 (time=7.05), 0.0284657 s/step
# Meep progress: 18.95/70.0 = 27.1% done in 8.0s, 21.6s to go
# on time step 379 (time=18.95), 0.01686 s/step
# Meep progress: 29.35/70.0 = 41.9% done in 12.0s, 16.7s to go
# on time step 587 (time=29.35), 0.0192795 s/step
# Meep progress: 37.7/70.0 = 53.9% done in 16.0s, 13.7s to go
# on time step 754 (time=37.7), 0.0239791 s/step
# Meep progress: 48.050000000000004/70.0 = 68.6% done in 20.0s, 9.2s to go
# on time step 961 (time=48.05), 0.0193398 s/step
# Meep progress: 59.35/70.0 = 84.8% done in 24.1s, 4.3s to go
# on time step 1187 (time=59.35), 0.0177266 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00109315 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 17.7245 s
# -----------
# Meep progress: 7.300000000000001/70.0 = 10.4% done in 4.0s, 34.4s to go
# on time step 146 (time=7.3), 0.0274214 s/step
# Meep progress: 18.5/70.0 = 26.4% done in 8.0s, 22.3s to go
# on time step 370 (time=18.5), 0.0178938 s/step
# Meep progress: 29.650000000000002/70.0 = 42.4% done in 12.0s, 16.4s to go
# on time step 593 (time=29.65), 0.0179599 s/step
# Meep progress: 41.25/70.0 = 58.9% done in 16.0s, 11.2s to go
# on time step 825 (time=41.25), 0.017246 s/step
# Meep progress: 52.6/70.0 = 75.1% done in 20.0s, 6.6s to go
# on time step 1052 (time=52.6), 0.0176944 s/step
# Meep progress: 63.550000000000004/70.0 = 90.8% done in 24.0s, 2.4s to go
# on time step 1271 (time=63.55), 0.0183014 s/step
# Meep progress: 67.3/70.0 = 96.1% done in 28.1s, 1.1s to go
# on time step 1346 (time=67.3), 0.0544986 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 1.5707963267948966
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00228381 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 1.21511 s
# -----------
# Meep progress: 1.7000000000000002/70.0 = 2.4% done in 4.0s, 161.1s to go
# on time step 34 (time=1.7), 0.117968 s/step
# Meep progress: 10.4/70.0 = 14.9% done in 8.0s, 45.9s to go
# on time step 208 (time=10.4), 0.0230007 s/step
# Meep progress: 18.2/70.0 = 26.0% done in 12.0s, 34.3s to go
# on time step 364 (time=18.2), 0.0257636 s/step
# Meep progress: 27.35/70.0 = 39.1% done in 16.0s, 25.0s to go
# on time step 548 (time=27.4), 0.0218268 s/step
# Meep progress: 36.7/70.0 = 52.4% done in 20.0s, 18.2s to go
# on time step 735 (time=36.75), 0.0214411 s/step
# Meep progress: 44.0/70.0 = 62.9% done in 24.1s, 14.2s to go
# on time step 880 (time=44), 0.0277876 s/step
# Meep progress: 49.300000000000004/70.0 = 70.4% done in 28.1s, 11.8s to go
# on time step 986 (time=49.3), 0.0377666 s/step
# Meep progress: 59.7/70.0 = 85.3% done in 32.1s, 5.5s to go
# on time step 1194 (time=59.7), 0.0193186 s/step
# Meep progress: 68.10000000000001/70.0 = 97.3% done in 36.1s, 1.0s to go
# on time step 1362 (time=68.1), 0.0239449 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000377893 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 19.3655 s
# -----------
# Meep progress: 6.7/70.0 = 9.6% done in 4.0s, 38.0s to go
# on time step 134 (time=6.7), 0.0299864 s/step
# Meep progress: 16.3/70.0 = 23.3% done in 8.0s, 26.4s to go
# on time step 326 (time=16.3), 0.0208657 s/step
# Meep progress: 24.8/70.0 = 35.4% done in 12.0s, 22.0s to go
# on time step 496 (time=24.8), 0.0236436 s/step
# Meep progress: 34.25/70.0 = 48.9% done in 16.1s, 16.8s to go
# on time step 685 (time=34.25), 0.0212419 s/step
# Meep progress: 44.650000000000006/70.0 = 63.8% done in 20.1s, 11.4s to go
# on time step 893 (time=44.65), 0.0192545 s/step
# Meep progress: 54.400000000000006/70.0 = 77.7% done in 24.1s, 6.9s to go
# on time step 1088 (time=54.4), 0.0205356 s/step
# Meep progress: 64.60000000000001/70.0 = 92.3% done in 28.1s, 2.3s to go
# on time step 1292 (time=64.6), 0.0196396 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000427008 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.600222 s
# -----------
# Meep progress: 6.050000000000001/70.0 = 8.6% done in 4.0s, 42.3s to go
# on time step 121 (time=6.05), 0.0330814 s/step
# Meep progress: 17.75/70.0 = 25.4% done in 8.0s, 23.6s to go
# on time step 355 (time=17.75), 0.0171395 s/step
# Meep progress: 29.700000000000003/70.0 = 42.4% done in 12.0s, 16.3s to go
# on time step 594 (time=29.7), 0.0167593 s/step
# Meep progress: 35.050000000000004/70.0 = 50.1% done in 16.0s, 16.0s to go
# on time step 701 (time=35.05), 0.0374057 s/step
# Meep progress: 42.5/70.0 = 60.7% done in 20.0s, 13.0s to go
# on time step 851 (time=42.55), 0.0267922 s/step
# Meep progress: 52.75/70.0 = 75.4% done in 24.0s, 7.9s to go
# on time step 1056 (time=52.8), 0.0195464 s/step
# Meep progress: 63.45/70.0 = 90.6% done in 28.0s, 2.9s to go
# on time step 1270 (time=63.5), 0.018732 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000363111 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 17.2715 s
# -----------
# Meep progress: 6.800000000000001/70.0 = 9.7% done in 4.0s, 37.3s to go
# on time step 136 (time=6.8), 0.0294939 s/step
# Meep progress: 17.45/70.0 = 24.9% done in 8.0s, 24.2s to go
# on time step 349 (time=17.45), 0.0188607 s/step
# Meep progress: 28.450000000000003/70.0 = 40.6% done in 12.0s, 17.6s to go
# on time step 569 (time=28.45), 0.0182166 s/step
# Meep progress: 39.900000000000006/70.0 = 57.0% done in 16.0s, 12.1s to go
# on time step 798 (time=39.9), 0.0174807 s/step
# Meep progress: 49.95/70.0 = 71.4% done in 20.1s, 8.0s to go
# on time step 999 (time=49.95), 0.0199539 s/step
# Meep progress: 61.45/70.0 = 87.8% done in 24.1s, 3.3s to go
# on time step 1229 (time=61.45), 0.0174507 s/step
# run 0 finished at t = 70.0 (1400 timesteps)

# %%
plt.plot([np.degrees(b) for b in betas], scatt_eff_list, marker='o')
plt.xlabel("Polarization angle β (degrees)")
plt.ylabel("Scattering efficiency")
plt.grid(True)
plt.title("Scattering efficiency vs. polarization angle")
plt.show()

# %%
from tabulate import tabulate

def scalar(val):
    return val.item() if isinstance(val, np.ndarray) else val

table_data = [
    [f"{scalar(row['beta']):.1f}°",
     f"{scalar(row['X1']):.5f}",
     f"{scalar(row['X2']):.5f}",
     f"{scalar(row['Y1']):.5f}",
     f"{scalar(row['Y2']):.5f}",
     f"{scalar(row['Z1']):.5f}",
     f"{scalar(row['Z2']):.5f}",
     f"{scalar(row['scatt_total']):.5f}"]
    for row in flux_results
]

headers = ["β (°)", "X1 (−x)", "X2 (+x)", "Y1 (−y)", "Y2 (+y)", "Z1 (−z)", "Z2 (+z)", "Scatt. Total"]
print(tabulate(table_data, headers=headers, tablefmt="github"))
# Out:
# | β (°)   |   X1 (−x) |   X2 (+x) |   Y1 (−y) |   Y2 (+y) |   Z1 (−z) |   Z2 (+z) |   Scatt. Total |
# |---------|-----------|-----------|-----------|-----------|-----------|-----------|----------------|
# | 0.0°    |   0.01217 |  -0.01259 |   0.00542 |   0.01196 |  -0.97458 |   0.01335 |       -0.9697  |
# | 15.0°   |   0.01231 |  -0.01263 |   0.00527 |   0.01192 |  -0.97426 |   0.01337 |       -0.96933 |
# | 30.0°   |   0.0127  |  -0.01275 |   0.00487 |   0.01182 |  -0.97339 |   0.01343 |       -0.96832 |
# | 45.0°   |   0.01322 |  -0.01292 |   0.00432 |   0.01169 |  -0.9722  |   0.01351 |       -0.96694 |
# | 60.0°   |   0.01375 |  -0.01309 |   0.00376 |   0.01156 |  -0.97101 |   0.01359 |       -0.96556 |
# | 75.0°   |   0.01413 |  -0.01321 |   0.00336 |   0.01146 |  -0.97014 |   0.01365 |       -0.96455 |
# | 90.0°   |   0.01427 |  -0.01325 |   0.00321 |   0.01142 |  -0.96982 |   0.01367 |       -0.96418 |

# %%
def scalar(val):
    return val.item() if isinstance(val, np.ndarray) else val

for entry in flux_results:
    print(f"\n--- β = {scalar(entry['beta']):.1f}° ---")
    print(f"X1 (−x): {scalar(entry['X1']):.5f}")
    print(f"X2 (+x): {scalar(entry['X2']):.5f}")
    print(f"Y1 (−y): {scalar(entry['Y1']):.5f}")
    print(f"Y2 (+y): {scalar(entry['Y2']):.5f}")
    print(f"Z1 (−z): {scalar(entry['Z1']):.5f}")
    print(f"Z2 (+z): {scalar(entry['Z2']):.5f}")
    print(f"Scattered Total: {scalar(entry['scatt_total']):.5f}")
# Out:
# --- β = 0.0° ---
# X1 (−x): 0.01217
# X2 (+x): -0.01259
# Y1 (−y): 0.00542
# Y2 (+y): 0.01196
# Z1 (−z): -0.97458
# Z2 (+z): 0.01335
# Scattered Total: -0.96970
#
# --- β = 15.0° ---
# X1 (−x): 0.01231
# X2 (+x): -0.01263
# Y1 (−y): 0.00527
# Y2 (+y): 0.01192
# Z1 (−z): -0.97426
# Z2 (+z): 0.01337
# Scattered Total: -0.96933
#
# --- β = 30.0° ---
# X1 (−x): 0.01270
# X2 (+x): -0.01275
# Y1 (−y): 0.00487
# Y2 (+y): 0.01182
# Z1 (−z): -0.97339
# Z2 (+z): 0.01343
# Scattered Total: -0.96832
#
# --- β = 45.0° ---
# X1 (−x): 0.01322
# X2 (+x): -0.01292
# Y1 (−y): 0.00432
# Y2 (+y): 0.01169
# Z1 (−z): -0.97220
# Z2 (+z): 0.01351
# Scattered Total: -0.96694
#
# --- β = 60.0° ---
# X1 (−x): 0.01375
# X2 (+x): -0.01309
# Y1 (−y): 0.00376
# Y2 (+y): 0.01156
# Z1 (−z): -0.97101
# Z2 (+z): 0.01359
# Scattered Total: -0.96556
#
# --- β = 75.0° ---
# X1 (−x): 0.01413
# X2 (+x): -0.01321
# Y1 (−y): 0.00336
# Y2 (+y): 0.01146
# Z1 (−z): -0.97014
# Z2 (+z): 0.01365
# Scattered Total: -0.96455
#
# --- β = 90.0° ---
# X1 (−x): 0.01427
# X2 (+x): -0.01325
# Y1 (−y): 0.00321
# Y2 (+y): 0.01142
# Z1 (−z): -0.96982
# Z2 (+z): 0.01367
# Scattered Total: -0.96418

# %%
import numpy as np
import matplotlib.pyplot as plt

# Convert to scalar values if needed
def scalar(val):
    return val.item() if isinstance(val, np.ndarray) else val

# Extract data
betas = [scalar(entry['beta']) for entry in flux_results]
Z1 = [scalar(entry['Z1']) for entry in flux_results]
Z2 = [scalar(entry['Z2']) for entry in flux_results]
X1 = [scalar(entry['X1']) for entry in flux_results]
X2 = [scalar(entry['X2']) for entry in flux_results]
Y1 = [scalar(entry['Y1']) for entry in flux_results]
Y2 = [scalar(entry['Y2']) for entry in flux_results]


# Set up subplots
fig, axs = plt.subplots(3, 2, figsize=(12, 10))
axs = axs.flatten()

# Plot each component
labels = ['Z1 (−z)', 'Z2 (+z)', 'X1 (−x)', 'X2 (+x)', 'Y1 (−y)', 'Y2 (+y)']
values = [Z1, Z2, X1, X2, Y1, Y2]

for i, (label, val) in enumerate(zip(labels, values)):
    axs[i].plot(betas, val, marker='o')
    axs[i].set_title(label)
    axs[i].set_xlabel("β (degrees)")
    axs[i].set_ylabel("Flux")
    axs[i].grid(True)

# Hide unused subplot if any
if len(axs) > len(labels):
    axs[-1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# The incident intensity (`intensity`) is the flux in one of the six monitor planes (the one closest to and facing the planewave source propagating in the $x$ direction) divided by its area. This is why the six sides of the flux box are defined separately. (Otherwise, the entire box could have been defined as a single flux object with different weights ±1 for each side.) The scattered power is multiplied by -1 since it is the *outgoing* power (a positive quantity) rather than the incoming power as defined by the orientation of the flux box. Note that because of the linear $E_z$ polarization of the source, the flux through the $y$ and $z$ planes will *not* be the same. A circularly-polarized source would have produced equal flux in these two monitor planes. The runtime of the scattering run is chosen to be sufficiently long to ensure that the Fourier-transformed fields have [converged](https://meep.readthedocs.io/en/latest/FAQ/checking-convergence).
