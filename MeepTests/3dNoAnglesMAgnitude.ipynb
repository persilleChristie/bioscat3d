# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt

# %%
# Simulation parameters
resolution = 10  # pixels/um
pml_thickness = 2
cell_x = 16
cell_y = 16
cell_z = 16

sphere_radius = 1.0
sphere_eps = 2.56
substrate_eps = 2.56
frequency = 1.0

cell_size = mp.Vector3(cell_x, cell_y, cell_z)

# %%
# Materials
default_material = mp.Medium(index=1.0)
sphere = mp.Sphere(
    center=mp.Vector3(0, 0, 1.5),  # place above substrate
    radius=sphere_radius,
    material=mp.Medium(epsilon=sphere_eps)
)

substrate = mp.Block(
    center=mp.Vector3(0, 0, -cell_z/4),
    size=mp.Vector3(mp.inf, mp.inf, cell_z/2),
    material=mp.Medium(epsilon=substrate_eps)
)

geometry = [sphere, substrate]

# Source: downward plane wave
sources = [
    mp.EigenModeSource(
        src=mp.ContinuousSource(frequency=frequency),
        center=mp.Vector3(0, 0, 0.5 * cell_z - pml_thickness - 1),
        size=mp.Vector3(cell_x, cell_y, 0),  # xy plane source
        direction=mp.Z,
        eig_kpoint=mp.Vector3(0, 0, -1),
        eig_band=1,
        eig_match_freq=True
    )
]

# PMLs on all sides
pml_layers = [
    mp.PML(thickness=pml_thickness, direction=mp.X),
    mp.PML(thickness=pml_thickness, direction=mp.Y),
    mp.PML(thickness=pml_thickness, direction=mp.Z),
]

# Simulation object
sim = mp.Simulation(
    cell_size=cell_size,
    resolution=resolution,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    default_material=default_material
)

# Add flux monitors (six directions)
flux_regions = {
    'top':    mp.FluxRegion(center=mp.Vector3(0, 0, 0.5*cell_z - pml_thickness - 0.1), size=mp.Vector3(cell_x, cell_y, 0)),
    'bottom': mp.FluxRegion(center=mp.Vector3(0, 0, -0.5*cell_z + pml_thickness + 0.1), size=mp.Vector3(cell_x, cell_y, 0)),
    'left':   mp.FluxRegion(center=mp.Vector3(-0.5*cell_x + pml_thickness + 0.1, 0, 0), size=mp.Vector3(0, cell_y, cell_z)),
    'right':  mp.FluxRegion(center=mp.Vector3(0.5*cell_x - pml_thickness - 0.1, 0, 0), size=mp.Vector3(0, cell_y, cell_z)),
    'front':  mp.FluxRegion(center=mp.Vector3(0, -0.5*cell_y + pml_thickness + 0.1, 0), size=mp.Vector3(cell_x, 0, cell_z)),
    'back':   mp.FluxRegion(center=mp.Vector3(0, 0.5*cell_y - pml_thickness - 0.1, 0), size=mp.Vector3(cell_x, 0, cell_z)),
}

flux_monitors = {name: sim.add_flux(frequency, 0, 1, region)
                 for name, region in flux_regions.items()}

# Run the simulation
sim.run(until=60)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00129199 s
# Working in 3D dimensions.
# Computational cell is 16 x 16 x 16 with resolution 10
#      sphere, center = (0,0,1.5)
#           radius 1
#           dielectric constant epsilon diagonal = (2.56,2.56,2.56)
#      block, center = (0,0,-4)
#           size (1e+20,1e+20,8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.56,2.56,2.56)
# time for set_epsilon = 17.4055 s
# -----------
# MPB solved for frequency_1(0,0,-1) = 1 after 105 iters
# Meep progress: 0.05/60.0 = 0.1% done in 10.5s, 12531.4s to go
# on time step 1 (time=0.05), 10.4522 s/step
# Meep progress: 1.5/60.0 = 2.5% done in 14.6s, 568.9s to go
# on time step 30 (time=1.5), 0.142508 s/step
# Meep progress: 2.8000000000000003/60.0 = 4.7% done in 18.6s, 380.8s to go
# on time step 56 (time=2.8), 0.155877 s/step
# Meep progress: 3.95/60.0 = 6.6% done in 22.9s, 324.2s to go
# on time step 79 (time=3.95), 0.183042 s/step
# Meep progress: 5.300000000000001/60.0 = 8.8% done in 26.9s, 277.4s to go
# on time step 106 (time=5.3), 0.148938 s/step
# Meep progress: 6.75/60.0 = 11.2% done in 31.0s, 244.6s to go
# on time step 135 (time=6.75), 0.142635 s/step
# Meep progress: 8.05/60.0 = 13.4% done in 35.0s, 226.1s to go
# on time step 161 (time=8.05), 0.15455 s/step
# Meep progress: 9.200000000000001/60.0 = 15.3% done in 39.0s, 215.6s to go
# on time step 184 (time=9.2), 0.174368 s/step
# Meep progress: 10.25/60.0 = 17.1% done in 43.1s, 209.4s to go
# on time step 205 (time=10.25), 0.195346 s/step
# Meep progress: 11.4/60.0 = 19.0% done in 47.2s, 201.2s to go
# on time step 228 (time=11.4), 0.175741 s/step
# Meep progress: 12.450000000000001/60.0 = 20.8% done in 51.2s, 195.6s to go
# on time step 249 (time=12.45), 0.192225 s/step
# Meep progress: 13.3/60.0 = 22.2% done in 56.0s, 196.5s to go
# on time step 266 (time=13.3), 0.27803 s/step
# Meep progress: 13.5/60.0 = 22.5% done in 61.6s, 212.0s to go
# on time step 270 (time=13.5), 1.40394 s/step
# Meep progress: 13.850000000000001/60.0 = 23.1% done in 65.9s, 219.7s to go
# on time step 277 (time=13.85), 0.618633 s/step
# Meep progress: 14.3/60.0 = 23.8% done in 70.2s, 224.2s to go
# on time step 286 (time=14.3), 0.469898 s/step
# Meep progress: 15.0/60.0 = 25.0% done in 74.3s, 223.0s to go
# on time step 300 (time=15), 0.29752 s/step
# Meep progress: 16.3/60.0 = 27.2% done in 78.4s, 210.1s to go
# on time step 326 (time=16.3), 0.155314 s/step
# Meep progress: 17.650000000000002/60.0 = 29.4% done in 82.4s, 197.8s to go
# on time step 353 (time=17.65), 0.150099 s/step
# Meep progress: 19.05/60.0 = 31.8% done in 86.6s, 186.1s to go
# on time step 381 (time=19.05), 0.147482 s/step
# Meep progress: 20.3/60.0 = 33.8% done in 90.6s, 177.1s to go
# on time step 406 (time=20.3), 0.160183 s/step
# Meep progress: 21.1/60.0 = 35.2% done in 95.1s, 175.4s to go
# on time step 422 (time=21.1), 0.286056 s/step
# Meep progress: 21.55/60.0 = 35.9% done in 99.6s, 177.7s to go
# on time step 431 (time=21.55), 0.492689 s/step
# Meep progress: 21.950000000000003/60.0 = 36.6% done in 103.8s, 180.0s to go
# on time step 439 (time=21.95), 0.531952 s/step
# Meep progress: 23.0/60.0 = 38.3% done in 107.9s, 173.5s to go
# on time step 460 (time=23), 0.191649 s/step
# Meep progress: 23.900000000000002/60.0 = 39.8% done in 111.9s, 169.0s to go
# on time step 478 (time=23.9), 0.224034 s/step
# Meep progress: 24.650000000000002/60.0 = 41.1% done in 116.1s, 166.5s to go
# on time step 493 (time=24.65), 0.281336 s/step
# Meep progress: 25.450000000000003/60.0 = 42.4% done in 120.2s, 163.2s to go
# on time step 509 (time=25.45), 0.256727 s/step
# Meep progress: 26.450000000000003/60.0 = 44.1% done in 124.3s, 157.7s to go
# on time step 529 (time=26.45), 0.206167 s/step
# Meep progress: 27.450000000000003/60.0 = 45.8% done in 128.5s, 152.4s to go
# on time step 549 (time=27.45), 0.208117 s/step
# Meep progress: 28.6/60.0 = 47.7% done in 132.6s, 145.6s to go
# on time step 572 (time=28.6), 0.176569 s/step
# Meep progress: 29.950000000000003/60.0 = 49.9% done in 136.6s, 137.1s to go
# on time step 599 (time=29.95), 0.149535 s/step
# Meep progress: 31.35/60.0 = 52.3% done in 140.8s, 128.6s to go
# on time step 627 (time=31.35), 0.147885 s/step
# Meep progress: 32.6/60.0 = 54.3% done in 144.8s, 121.7s to go
# on time step 652 (time=32.6), 0.161348 s/step
# Meep progress: 33.95/60.0 = 56.6% done in 148.9s, 114.2s to go
# on time step 679 (time=33.95), 0.150503 s/step
# Meep progress: 35.0/60.0 = 58.3% done in 152.9s, 109.2s to go
# on time step 700 (time=35), 0.193289 s/step
# Meep progress: 36.1/60.0 = 60.2% done in 157.2s, 104.0s to go
# on time step 722 (time=36.1), 0.193027 s/step
# Meep progress: 37.25/60.0 = 62.1% done in 161.2s, 98.4s to go
# on time step 745 (time=37.25), 0.173968 s/step
# Meep progress: 38.400000000000006/60.0 = 64.0% done in 165.2s, 92.9s to go
# on time step 768 (time=38.4), 0.175353 s/step
# Meep progress: 39.650000000000006/60.0 = 66.1% done in 169.4s, 86.9s to go
# on time step 793 (time=39.65), 0.166761 s/step
# Meep progress: 40.7/60.0 = 67.8% done in 173.4s, 82.2s to go
# on time step 814 (time=40.7), 0.194142 s/step
# Meep progress: 41.550000000000004/60.0 = 69.3% done in 177.5s, 78.8s to go
# on time step 831 (time=41.55), 0.2385 s/step
# Meep progress: 42.400000000000006/60.0 = 70.7% done in 181.7s, 75.4s to go
# on time step 848 (time=42.4), 0.246664 s/step
# Meep progress: 43.150000000000006/60.0 = 71.9% done in 185.8s, 72.6s to go
# on time step 863 (time=43.15), 0.276244 s/step
# Meep progress: 43.95/60.0 = 73.3% done in 189.9s, 69.3s to go
# on time step 879 (time=43.95), 0.252257 s/step
# Meep progress: 44.800000000000004/60.0 = 74.7% done in 193.9s, 65.8s to go
# on time step 896 (time=44.8), 0.238779 s/step
# Meep progress: 45.45/60.0 = 75.8% done in 198.0s, 63.4s to go
# on time step 909 (time=45.45), 0.315673 s/step
# Meep progress: 46.300000000000004/60.0 = 77.2% done in 202.2s, 59.8s to go
# on time step 926 (time=46.3), 0.242001 s/step
# Meep progress: 47.25/60.0 = 78.8% done in 206.3s, 55.7s to go
# on time step 945 (time=47.25), 0.21519 s/step
# Meep progress: 48.25/60.0 = 80.4% done in 210.4s, 51.2s to go
# on time step 965 (time=48.25), 0.204971 s/step
# Meep progress: 48.75/60.0 = 81.2% done in 214.7s, 49.5s to go
# on time step 975 (time=48.75), 0.436809 s/step
# Meep progress: 49.35/60.0 = 82.2% done in 219.0s, 47.3s to go
# on time step 987 (time=49.35), 0.354369 s/step
# Meep progress: 49.75/60.0 = 82.9% done in 224.4s, 46.2s to go
# on time step 995 (time=49.75), 0.673983 s/step
# Meep progress: 49.95/60.0 = 83.3% done in 229.6s, 46.2s to go
# on time step 999 (time=49.95), 1.30598 s/step
# Meep progress: 50.400000000000006/60.0 = 84.0% done in 233.9s, 44.6s to go
# on time step 1008 (time=50.4), 0.481324 s/step
# Meep progress: 51.1/60.0 = 85.2% done in 238.0s, 41.5s to go
# on time step 1022 (time=51.1), 0.293222 s/step
# Meep progress: 52.1/60.0 = 86.8% done in 242.2s, 36.7s to go
# on time step 1042 (time=52.1), 0.208778 s/step
# Meep progress: 53.0/60.0 = 88.3% done in 246.3s, 32.5s to go
# on time step 1060 (time=53), 0.226347 s/step
# Meep progress: 53.650000000000006/60.0 = 89.4% done in 250.3s, 29.6s to go
# on time step 1073 (time=53.65), 0.310779 s/step
# Meep progress: 53.95/60.0 = 89.9% done in 254.5s, 28.5s to go
# on time step 1079 (time=53.95), 0.68865 s/step
# Meep progress: 54.300000000000004/60.0 = 90.5% done in 259.4s, 27.2s to go
# on time step 1086 (time=54.3), 0.696018 s/step
# Meep progress: 54.550000000000004/60.0 = 90.9% done in 263.8s, 26.4s to go
# on time step 1091 (time=54.55), 0.881524 s/step
# Meep progress: 54.85/60.0 = 91.4% done in 268.2s, 25.2s to go
# on time step 1097 (time=54.85), 0.725589 s/step
# Meep progress: 55.150000000000006/60.0 = 91.9% done in 272.3s, 23.9s to go
# on time step 1103 (time=55.15), 0.683889 s/step
# Meep progress: 55.45/60.0 = 92.4% done in 276.4s, 22.7s to go
# on time step 1109 (time=55.45), 0.688833 s/step
# Meep progress: 56.0/60.0 = 93.3% done in 280.9s, 20.1s to go
# on time step 1120 (time=56), 0.403793 s/step
# Meep progress: 56.550000000000004/60.0 = 94.3% done in 284.9s, 17.4s to go
# on time step 1131 (time=56.55), 0.367843 s/step
# Meep progress: 57.35/60.0 = 95.6% done in 289.1s, 13.4s to go
# on time step 1147 (time=57.35), 0.260931 s/step
# Meep progress: 58.1/60.0 = 96.8% done in 293.3s, 9.6s to go
# on time step 1162 (time=58.1), 0.281187 s/step
# Meep progress: 58.7/60.0 = 97.8% done in 297.7s, 6.6s to go
# on time step 1174 (time=58.7), 0.367613 s/step
# Meep progress: 59.1/60.0 = 98.5% done in 302.1s, 4.6s to go
# on time step 1182 (time=59.1), 0.546146 s/step
# Meep progress: 59.550000000000004/60.0 = 99.3% done in 306.1s, 2.3s to go
# on time step 1191 (time=59.55), 0.448451 s/step
# run 0 finished at t = 60.0 (1200 timesteps)

# %%
# Print flux values
for name, monitor in flux_monitors.items():
    flux_val = mp.get_fluxes(monitor)[0]
    print(f"Flux through {name}: {flux_val:.6f}")

# Get all field components for total |E| calculation
ex = sim.get_array(center=mp.Vector3(), size=mp.Vector3(cell_x, 0, cell_z), component=mp.Ex)
ey = sim.get_array(center=mp.Vector3(), size=mp.Vector3(cell_x, 0, cell_z), component=mp.Ey)
ez = sim.get_array(center=mp.Vector3(), size=mp.Vector3(cell_x, 0, cell_z), component=mp.Ez)

abs_E = np.sqrt(np.abs(ex)**2 + np.abs(ey)**2 + np.abs(ez)**2)

# Plot total field magnitude
plt.figure(dpi=100)
plt.imshow(abs_E.T, cmap='inferno', origin='lower', extent=[-cell_x/2, cell_x/2, -cell_z/2, cell_z/2])
plt.colorbar(label='|E|')
plt.xlabel('x (µm)')
plt.ylabel('z (µm)')
plt.title('Total Electric Field Magnitude |E| (slice at y=0)')
plt.tight_layout()
plt.show()
# Out:
# Flux through top: 16.750816
# Flux through bottom: -269.148455
# Flux through left: 4.600653
# Flux through right: -4.600699
# Flux through front: 4.502780
# Flux through back: -4.502767
