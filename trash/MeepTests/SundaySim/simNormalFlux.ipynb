# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
import json
import os

keyword = "Normal"
path = "SurfaceData/surfaceParams" + keyword + ".json"
def load_params(path = path):
    with open(path, "r") as f:
        return json.load(f)
params = load_params()

# Cell and resolution
pml_thickness = params["pml_thickness"]
monitor_size = params["monitor_size"]
half_x = params["halfWidth_x"]
half_y = params["halfWidth_y"]
half_z = params["halfWidth_z"]
cell_size = mp.Vector3(2*half_x + 2*pml_thickness,
                       2*half_y + 2*pml_thickness,
                       2*half_z + 2*pml_thickness)

omega = params["omega"]
betas = params["betas"]
# Material
epsilon1 = params["epsilon1"] 
substrate = mp.Medium(epsilon = epsilon1)
bumps = params["bumpData"]

## Must be at least 8 pixels per smallest wavelength, i.e. np.floor(8/wvl_min)
resolution = params["resolution"]

frq = params["omega"]/(2*np.pi)
wvl = 1 / frq

pml_layers = [mp.PML(thickness=pml_thickness)] 

def make_source(component):
    return [mp.Source(
        mp.GaussianSource(frequency=frq, fwidth=1, is_integrated=True),
        center=mp.Vector3(0, 0, half_z - 0.5),
        size=mp.Vector3(cell_size[0], cell_size[1], 0),
        component=component
    )]

def run_meep_simulation(sources):
    # Reference simulation (no bumps)
    sim = mp.Simulation(
        resolution=resolution,
        cell_size=cell_size,
        boundary_layers=pml_layers,
        sources=sources,
        k_point=mp.Vector3(),
    )

    box1_x1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(x=-monitor_size/2), size=mp.Vector3(0, monitor_size, monitor_size)))
    box1_x2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(x=+monitor_size/2), size=mp.Vector3(0, monitor_size, monitor_size)))
    box1_y1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(y=-monitor_size/2), size=mp.Vector3(monitor_size, 0, monitor_size)))
    box1_y2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(y=+monitor_size/2), size=mp.Vector3(monitor_size, 0, monitor_size)))
    box1_z1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(z=-monitor_size/2), size=mp.Vector3(monitor_size, monitor_size, 0)))
    box1_z2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(z=+monitor_size/2), size=mp.Vector3(monitor_size, monitor_size, 0)))


    sim.run(until_after_sources=60)

    box_x1 = mp.get_fluxes(box1_x1)
    box_x2 = mp.get_fluxes(box1_x2)
    box_y1 = mp.get_fluxes(box1_y1)
    box_y2 = mp.get_fluxes(box1_y2)
    box_z1 = mp.get_fluxes(box1_z1)
    box_z2 = mp.get_fluxes(box1_z2)

    # Save individual components for later printing/plotting
    inc_flux_components = {
        "X1": np.asarray(box_x1)[0],
        "X2": np.asarray(box_x2)[0],
        "Y1": np.asarray(box_y1)[0],
        "Y2": np.asarray(box_y2)[0],
        "Z1": np.asarray(box_z1)[0],
        "Z2": np.asarray(box_z2)[0],
    }

    box_x1_data = sim.get_flux_data(box1_x1)
    box_x2_data = sim.get_flux_data(box1_x2)
    box_y1_data = sim.get_flux_data(box1_y1)
    box_y2_data = sim.get_flux_data(box1_y2)
    box_z1_data = sim.get_flux_data(box1_z1)
    box_z2_data = sim.get_flux_data(box1_z2)

    sim.reset_meep()

    # Structured simulation (with bumps)
    def material_function(p):
        z_surface = sum(
            b["height"] * np.exp(-((p.x - b["x0"])**2 + (p.y - b["y0"])**2) / (2 * b["sigma"]**2))
            for b in bumps
        )
        return substrate if p.z + 1.5 < z_surface else mp.air

    sim = mp.Simulation(
        resolution=resolution,
        cell_size=cell_size,
        boundary_layers=pml_layers,
        sources=sources,
        k_point=mp.Vector3(),
        default_material=material_function,
    )

    box2_x1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(x=-monitor_size/2), size=mp.Vector3(0, monitor_size, monitor_size)))
    box2_x2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(x=+monitor_size/2), size=mp.Vector3(0, monitor_size, monitor_size)))
    box2_y1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(y=-monitor_size/2), size=mp.Vector3(monitor_size, 0, monitor_size)))
    box2_y2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(y=+monitor_size/2), size=mp.Vector3(monitor_size, 0, monitor_size)))
    box2_z1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(z=-monitor_size/2), size=mp.Vector3(monitor_size, monitor_size, 0)))
    box2_z2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(z=+monitor_size/2), size=mp.Vector3(monitor_size, monitor_size, 0)))

    sim.load_minus_flux_data(box2_x1, box_x1_data)
    sim.load_minus_flux_data(box2_x2, box_x2_data)
    sim.load_minus_flux_data(box2_y1, box_y1_data)
    sim.load_minus_flux_data(box2_y2, box_y2_data)
    sim.load_minus_flux_data(box2_z1, box_z1_data)
    sim.load_minus_flux_data(box2_z2, box_z2_data)

    sim.run(until_after_sources=60) # maybe 20 is too little? 

    box_x1_flux = mp.get_fluxes(box2_x1)
    box_x2_flux = mp.get_fluxes(box2_x2)
    box_y1_flux = mp.get_fluxes(box2_y1)
    box_y2_flux = mp.get_fluxes(box2_y2)
    box_z1_flux = mp.get_fluxes(box2_z1)
    box_z2_flux = mp.get_fluxes(box2_z2)

    # Save individual components for later printing/plotting
    scatt_flux_components = {
        "X1": np.asarray(box_x1_flux)[0],
        "X2": np.asarray(box_x2_flux)[0],
        "Y1": np.asarray(box_y1_flux)[0],
        "Y2": np.asarray(box_y2_flux)[0],
        "Z1": np.asarray(box_z1_flux)[0],
        "Z2": np.asarray(box_z2_flux)[0],
    }
    return scatt_flux_components, inc_flux_components

flux_results = []
inc_flux_results = []

def print_parameters():
    print("Simulation Parameters:")
    print(f"  omega      = {omega}")
    print(f"  frequency  = {frq}")
    print(f"  wavelength = {wvl}")
    print(f"  resolution = {resolution}")
    print(f"  cell_size  = ({cell_size.x}, {cell_size.y}, {cell_size.z})")
    print(f"  PML thickness = {pml_thickness}")
    print(f"  monitor size  = {monitor_size}")
    print(f"  substrate ε   = {epsilon1}")
    print(f"  number of bumps = {len(bumps)}")
    print("  betas (deg)    =", [round(np.degrees(b), 2) for b in betas])
    print()

print_parameters()


for beta in betas:
    print("beta = " + str(beta))
    cos2 = np.cos(beta)**2
    sin2 = np.sin(beta)**2

    sources_1 = make_source(mp.Ey)
    sources_2 = make_source(mp.Ex)
    
    flux_1, inc_flux_1 = run_meep_simulation(sources_1)
    flux_2, inc_flux_2 = run_meep_simulation(sources_2)

    # Combine flux components manually
    flux_combined = {
        "beta": np.degrees(beta),
        "X1": cos2 * flux_1["X1"] + sin2 * flux_2["X1"],
        "X2": cos2 * flux_1["X2"] + sin2 * flux_2["X2"],
        "Y1": cos2 * flux_1["Y1"] + sin2 * flux_2["Y1"],
        "Y2": cos2 * flux_1["Y2"] + sin2 * flux_2["Y2"],
        "Z1": cos2 * flux_1["Z1"] + sin2 * flux_2["Z1"],
        "Z2": cos2 * flux_1["Z2"] + sin2 * flux_2["Z2"],
    }
    
    flux_results.append(flux_combined)
    
    # Combine flux components manually
    inc_flux_combined = {
        "beta": np.degrees(beta),
        "X1": cos2 * inc_flux_1["X1"] + sin2 * inc_flux_2["X1"],
        "X2": cos2 * inc_flux_1["X2"] + sin2 * inc_flux_2["X2"],
        "Y1": cos2 * inc_flux_1["Y1"] + sin2 * inc_flux_2["Y1"],
        "Y2": cos2 * inc_flux_1["Y2"] + sin2 * inc_flux_2["Y2"],
        "Z1": cos2 * inc_flux_1["Z1"] + sin2 * inc_flux_2["Z1"],
        "Z2": cos2 * inc_flux_1["Z2"] + sin2 * inc_flux_2["Z2"],
    }

    inc_flux_results.append(inc_flux_combined)
# Out:
# Simulation Parameters:
#   omega      = 1.0
#   frequency  = 0.15915494309189535
#   wavelength = 6.283185307179586
#   resolution = 10
#   cell_size  = (6.0, 6.0, 8.0)
#   PML thickness = 2
#   monitor size  = 1
#   substrate ε   = 2.56
#   number of bumps = 3
#   betas (deg)    = [0.0, 15.0, 30.0, 45.0, 60.0, 75.0, 90.0]
#
# beta = 0.0
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000320911 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.728189 s
# -----------
# Meep progress: 8.25/70.0 = 11.8% done in 4.0s, 30.0s to go
# on time step 165 (time=8.25), 0.0242921 s/step
# Meep progress: 20.8/70.0 = 29.7% done in 8.0s, 19.0s to go
# on time step 416 (time=20.8), 0.0159684 s/step
# Meep progress: 33.2/70.0 = 47.4% done in 12.0s, 13.3s to go
# on time step 664 (time=33.2), 0.0161556 s/step
# Meep progress: 45.900000000000006/70.0 = 65.6% done in 16.0s, 8.4s to go
# on time step 918 (time=45.9), 0.0157891 s/step
# Meep progress: 58.7/70.0 = 83.9% done in 20.0s, 3.9s to go
# on time step 1174 (time=58.7), 0.0156633 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000304937 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 14.4257 s
# -----------
# Meep progress: 8.75/70.0 = 12.5% done in 4.0s, 28.0s to go
# on time step 175 (time=8.75), 0.0228829 s/step
# Meep progress: 20.75/70.0 = 29.6% done in 8.0s, 19.0s to go
# on time step 416 (time=20.8), 0.0166657 s/step
# Meep progress: 33.0/70.0 = 47.1% done in 12.0s, 13.5s to go
# on time step 661 (time=33.05), 0.0163524 s/step
# Meep progress: 45.45/70.0 = 64.9% done in 16.0s, 8.7s to go
# on time step 910 (time=45.5), 0.0160891 s/step
# Meep progress: 57.5/70.0 = 82.1% done in 20.0s, 4.4s to go
# on time step 1151 (time=57.55), 0.0166518 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000359058 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.53408 s
# -----------
# Meep progress: 8.35/70.0 = 11.9% done in 4.0s, 29.6s to go
# on time step 167 (time=8.35), 0.0239808 s/step
# Meep progress: 18.1/70.0 = 25.9% done in 8.0s, 23.0s to go
# on time step 363 (time=18.15), 0.0205092 s/step
# Meep progress: 26.6/70.0 = 38.0% done in 12.0s, 19.6s to go
# on time step 533 (time=26.65), 0.0236123 s/step
# Meep progress: 38.300000000000004/70.0 = 54.7% done in 16.0s, 13.3s to go
# on time step 767 (time=38.35), 0.0171392 s/step
# Meep progress: 50.75/70.0 = 72.5% done in 20.1s, 7.6s to go
# on time step 1016 (time=50.8), 0.0161347 s/step
# Meep progress: 61.550000000000004/70.0 = 87.9% done in 24.1s, 3.3s to go
# on time step 1232 (time=61.6), 0.0185476 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000296831 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 15.1903 s
# -----------
# Meep progress: 8.1/70.0 = 11.6% done in 4.0s, 30.6s to go
# on time step 162 (time=8.1), 0.024716 s/step
# Meep progress: 20.450000000000003/70.0 = 29.2% done in 8.0s, 19.4s to go
# on time step 409 (time=20.45), 0.0161984 s/step
# Meep progress: 32.75/70.0 = 46.8% done in 12.0s, 13.7s to go
# on time step 655 (time=32.75), 0.0162793 s/step
# Meep progress: 44.95/70.0 = 64.2% done in 16.0s, 8.9s to go
# on time step 899 (time=44.95), 0.016396 s/step
# Meep progress: 57.25/70.0 = 81.8% done in 20.0s, 4.5s to go
# on time step 1145 (time=57.25), 0.0162784 s/step
# Meep progress: 69.45/70.0 = 99.2% done in 24.0s, 0.2s to go
# on time step 1389 (time=69.45), 0.0164275 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 0.2617993877991494
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000437021 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.535262 s
# -----------
# Meep progress: 8.8/70.0 = 12.6% done in 4.0s, 27.9s to go
# on time step 176 (time=8.8), 0.0228099 s/step
# Meep progress: 21.950000000000003/70.0 = 31.4% done in 8.0s, 17.6s to go
# on time step 439 (time=21.95), 0.0152299 s/step
# Meep progress: 34.800000000000004/70.0 = 49.7% done in 12.0s, 12.2s to go
# on time step 696 (time=34.8), 0.0155904 s/step
# Meep progress: 47.95/70.0 = 68.5% done in 16.0s, 7.4s to go
# on time step 959 (time=47.95), 0.0152596 s/step
# Meep progress: 60.25/70.0 = 86.1% done in 20.1s, 3.2s to go
# on time step 1205 (time=60.25), 0.0163281 s/step
# Meep progress: 69.45/70.0 = 99.2% done in 24.1s, 0.2s to go
# on time step 1389 (time=69.45), 0.0218399 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000597 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 16.0969 s
# -----------
# Meep progress: 8.4/70.0 = 12.0% done in 4.0s, 29.4s to go
# on time step 168 (time=8.4), 0.0238969 s/step
# Meep progress: 20.75/70.0 = 29.6% done in 8.0s, 19.0s to go
# on time step 415 (time=20.75), 0.0162118 s/step
# Meep progress: 33.7/70.0 = 48.1% done in 12.0s, 13.0s to go
# on time step 674 (time=33.7), 0.0154928 s/step
# Meep progress: 46.45/70.0 = 66.4% done in 16.0s, 8.1s to go
# on time step 929 (time=46.45), 0.0156888 s/step
# Meep progress: 59.45/70.0 = 84.9% done in 20.0s, 3.6s to go
# on time step 1189 (time=59.45), 0.0154184 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000505924 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.488327 s
# -----------
# Meep progress: 8.65/70.0 = 12.4% done in 4.0s, 28.5s to go
# on time step 173 (time=8.65), 0.0231891 s/step
# Meep progress: 21.0/70.0 = 30.0% done in 8.0s, 18.7s to go
# on time step 420 (time=21), 0.0162087 s/step
# Meep progress: 33.6/70.0 = 48.0% done in 12.0s, 13.0s to go
# on time step 672 (time=33.6), 0.0158938 s/step
# Meep progress: 46.150000000000006/70.0 = 65.9% done in 16.0s, 8.3s to go
# on time step 923 (time=46.15), 0.0159647 s/step
# Meep progress: 58.75/70.0 = 83.9% done in 20.0s, 3.8s to go
# on time step 1175 (time=58.75), 0.0158902 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000316858 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 14.3954 s
# -----------
# Meep progress: 8.8/70.0 = 12.6% done in 4.0s, 27.9s to go
# on time step 176 (time=8.8), 0.022786 s/step
# Meep progress: 20.650000000000002/70.0 = 29.5% done in 8.0s, 19.1s to go
# on time step 413 (time=20.65), 0.0168781 s/step
# Meep progress: 32.95/70.0 = 47.1% done in 12.0s, 13.5s to go
# on time step 659 (time=32.95), 0.0162963 s/step
# Meep progress: 45.45/70.0 = 64.9% done in 16.0s, 8.7s to go
# on time step 909 (time=45.45), 0.0160586 s/step
# Meep progress: 58.0/70.0 = 82.9% done in 20.0s, 4.1s to go
# on time step 1160 (time=58), 0.0159815 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 0.5235987755982988
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000437975 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.50807 s
# -----------
# Meep progress: 9.3/70.0 = 13.3% done in 4.0s, 26.2s to go
# on time step 186 (time=9.3), 0.0215624 s/step
# Meep progress: 21.450000000000003/70.0 = 30.6% done in 8.0s, 18.2s to go
# on time step 429 (time=21.45), 0.0164986 s/step
# Meep progress: 32.95/70.0 = 47.1% done in 12.0s, 13.5s to go
# on time step 659 (time=32.95), 0.0174015 s/step
# Meep progress: 45.0/70.0 = 64.3% done in 16.0s, 8.9s to go
# on time step 900 (time=45), 0.0166289 s/step
# Meep progress: 57.800000000000004/70.0 = 82.6% done in 20.0s, 4.2s to go
# on time step 1156 (time=57.8), 0.0156341 s/step
# Meep progress: 69.4/70.0 = 99.1% done in 24.0s, 0.2s to go
# on time step 1388 (time=69.4), 0.0172629 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000356197 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 16.4923 s
# -----------
# Meep progress: 7.8500000000000005/70.0 = 11.2% done in 4.0s, 31.7s to go
# on time step 157 (time=7.85), 0.0255257 s/step
# Meep progress: 19.25/70.0 = 27.5% done in 8.0s, 21.1s to go
# on time step 385 (time=19.25), 0.0175442 s/step
# Meep progress: 29.25/70.0 = 41.8% done in 12.0s, 16.7s to go
# on time step 585 (time=29.25), 0.0200418 s/step
# Meep progress: 38.5/70.0 = 55.0% done in 16.0s, 13.1s to go
# on time step 770 (time=38.5), 0.021686 s/step
# Meep progress: 47.25/70.0 = 67.5% done in 20.0s, 9.6s to go
# on time step 945 (time=47.25), 0.0228635 s/step
# Meep progress: 57.1/70.0 = 81.6% done in 24.0s, 5.4s to go
# on time step 1142 (time=57.1), 0.020313 s/step
# Meep progress: 65.8/70.0 = 94.0% done in 28.0s, 1.8s to go
# on time step 1316 (time=65.8), 0.0230203 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000398874 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.598361 s
# -----------
# Meep progress: 5.6000000000000005/70.0 = 8.0% done in 4.0s, 46.1s to go
# on time step 112 (time=5.6), 0.0357938 s/step
# Meep progress: 16.75/70.0 = 23.9% done in 8.0s, 25.5s to go
# on time step 336 (time=16.8), 0.017926 s/step
# Meep progress: 28.3/70.0 = 40.4% done in 12.0s, 17.7s to go
# on time step 567 (time=28.35), 0.0173319 s/step
# Meep progress: 39.5/70.0 = 56.4% done in 16.0s, 12.4s to go
# on time step 792 (time=39.6), 0.0178492 s/step
# Meep progress: 50.900000000000006/70.0 = 72.7% done in 20.0s, 7.5s to go
# on time step 1020 (time=51), 0.0175717 s/step
# Meep progress: 62.85/70.0 = 89.8% done in 24.0s, 2.7s to go
# on time step 1259 (time=62.95), 0.0167698 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000287056 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 15.0415 s
# -----------
# Meep progress: 8.15/70.0 = 11.6% done in 4.0s, 30.4s to go
# on time step 163 (time=8.15), 0.0246156 s/step
# Meep progress: 20.1/70.0 = 28.7% done in 8.0s, 19.9s to go
# on time step 402 (time=20.1), 0.0167745 s/step
# Meep progress: 32.4/70.0 = 46.3% done in 12.0s, 14.0s to go
# on time step 648 (time=32.4), 0.0163039 s/step
# Meep progress: 44.650000000000006/70.0 = 63.8% done in 16.0s, 9.1s to go
# on time step 893 (time=44.65), 0.0163665 s/step
# Meep progress: 56.75/70.0 = 81.1% done in 20.0s, 4.7s to go
# on time step 1135 (time=56.75), 0.0165481 s/step
# Meep progress: 69.15/70.0 = 98.8% done in 24.1s, 0.3s to go
# on time step 1383 (time=69.15), 0.0161868 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 0.7853981633974483
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000446081 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.48794 s
# -----------
# Meep progress: 8.15/70.0 = 11.6% done in 4.0s, 30.4s to go
# on time step 163 (time=8.15), 0.024564 s/step
# Meep progress: 20.35/70.0 = 29.1% done in 8.0s, 19.5s to go
# on time step 408 (time=20.4), 0.0163933 s/step
# Meep progress: 31.400000000000002/70.0 = 44.9% done in 12.0s, 14.8s to go
# on time step 629 (time=31.45), 0.0181534 s/step
# Meep progress: 43.45/70.0 = 62.1% done in 16.0s, 9.8s to go
# on time step 870 (time=43.5), 0.0165988 s/step
# Meep progress: 55.75/70.0 = 79.6% done in 20.0s, 5.1s to go
# on time step 1116 (time=55.8), 0.0162801 s/step
# Meep progress: 67.9/70.0 = 97.0% done in 24.0s, 0.7s to go
# on time step 1359 (time=67.95), 0.0164644 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00030303 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 14.9455 s
# -----------
# Meep progress: 8.3/70.0 = 11.9% done in 4.0s, 29.8s to go
# on time step 166 (time=8.3), 0.0241456 s/step
# Meep progress: 20.150000000000002/70.0 = 28.8% done in 8.0s, 19.8s to go
# on time step 403 (time=20.15), 0.0169088 s/step
# Meep progress: 32.0/70.0 = 45.7% done in 12.0s, 14.3s to go
# on time step 640 (time=32), 0.0169341 s/step
# Meep progress: 42.150000000000006/70.0 = 60.2% done in 16.0s, 10.6s to go
# on time step 843 (time=42.15), 0.0197293 s/step
# Meep progress: 52.150000000000006/70.0 = 74.5% done in 20.0s, 6.9s to go
# on time step 1043 (time=52.15), 0.0200059 s/step
# Meep progress: 62.1/70.0 = 88.7% done in 24.0s, 3.1s to go
# on time step 1242 (time=62.1), 0.0201478 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00049305 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.560767 s
# -----------
# Meep progress: 6.95/70.0 = 9.9% done in 4.0s, 36.3s to go
# on time step 139 (time=6.95), 0.028795 s/step
# Meep progress: 17.6/70.0 = 25.1% done in 8.0s, 23.8s to go
# on time step 352 (time=17.6), 0.0187797 s/step
# Meep progress: 29.5/70.0 = 42.1% done in 12.0s, 16.5s to go
# on time step 590 (time=29.5), 0.0168358 s/step
# Meep progress: 40.150000000000006/70.0 = 57.4% done in 16.0s, 11.9s to go
# on time step 803 (time=40.15), 0.0188112 s/step
# Meep progress: 50.400000000000006/70.0 = 72.0% done in 20.0s, 7.8s to go
# on time step 1008 (time=50.4), 0.019541 s/step
# Meep progress: 59.45/70.0 = 84.9% done in 24.0s, 4.3s to go
# on time step 1190 (time=59.5), 0.0220787 s/step
# Meep progress: 65.85000000000001/70.0 = 94.1% done in 28.1s, 1.8s to go
# on time step 1317 (time=65.85), 0.0318261 s/step
# Meep progress: 69.05/70.0 = 98.6% done in 32.1s, 0.4s to go
# on time step 1382 (time=69.1), 0.0623165 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00104284 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 21.2802 s
# -----------
# Meep progress: 7.5/70.0 = 10.7% done in 4.0s, 33.4s to go
# on time step 150 (time=7.5), 0.0267444 s/step
# Meep progress: 19.5/70.0 = 27.9% done in 8.0s, 20.8s to go
# on time step 390 (time=19.5), 0.0167154 s/step
# Meep progress: 29.700000000000003/70.0 = 42.4% done in 12.0s, 16.3s to go
# on time step 595 (time=29.75), 0.0195931 s/step
# Meep progress: 39.5/70.0 = 56.4% done in 16.0s, 12.4s to go
# on time step 791 (time=39.55), 0.0204257 s/step
# Meep progress: 49.7/70.0 = 71.0% done in 20.0s, 8.2s to go
# on time step 995 (time=49.75), 0.0196587 s/step
# Meep progress: 57.400000000000006/70.0 = 82.0% done in 24.1s, 5.3s to go
# on time step 1149 (time=57.45), 0.0261909 s/step
# Meep progress: 67.55/70.0 = 96.5% done in 28.1s, 1.0s to go
# on time step 1352 (time=67.6), 0.0197157 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 1.0471975511965976
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000348091 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.615285 s
# -----------
# Meep progress: 6.6000000000000005/70.0 = 9.4% done in 4.0s, 38.6s to go
# on time step 132 (time=6.6), 0.0304157 s/step
# Meep progress: 16.25/70.0 = 23.2% done in 8.0s, 26.5s to go
# on time step 325 (time=16.25), 0.020779 s/step
# Meep progress: 27.05/70.0 = 38.6% done in 12.0s, 19.1s to go
# on time step 541 (time=27.05), 0.0185359 s/step
# Meep progress: 38.800000000000004/70.0 = 55.4% done in 16.0s, 12.9s to go
# on time step 776 (time=38.8), 0.0170283 s/step
# Meep progress: 49.2/70.0 = 70.3% done in 20.0s, 8.5s to go
# on time step 984 (time=49.2), 0.0192809 s/step
# Meep progress: 59.35/70.0 = 84.8% done in 24.0s, 4.3s to go
# on time step 1188 (time=59.4), 0.0196877 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000953913 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 15.6183 s
# -----------
# Meep progress: 7.6000000000000005/70.0 = 10.9% done in 4.0s, 32.9s to go
# on time step 152 (time=7.6), 0.0263588 s/step
# Meep progress: 19.450000000000003/70.0 = 27.8% done in 8.0s, 20.8s to go
# on time step 389 (time=19.45), 0.0169353 s/step
# Meep progress: 31.650000000000002/70.0 = 45.2% done in 12.0s, 14.6s to go
# on time step 633 (time=31.65), 0.0164046 s/step
# Meep progress: 43.400000000000006/70.0 = 62.0% done in 16.0s, 9.8s to go
# on time step 868 (time=43.4), 0.0170551 s/step
# Meep progress: 54.650000000000006/70.0 = 78.1% done in 20.0s, 5.6s to go
# on time step 1094 (time=54.7), 0.0177624 s/step
# Meep progress: 66.60000000000001/70.0 = 95.1% done in 24.0s, 1.2s to go
# on time step 1333 (time=66.65), 0.0167636 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000367165 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.522136 s
# -----------
# Meep progress: 8.05/70.0 = 11.5% done in 4.0s, 30.9s to go
# on time step 161 (time=8.05), 0.0249057 s/step
# Meep progress: 19.75/70.0 = 28.2% done in 8.0s, 20.4s to go
# on time step 395 (time=19.75), 0.0171203 s/step
# Meep progress: 31.8/70.0 = 45.4% done in 12.0s, 14.4s to go
# on time step 636 (time=31.8), 0.0166417 s/step
# Meep progress: 43.6/70.0 = 62.3% done in 16.0s, 9.7s to go
# on time step 872 (time=43.6), 0.0169541 s/step
# Meep progress: 55.800000000000004/70.0 = 79.7% done in 20.0s, 5.1s to go
# on time step 1116 (time=55.8), 0.0164259 s/step
# Meep progress: 67.8/70.0 = 96.9% done in 24.0s, 0.8s to go
# on time step 1356 (time=67.8), 0.0166708 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000402212 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 15.5041 s
# -----------
# Meep progress: 8.55/70.0 = 12.2% done in 4.0s, 28.8s to go
# on time step 171 (time=8.55), 0.0234238 s/step
# Meep progress: 20.200000000000003/70.0 = 28.9% done in 8.0s, 19.8s to go
# on time step 404 (time=20.2), 0.0172237 s/step
# Meep progress: 32.550000000000004/70.0 = 46.5% done in 12.0s, 13.8s to go
# on time step 651 (time=32.55), 0.0162451 s/step
# Meep progress: 44.400000000000006/70.0 = 63.4% done in 16.0s, 9.3s to go
# on time step 888 (time=44.4), 0.0169192 s/step
# Meep progress: 57.45/70.0 = 82.1% done in 20.1s, 4.4s to go
# on time step 1149 (time=57.45), 0.0153871 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 1.308996938995747
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000264168 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.52376 s
# -----------
# Meep progress: 7.75/70.0 = 11.1% done in 4.0s, 32.2s to go
# on time step 155 (time=7.75), 0.0258955 s/step
# Meep progress: 19.0/70.0 = 27.1% done in 8.0s, 21.6s to go
# on time step 380 (time=19), 0.017845 s/step
# Meep progress: 31.0/70.0 = 44.3% done in 12.0s, 15.1s to go
# on time step 620 (time=31), 0.0166898 s/step
# Meep progress: 43.2/70.0 = 61.7% done in 16.0s, 9.9s to go
# on time step 864 (time=43.2), 0.016396 s/step
# Meep progress: 55.2/70.0 = 78.9% done in 20.0s, 5.4s to go
# on time step 1104 (time=55.2), 0.0166742 s/step
# Meep progress: 65.5/70.0 = 93.6% done in 24.1s, 1.7s to go
# on time step 1310 (time=65.5), 0.0194983 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000282049 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 18.5052 s
# -----------
# Meep progress: 6.25/70.0 = 8.9% done in 4.0s, 41.0s to go
# on time step 125 (time=6.25), 0.0321938 s/step
# Meep progress: 13.9/70.0 = 19.9% done in 8.0s, 32.5s to go
# on time step 278 (time=13.9), 0.0262416 s/step
# Meep progress: 18.6/70.0 = 26.6% done in 12.1s, 33.4s to go
# on time step 372 (time=18.6), 0.0429524 s/step
# Meep progress: 26.1/70.0 = 37.3% done in 16.1s, 27.1s to go
# on time step 522 (time=26.1), 0.026813 s/step
# Meep progress: 35.9/70.0 = 51.3% done in 20.1s, 19.1s to go
# on time step 719 (time=35.95), 0.0203834 s/step
# Meep progress: 48.150000000000006/70.0 = 68.8% done in 24.1s, 10.9s to go
# on time step 964 (time=48.2), 0.0163512 s/step
# Meep progress: 60.1/70.0 = 85.9% done in 28.1s, 4.6s to go
# on time step 1203 (time=60.15), 0.0167854 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000533819 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.728725 s
# -----------
# Meep progress: 5.95/70.0 = 8.5% done in 4.0s, 43.2s to go
# on time step 119 (time=5.95), 0.0337262 s/step
# Meep progress: 18.35/70.0 = 26.2% done in 8.0s, 22.6s to go
# on time step 367 (time=18.35), 0.016169 s/step
# Meep progress: 31.200000000000003/70.0 = 44.6% done in 12.0s, 15.0s to go
# on time step 624 (time=31.2), 0.0156091 s/step
# Meep progress: 43.800000000000004/70.0 = 62.6% done in 16.0s, 9.6s to go
# on time step 876 (time=43.8), 0.0158767 s/step
# Meep progress: 56.650000000000006/70.0 = 80.9% done in 20.0s, 4.7s to go
# on time step 1133 (time=56.65), 0.0155754 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000303984 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 16.51 s
# -----------
# Meep progress: 8.0/70.0 = 11.4% done in 4.0s, 31.1s to go
# on time step 160 (time=8), 0.0250813 s/step
# Meep progress: 18.45/70.0 = 26.4% done in 8.0s, 22.4s to go
# on time step 369 (time=18.45), 0.0191749 s/step
# Meep progress: 30.85/70.0 = 44.1% done in 12.0s, 15.3s to go
# on time step 617 (time=30.85), 0.016157 s/step
# Meep progress: 42.900000000000006/70.0 = 61.3% done in 16.0s, 10.1s to go
# on time step 858 (time=42.9), 0.0166133 s/step
# Meep progress: 53.650000000000006/70.0 = 76.6% done in 20.0s, 6.1s to go
# on time step 1073 (time=53.65), 0.0186368 s/step
# Meep progress: 65.85000000000001/70.0 = 94.1% done in 24.1s, 1.5s to go
# on time step 1317 (time=65.85), 0.0164269 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 1.5707963267948966
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000306129 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.524463 s
# -----------
# Meep progress: 7.5/70.0 = 10.7% done in 4.0s, 33.5s to go
# on time step 150 (time=7.5), 0.0267757 s/step
# Meep progress: 19.150000000000002/70.0 = 27.4% done in 8.0s, 21.3s to go
# on time step 384 (time=19.2), 0.0171667 s/step
# Meep progress: 30.8/70.0 = 44.0% done in 12.0s, 15.3s to go
# on time step 617 (time=30.85), 0.0171958 s/step
# Meep progress: 41.650000000000006/70.0 = 59.5% done in 16.0s, 10.9s to go
# on time step 835 (time=41.75), 0.0183913 s/step
# Meep progress: 53.900000000000006/70.0 = 77.0% done in 20.0s, 6.0s to go
# on time step 1079 (time=53.95), 0.0164348 s/step
# Meep progress: 66.55/70.0 = 95.1% done in 24.1s, 1.2s to go
# on time step 1333 (time=66.65), 0.015797 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000311852 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 15.3095 s
# -----------
# Meep progress: 5.7/70.0 = 8.1% done in 4.0s, 45.3s to go
# on time step 114 (time=5.7), 0.0352056 s/step
# Meep progress: 18.400000000000002/70.0 = 26.3% done in 8.0s, 22.5s to go
# on time step 368 (time=18.4), 0.0157908 s/step
# Meep progress: 30.6/70.0 = 43.7% done in 12.0s, 15.5s to go
# on time step 612 (time=30.6), 0.0163982 s/step
# Meep progress: 42.6/70.0 = 60.9% done in 16.0s, 10.3s to go
# on time step 852 (time=42.6), 0.0167398 s/step
# Meep progress: 52.5/70.0 = 75.0% done in 20.1s, 6.7s to go
# on time step 1050 (time=52.5), 0.0202634 s/step
# Meep progress: 64.05/70.0 = 91.5% done in 24.1s, 2.2s to go
# on time step 1281 (time=64.05), 0.0173529 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00037384 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.511721 s
# -----------
# Meep progress: 8.450000000000001/70.0 = 12.1% done in 4.0s, 29.2s to go
# on time step 169 (time=8.45), 0.0236833 s/step
# Meep progress: 22.35/70.0 = 31.9% done in 8.0s, 17.1s to go
# on time step 447 (time=22.35), 0.0144363 s/step
# Meep progress: 36.300000000000004/70.0 = 51.9% done in 12.0s, 11.2s to go
# on time step 726 (time=36.3), 0.0143563 s/step
# Meep progress: 50.25/70.0 = 71.8% done in 16.0s, 6.3s to go
# on time step 1005 (time=50.25), 0.0143599 s/step
# Meep progress: 64.2/70.0 = 91.7% done in 20.0s, 1.8s to go
# on time step 1284 (time=64.2), 0.0143634 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000468016 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 14.3826 s
# -----------
# Meep progress: 9.3/70.0 = 13.3% done in 4.0s, 26.1s to go
# on time step 186 (time=9.3), 0.0215305 s/step
# Meep progress: 22.85/70.0 = 32.6% done in 8.0s, 16.5s to go
# on time step 457 (time=22.85), 0.0147716 s/step
# Meep progress: 36.300000000000004/70.0 = 51.9% done in 12.0s, 11.2s to go
# on time step 726 (time=36.3), 0.0148775 s/step
# Meep progress: 49.900000000000006/70.0 = 71.3% done in 16.0s, 6.4s to go
# on time step 998 (time=49.9), 0.0147107 s/step
# Meep progress: 61.6/70.0 = 88.0% done in 20.0s, 2.7s to go
# on time step 1232 (time=61.6), 0.0171337 s/step
# run 0 finished at t = 70.0 (1400 timesteps)

# %%
d = flux_1
#d = flux_1
print("Size of dict:", len(d))
d
# Out:
# Size of dict: 6
# {'X1': 2.517478249013646e-05,
#  'X2': -4.923507200340001e-05,
#  'Y1': -3.4629734088580992e-06,
#  'Y2': -7.823180776755396e-06,
#  'Z1': 0.002156991009579839,
#  'Z2': 0.0022352765634445593}

# %%
from tabulate import tabulate

# Convert to scalar values if needed
def scalar(val):
    return val.item() if isinstance(val, np.ndarray) else val



table_data = [
    [f"{scalar(row['beta']):.1f}°",
     f"{scalar(row['X1']):.5f}",
     f"{scalar(row['X2']):.5f}",
     f"{scalar(row['Y1']):.5f}",
     f"{scalar(row['Y2']):.5f}",
     f"{scalar(row['Z1']):.5f}",
     f"{scalar(row['Z2']):.5f}"]
    for row in flux_results
]

headers = ["β (°)", "X1 (−x)", "X2 (+x)", "Y1 (−y)", "Y2 (+y)", "Z1 (−z)", "Z2 (+z)"]
print(tabulate(table_data, headers=headers, tablefmt="github"))
# Out:
# | β (°)   |   X1 (−x) |   X2 (+x) |   Y1 (−y) |   Y2 (+y) |   Z1 (−z) |   Z2 (+z) |
# |---------|-----------|-----------|-----------|-----------|-----------|-----------|
# | 0.0°    |     3e-05 |    -5e-05 |    -0     |    -1e-05 |   0.00216 |   0.00224 |
# | 15.0°   |     2e-05 |    -5e-05 |    -0     |    -1e-05 |   0.00216 |   0.00224 |
# | 30.0°   |     2e-05 |    -4e-05 |     1e-05 |    -0     |   0.00217 |   0.00224 |
# | 45.0°   |     1e-05 |    -2e-05 |     2e-05 |    -0     |   0.00219 |   0.00224 |
# | 60.0°   |     0     |    -1e-05 |     3e-05 |     0     |   0.0022  |   0.00224 |
# | 75.0°   |    -0     |    -0     |     4e-05 |     1e-05 |   0.00221 |   0.00224 |
# | 90.0°   |    -0     |     0     |     4e-05 |     1e-05 |   0.00221 |   0.00224 |

# %%
from tabulate import tabulate

# Convert to scalar values if needed
def scalar(val):
    return val.item() if isinstance(val, np.ndarray) else val



table_data = [
    [f"{scalar(row['beta']):.1f}°",
     f"{scalar(row['X1']):.15f}",
     f"{scalar(row['X2']):.15f}",
     f"{scalar(row['Y1']):.15f}",
     f"{scalar(row['Y2']):.15f}",
     f"{scalar(row['Z1']):.15f}",
     f"{scalar(row['Z2']):.15f}"]
    for row in inc_flux_results
]

headers = ["β (°)", "X1 (−x)", "X2 (+x)", "Y1 (−y)", "Y2 (+y)", "Z1 (−z)", "Z2 (+z)"]
print(tabulate(table_data, headers=headers, tablefmt="github"))
# Out:
# | β (°)   |   X1 (−x) |   X2 (+x) |   Y1 (−y) |   Y2 (+y) |    Z1 (−z) |    Z2 (+z) |
# |---------|-----------|-----------|-----------|-----------|------------|------------|
# | 0.0°    |        -0 |         0 |         0 |        -0 | -0.0467769 | -0.0467767 |
# | 15.0°   |        -0 |         0 |         0 |        -0 | -0.0467769 | -0.0467767 |
# | 30.0°   |        -0 |         0 |         0 |        -0 | -0.0467769 | -0.0467767 |
# | 45.0°   |         0 |         0 |         0 |        -0 | -0.0467769 | -0.0467767 |
# | 60.0°   |         0 |        -0 |        -0 |        -0 | -0.0467769 | -0.0467767 |
# | 75.0°   |         0 |        -0 |        -0 |         0 | -0.0467769 | -0.0467767 |
# | 90.0°   |         0 |        -0 |        -0 |         0 | -0.0467769 | -0.0467767 |

# %%
import numpy as np
import matplotlib.pyplot as plt

# Convert to scalar values if needed
def scalar(val):
    return val.item() if isinstance(val, np.ndarray) else val


# Extract data
betas = [scalar(entry['beta']) for entry in flux_results]
Z1 = [scalar(entry['Z1']) for entry in flux_results]
Z2 = [scalar(entry['Z2']) for entry in flux_results]
X1 = [scalar(entry['X1']) for entry in flux_results]
X2 = [scalar(entry['X2']) for entry in flux_results]
Y1 = [scalar(entry['Y1']) for entry in flux_results]
Y2 = [scalar(entry['Y2']) for entry in flux_results]


# Set up subplots
fig, axs = plt.subplots(3, 2, figsize=(12, 10))
axs = axs.flatten()

# Plot each component
labels = ['Z1 (−z)', 'Z2 (+z)', 'X1 (−x)', 'X2 (+x)', 'Y1 (−y)', 'Y2 (+y)']
values = [Z1, Z2, X1, X2, Y1, Y2]

for i, (label, val) in enumerate(zip(labels, values)):
    axs[i].plot(betas, val, marker='o')
    axs[i].set_title(label)
    axs[i].set_xlabel("β (degrees)")
    axs[i].set_ylabel("Flux")
    axs[i].grid(True)

# Hide unused subplot if any
if len(axs) > len(labels):
    axs[-1].axis('off')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Convert to scalar values if needed
def scalar(val):
    return val.item() if isinstance(val, np.ndarray) else val

# Extract data
betas = [scalar(entry['beta']) for entry in inc_flux_results]
Z1 = [scalar(entry['Z1']) for entry in inc_flux_results]
Z2 = [scalar(entry['Z2']) for entry in inc_flux_results]
X1 = [scalar(entry['X1']) for entry in inc_flux_results]
X2 = [scalar(entry['X2']) for entry in inc_flux_results]
Y1 = [scalar(entry['Y1']) for entry in inc_flux_results]
Y2 = [scalar(entry['Y2']) for entry in inc_flux_results]


# Set up subplots
fig, axs = plt.subplots(3, 2, figsize=(12, 10))
axs = axs.flatten()

# Plot each component
labels = ['Z1 (−z)', 'Z2 (+z)', 'X1 (−x)', 'X2 (+x)', 'Y1 (−y)', 'Y2 (+y)']
values = [Z1, Z2, X1, X2, Y1, Y2]

for i, (label, val) in enumerate(zip(labels, values)):
    axs[i].plot(betas, val, marker='o')
    axs[i].set_title(label)
    axs[i].set_xlabel("β (degrees)")
    axs[i].set_ylabel("Flux")
    axs[i].grid(True)

# Hide unused subplot if any
if len(axs) > len(labels):
    axs[-1].axis('off')

plt.tight_layout()
plt.show()
