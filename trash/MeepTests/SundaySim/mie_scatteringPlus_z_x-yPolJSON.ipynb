# %% [markdown]
# # Mie Scattering of a Lossless Dielectric Sphere
#
# A common reference calculation in computational electromagnetics for which an analytical solution is known is [Mie scattering](https://en.wikipedia.org/wiki/Mie_scattering) which involves computing the [scattering efficiency](http://www.thermopedia.com/content/956/) of a single, homogeneous sphere given an incident planewave. The scattered power of any object (absorbing or non) can be computed by surrounding it with a *closed* [DFT flux](https://meep.readthedocs.io/en/latest/Python_User_Interface/#flux-spectra) box (its size and orientation are irrelevant because of Poynting's theorem) and performing two simulations: (1) a normalization run involving an empty cell to save the incident fields from the source and (2) the scattering run with the object but first subtracting the incident fields in order to obtain just the scattered fields. This approach has already been described in [Transmittance Spectrum of a Waveguide Bend](https://meep.readthedocs.io/en/latest/Python_Tutorials/Basics#transmittance-spectrum-of-a-waveguide-bend).
#
# The scattering cross section is the scattered power in all directions divided by the incident intensity. The scattering efficiency, a dimensionless quantity, is the ratio of the scattering cross section to the cross sectional area of the sphere. In this demonstration, the sphere is a lossless dielectric with wavelength-independent refractive index of 2.0. This way, [subpixel smoothing](https://meep.readthedocs.io/en/latest/Subpixel_Smoothing) can improve accuracy at low resolutions which is important for reducing the size of this 3d simulation. The source is an $E_z$-polarized, planewave pulse (its `size` parameter fills the *entire* cell in 2d) spanning the broadband wavelength spectrum of 10% to 50% the circumference of the sphere. There is one subtlety: since the [planewave source extends into the PML](https://meep.readthedocs.io/en/latest/Perfectly_Matched_Layer/#planewave-sources-extending-into-pml) which surrounds the cell on all sides, `is_integrated=True` must be specified in the source object definition. A `k_point` of zero specifying periodic boundary conditions is necessary in order for the source to be infinitely extended. Also, given the [symmetry of the fields and the structure](https://meep.readthedocs.io/en/latest/Exploiting_Symmetry), two mirror symmery planes can be used to reduce the cell size by a factor of four. The simulation results are validated by comparing with the analytic theory obtained from the [PyMieScatt](https://pymiescatt.readthedocs.io/en/latest/) module (which you will have to install in order to run the script below).

# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
import json
import os

keyword = "Normal"
path = "SurfaceData/surfaceParams" + keyword + ".json"
def load_params(path = path):
    with open(path, "r") as f:
        return json.load(f)
params = load_params()

# Cell and resolution
pml_thickness = params["pml_thickness"]
monitor_size = params["monitor_size"]
half_x = params["halfWidth_x"]
half_y = params["halfWidth_y"]
half_z = params["halfWidth_z"]
cell_size = mp.Vector3(2*half_x + 2*pml_thickness,
                       2*half_y + 2*pml_thickness,
                       2*half_z + 2*pml_thickness)

omega = params["omega"]
betas = params["betas"]
# Material
epsilon1 = params["epsilon1"] 

substrate = mp.Medium(epsilon = epsilon1)
bumps = params["bumpData"]
#bumps = []

## Must be at least 8 pixels per smallest wavelength, i.e. np.floor(8/wvl_min)
resolution = params["resolution"]

frq = params["omega"]/(2*np.pi)
wvl = 1 / frq

pml_layers = [mp.PML(thickness=pml_thickness)] 

def make_source(component):
    return [mp.Source(
        mp.GaussianSource(frequency=frq, fwidth=1, is_integrated=True),
        center=mp.Vector3(0, 0, half_z - 0.5),
        size=mp.Vector3(cell_size[0], cell_size[1], 0),
        component=component
    )]

def run_meep_simulation(sources):
    # Reference simulation (no bumps)
    sim = mp.Simulation(
        resolution=resolution,
        cell_size=cell_size,
        boundary_layers=pml_layers,
        sources=sources,
        k_point=mp.Vector3(),
    )

    box_x1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(x=-monitor_size/2), size=mp.Vector3(0, monitor_size, monitor_size)))
    box_x2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(x=+monitor_size/2), size=mp.Vector3(0, monitor_size, monitor_size)))
    box_y1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(y=-monitor_size/2), size=mp.Vector3(monitor_size, 0, monitor_size)))
    box_y2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(y=+monitor_size/2), size=mp.Vector3(monitor_size, 0, monitor_size)))
    box_z1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(z=-monitor_size/2), size=mp.Vector3(monitor_size, monitor_size, 0)))
    box_z2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(z=+monitor_size/2), size=mp.Vector3(monitor_size, monitor_size, 0)))

    sim.run(until_after_sources=60)

    box_x1_data = sim.get_flux_data(box_x1)
    box_x2_data = sim.get_flux_data(box_x2)
    box_y1_data = sim.get_flux_data(box_y1)
    box_y2_data = sim.get_flux_data(box_y2)
    box_z1_data = sim.get_flux_data(box_z1)
    box_z2_data = sim.get_flux_data(box_z2)

    box_x1_flux0 = mp.get_fluxes(box_x1)
    sim.reset_meep()

    # Structured simulation (with bumps)
    def material_function(p):
        z_surface = sum(
            b["height"] * np.exp(-((p.x - b["x0"])**2 + (p.y - b["y0"])**2) / (2 * b["sigma"]**2))
            for b in bumps
        )
        return substrate if p.z + 1.5 < z_surface else mp.air

    sim = mp.Simulation(
        resolution=resolution,
        cell_size=cell_size,
        boundary_layers=pml_layers,
        sources=sources,
        k_point=mp.Vector3(),
        default_material=material_function,
    )

    box_x1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(x=-monitor_size/2), size=mp.Vector3(0, monitor_size, monitor_size)))
    box_x2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(x=+monitor_size/2), size=mp.Vector3(0, monitor_size, monitor_size)))
    box_y1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(y=-monitor_size/2), size=mp.Vector3(monitor_size, 0, monitor_size)))
    box_y2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(y=+monitor_size/2), size=mp.Vector3(monitor_size, 0, monitor_size)))
    box_z1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(z=-monitor_size/2), size=mp.Vector3(monitor_size, monitor_size, 0)))
    box_z2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(z=+monitor_size/2), size=mp.Vector3(monitor_size, monitor_size, 0)))

    sim.load_minus_flux_data(box_x1, box_x1_data)
    sim.load_minus_flux_data(box_x2, box_x2_data)
    sim.load_minus_flux_data(box_y1, box_y1_data)
    sim.load_minus_flux_data(box_y2, box_y2_data)
    sim.load_minus_flux_data(box_z1, box_z1_data)
    sim.load_minus_flux_data(box_z2, box_z2_data)

    sim.run(until_after_sources=60) # maybe 20 is too little? 

    box_x1_flux = mp.get_fluxes(box_x1)
    box_x2_flux = mp.get_fluxes(box_x2)
    box_y1_flux = mp.get_fluxes(box_y1)
    box_y2_flux = mp.get_fluxes(box_y2)
    box_z1_flux = mp.get_fluxes(box_z1)
    box_z2_flux = mp.get_fluxes(box_z2)

    scatt_flux = (
        np.asarray(box_x1_flux)
        - np.asarray(box_x2_flux)
        + np.asarray(box_y1_flux)
        - np.asarray(box_y2_flux)
        + np.asarray(box_z1_flux)
        - np.asarray(box_z2_flux)
    )
    # Normalize by incident flux density (assuming monitor area = monitor_size²)
    intensity = np.asarray(box_x1_flux0) / (monitor_size)**2
    scatt_cross_section = np.divide(scatt_flux, intensity)
    # Meep flux convention: power leaving the box is positive
    scatt_eff = scatt_cross_section * -1 / (np.pi * 1**2) # r=1

    # Save individual components for later printing/plotting
    scatt_flux_components = {
        "X1": np.asarray(box_x1_flux)[0],
        "X2": np.asarray(box_x2_flux)[0],
        "Y1": np.asarray(box_y1_flux)[0],
        "Y2": np.asarray(box_y2_flux)[0],
        "Z1": np.asarray(box_z1_flux)[0],
        "Z2": np.asarray(box_z2_flux)[0],
        "scatt_total": scatt_flux[0],
    }


    return scatt_eff, scatt_flux_components

scatt_eff_list = []
flux_results = []

def print_parameters():
    print("Simulation Parameters:")
    print(f"  omega      = {omega}")
    print(f"  frequency  = {frq}")
    print(f"  wavelength = {wvl}")
    print(f"  resolution = {resolution}")
    print(f"  cell_size  = ({cell_size.x}, {cell_size.y}, {cell_size.z})")
    print(f"  PML thickness = {pml_thickness}")
    print(f"  monitor size  = {monitor_size}")
    print(f"  substrate ε   = {epsilon1}")
    print(f"  number of bumps = {len(bumps)}")
    print("  betas (deg)    =", [round(np.degrees(b), 2) for b in betas])
    print()

print_parameters()

for beta in betas:
    print("beta = " + str(beta))
    cos2 = np.cos(beta)**2
    sin2 = np.sin(beta)**2

    sources_1 = make_source(mp.Ey)
    sources_2 = make_source(mp.Ex)
    

    Qy, flux_1 = run_meep_simulation(sources_1)
    Qx, flux_2 = run_meep_simulation(sources_2)
    

    Q_beta = cos2 * Qx + sin2 * Qy
    scatt_eff_list.append(Q_beta)

    # Combine flux components manually
    flux_combined = {
        "beta": np.degrees(beta),
        "X1": cos2 * flux_1["X1"] + sin2 * flux_2["X1"],
        "X2": cos2 * flux_1["X2"] + sin2 * flux_2["X2"],
        "Y1": cos2 * flux_1["Y1"] + sin2 * flux_2["Y1"],
        "Y2": cos2 * flux_1["Y2"] + sin2 * flux_2["Y2"],
        "Z1": cos2 * flux_1["Z1"] + sin2 * flux_2["Z1"],
        "Z2": cos2 * flux_1["Z2"] + sin2 * flux_2["Z2"],
    }

    flux_results.append(flux_combined)
# Out:
# Simulation Parameters:
#   omega      = 1.0
#   frequency  = 0.15915494309189535
#   wavelength = 6.283185307179586
#   resolution = 10
#   cell_size  = (6.0, 6.0, 8.0)
#   PML thickness = 2
#   monitor size  = 1
#   substrate ε   = 2.56
#   number of bumps = 0
#   betas (deg)    = [0.0, 15.0, 30.0, 45.0, 60.0, 75.0, 90.0]
#
# beta = 0.0
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00286603 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.471158 s
# -----------
# Meep progress: 6.6000000000000005/70.0 = 9.4% done in 4.0s, 38.5s to go
# on time step 132 (time=6.6), 0.0303549 s/step
# Meep progress: 19.05/70.0 = 27.2% done in 8.0s, 21.4s to go
# on time step 381 (time=19.05), 0.0160947 s/step
# Meep progress: 31.75/70.0 = 45.4% done in 12.0s, 14.5s to go
# on time step 635 (time=31.75), 0.0157642 s/step
# Meep progress: 49.400000000000006/70.0 = 70.6% done in 16.0s, 6.7s to go
# on time step 988 (time=49.4), 0.0113524 s/step
# Meep progress: 62.35/70.0 = 89.1% done in 20.0s, 2.5s to go
# on time step 1248 (time=62.4), 0.0154412 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000339985 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 5.77612 s
# -----------
# Meep progress: 8.8/70.0 = 12.6% done in 4.0s, 27.8s to go
# on time step 176 (time=8.8), 0.0227319 s/step
# Meep progress: 21.400000000000002/70.0 = 30.6% done in 8.0s, 18.2s to go
# on time step 428 (time=21.4), 0.0158794 s/step
# Meep progress: 32.95/70.0 = 47.1% done in 12.0s, 13.5s to go
# on time step 659 (time=32.95), 0.0173471 s/step
# Meep progress: 44.900000000000006/70.0 = 64.1% done in 16.0s, 9.0s to go
# on time step 898 (time=44.9), 0.0167458 s/step
# Meep progress: 61.400000000000006/70.0 = 87.7% done in 20.0s, 2.8s to go
# on time step 1228 (time=61.4), 0.0121669 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000324011 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.549449 s
# -----------
# Meep progress: 8.35/70.0 = 11.9% done in 4.0s, 29.5s to go
# on time step 167 (time=8.35), 0.0239576 s/step
# Meep progress: 20.650000000000002/70.0 = 29.5% done in 8.0s, 19.2s to go
# on time step 413 (time=20.65), 0.0163206 s/step
# Meep progress: 31.8/70.0 = 45.4% done in 12.0s, 14.4s to go
# on time step 636 (time=31.8), 0.017979 s/step
# Meep progress: 43.050000000000004/70.0 = 61.5% done in 16.0s, 10.0s to go
# on time step 861 (time=43.05), 0.01784 s/step
# Meep progress: 54.95/70.0 = 78.5% done in 20.0s, 5.5s to go
# on time step 1099 (time=54.95), 0.0168146 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000354052 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 6.94197 s
# -----------
# Meep progress: 8.0/70.0 = 11.4% done in 4.0s, 31.0s to go
# on time step 160 (time=8), 0.0250111 s/step
# Meep progress: 19.35/70.0 = 27.6% done in 8.0s, 21.0s to go
# on time step 387 (time=19.35), 0.0176291 s/step
# Meep progress: 31.3/70.0 = 44.7% done in 12.0s, 14.9s to go
# on time step 626 (time=31.3), 0.0168128 s/step
# Meep progress: 42.900000000000006/70.0 = 61.3% done in 16.0s, 10.1s to go
# on time step 858 (time=42.9), 0.0172604 s/step
# Meep progress: 54.75/70.0 = 78.2% done in 20.0s, 5.6s to go
# on time step 1095 (time=54.75), 0.0169014 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 0.2617993877991494
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000371218 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.580541 s
# -----------
# Meep progress: 8.25/70.0 = 11.8% done in 4.0s, 30.0s to go
# on time step 165 (time=8.25), 0.0242759 s/step
# Meep progress: 20.55/70.0 = 29.4% done in 8.0s, 19.3s to go
# on time step 411 (time=20.55), 0.0163224 s/step
# Meep progress: 32.5/70.0 = 46.4% done in 12.0s, 13.9s to go
# on time step 650 (time=32.5), 0.0168067 s/step
# Meep progress: 44.400000000000006/70.0 = 63.4% done in 16.0s, 9.2s to go
# on time step 888 (time=44.4), 0.0168069 s/step
# Meep progress: 56.5/70.0 = 80.7% done in 20.0s, 4.8s to go
# on time step 1130 (time=56.5), 0.0165406 s/step
# Meep progress: 68.3/70.0 = 97.6% done in 24.0s, 0.6s to go
# on time step 1366 (time=68.3), 0.0169591 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00041604 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 5.32655 s
# -----------
# Meep progress: 8.0/70.0 = 11.4% done in 4.0s, 31.0s to go
# on time step 160 (time=8), 0.0250235 s/step
# Meep progress: 19.900000000000002/70.0 = 28.4% done in 8.0s, 20.2s to go
# on time step 398 (time=19.9), 0.0168377 s/step
# Meep progress: 31.6/70.0 = 45.1% done in 12.0s, 14.6s to go
# on time step 632 (time=31.6), 0.0171198 s/step
# Meep progress: 43.650000000000006/70.0 = 62.4% done in 16.0s, 9.7s to go
# on time step 873 (time=43.65), 0.0166152 s/step
# Meep progress: 55.2/70.0 = 78.9% done in 20.0s, 5.4s to go
# on time step 1104 (time=55.2), 0.0173504 s/step
# Meep progress: 67.05/70.0 = 95.8% done in 24.0s, 1.1s to go
# on time step 1341 (time=67.05), 0.0168902 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000380039 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.51558 s
# -----------
# Meep progress: 7.7/70.0 = 11.0% done in 4.0s, 32.5s to go
# on time step 154 (time=7.7), 0.0260608 s/step
# Meep progress: 23.75/70.0 = 33.9% done in 8.0s, 15.6s to go
# on time step 475 (time=23.75), 0.0124777 s/step
# Meep progress: 35.45/70.0 = 50.6% done in 12.0s, 11.7s to go
# on time step 709 (time=35.45), 0.0171169 s/step
# Meep progress: 46.95/70.0 = 67.1% done in 16.0s, 7.9s to go
# on time step 939 (time=46.95), 0.0174131 s/step
# Meep progress: 58.6/70.0 = 83.7% done in 20.0s, 3.9s to go
# on time step 1172 (time=58.6), 0.0171678 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000554085 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 6.93716 s
# -----------
# Meep progress: 7.6000000000000005/70.0 = 10.9% done in 4.0s, 32.9s to go
# on time step 152 (time=7.6), 0.0263457 s/step
# Meep progress: 21.75/70.0 = 31.1% done in 8.0s, 17.8s to go
# on time step 435 (time=21.75), 0.014152 s/step
# Meep progress: 32.15/70.0 = 45.9% done in 12.0s, 14.1s to go
# on time step 643 (time=32.15), 0.0192394 s/step
# Meep progress: 43.35/70.0 = 61.9% done in 16.0s, 9.8s to go
# on time step 867 (time=43.35), 0.0178736 s/step
# Meep progress: 54.75/70.0 = 78.2% done in 20.0s, 5.6s to go
# on time step 1096 (time=54.8), 0.0175653 s/step
# Meep progress: 66.0/70.0 = 94.3% done in 24.0s, 1.5s to go
# on time step 1322 (time=66.1), 0.0177702 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 0.5235987755982988
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000472784 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.532481 s
# -----------
# Meep progress: 7.800000000000001/70.0 = 11.1% done in 4.0s, 32.0s to go
# on time step 156 (time=7.8), 0.0257202 s/step
# Meep progress: 19.8/70.0 = 28.3% done in 8.0s, 20.3s to go
# on time step 396 (time=19.8), 0.0166932 s/step
# Meep progress: 35.9/70.0 = 51.3% done in 12.0s, 11.4s to go
# on time step 718 (time=35.9), 0.0124436 s/step
# Meep progress: 47.85/70.0 = 68.4% done in 16.0s, 7.4s to go
# on time step 957 (time=47.85), 0.0167551 s/step
# Meep progress: 59.5/70.0 = 85.0% done in 20.0s, 3.5s to go
# on time step 1190 (time=59.5), 0.0171686 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000422001 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 8.43594 s
# -----------
# Meep progress: 8.1/70.0 = 11.6% done in 4.0s, 30.7s to go
# on time step 162 (time=8.1), 0.0247919 s/step
# Meep progress: 19.85/70.0 = 28.4% done in 8.0s, 20.3s to go
# on time step 397 (time=19.85), 0.0170334 s/step
# Meep progress: 35.75/70.0 = 51.1% done in 12.0s, 11.5s to go
# on time step 715 (time=35.75), 0.0126074 s/step
# Meep progress: 47.800000000000004/70.0 = 68.3% done in 16.0s, 7.4s to go
# on time step 956 (time=47.8), 0.016633 s/step
# Meep progress: 59.75/70.0 = 85.4% done in 20.0s, 3.4s to go
# on time step 1195 (time=59.75), 0.0167463 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000390053 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.527388 s
# -----------
# Meep progress: 7.8500000000000005/70.0 = 11.2% done in 4.0s, 31.7s to go
# on time step 157 (time=7.85), 0.0255288 s/step
# Meep progress: 19.5/70.0 = 27.9% done in 8.0s, 20.8s to go
# on time step 390 (time=19.5), 0.0172082 s/step
# Meep progress: 31.25/70.0 = 44.6% done in 12.0s, 14.9s to go
# on time step 625 (time=31.25), 0.0170714 s/step
# Meep progress: 46.75/70.0 = 66.8% done in 16.0s, 8.0s to go
# on time step 935 (time=46.75), 0.0129283 s/step
# Meep progress: 58.25/70.0 = 83.2% done in 20.0s, 4.0s to go
# on time step 1166 (time=58.3), 0.0173894 s/step
# Meep progress: 69.05/70.0 = 98.6% done in 24.0s, 0.3s to go
# on time step 1382 (time=69.1), 0.0185478 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000919819 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 7.93471 s
# -----------
# Meep progress: 7.65/70.0 = 10.9% done in 4.0s, 32.6s to go
# on time step 153 (time=7.65), 0.0261615 s/step
# Meep progress: 18.900000000000002/70.0 = 27.0% done in 8.0s, 21.6s to go
# on time step 379 (time=18.95), 0.0177789 s/step
# Meep progress: 30.200000000000003/70.0 = 43.1% done in 12.0s, 15.8s to go
# on time step 605 (time=30.25), 0.0177267 s/step
# Meep progress: 45.95/70.0 = 65.6% done in 16.0s, 8.4s to go
# on time step 920 (time=46), 0.0127092 s/step
# Meep progress: 57.300000000000004/70.0 = 81.9% done in 20.0s, 4.4s to go
# on time step 1147 (time=57.35), 0.0176489 s/step
# Meep progress: 68.55/70.0 = 97.9% done in 24.0s, 0.5s to go
# on time step 1372 (time=68.6), 0.017843 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 0.7853981633974483
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000353098 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.521111 s
# -----------
# Meep progress: 8.05/70.0 = 11.5% done in 4.0s, 30.8s to go
# on time step 161 (time=8.05), 0.0248702 s/step
# Meep progress: 19.950000000000003/70.0 = 28.5% done in 8.0s, 20.1s to go
# on time step 399 (time=19.95), 0.0168456 s/step
# Meep progress: 32.300000000000004/70.0 = 46.1% done in 12.0s, 14.0s to go
# on time step 646 (time=32.3), 0.0162456 s/step
# Meep progress: 44.35/70.0 = 63.4% done in 16.0s, 9.3s to go
# on time step 887 (time=44.35), 0.0166196 s/step
# Meep progress: 61.1/70.0 = 87.3% done in 20.0s, 2.9s to go
# on time step 1222 (time=61.1), 0.0119449 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000402927 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 6.85452 s
# -----------
# Meep progress: 8.15/70.0 = 11.6% done in 4.0s, 30.4s to go
# on time step 163 (time=8.15), 0.0245601 s/step
# Meep progress: 20.0/70.0 = 28.6% done in 8.0s, 20.0s to go
# on time step 400 (time=20), 0.0168993 s/step
# Meep progress: 31.55/70.0 = 45.1% done in 12.0s, 14.7s to go
# on time step 631 (time=31.55), 0.0173742 s/step
# Meep progress: 43.150000000000006/70.0 = 61.6% done in 16.0s, 10.0s to go
# on time step 863 (time=43.15), 0.0172586 s/step
# Meep progress: 55.050000000000004/70.0 = 78.6% done in 20.0s, 5.4s to go
# on time step 1101 (time=55.05), 0.0168574 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000841141 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.519187 s
# -----------
# Meep progress: 7.25/70.0 = 10.4% done in 4.0s, 34.7s to go
# on time step 145 (time=7.25), 0.0276768 s/step
# Meep progress: 19.25/70.0 = 27.5% done in 8.0s, 21.1s to go
# on time step 385 (time=19.25), 0.0166874 s/step
# Meep progress: 31.5/70.0 = 45.0% done in 12.0s, 14.7s to go
# on time step 630 (time=31.5), 0.0163538 s/step
# Meep progress: 43.900000000000006/70.0 = 62.7% done in 16.0s, 9.5s to go
# on time step 878 (time=43.9), 0.0161765 s/step
# Meep progress: 56.45/70.0 = 80.6% done in 20.1s, 4.8s to go
# on time step 1129 (time=56.45), 0.0159759 s/step
# Meep progress: 68.35000000000001/70.0 = 97.6% done in 24.1s, 0.6s to go
# on time step 1367 (time=68.35), 0.0168224 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000834942 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 5.84746 s
# -----------
# Meep progress: 7.3500000000000005/70.0 = 10.5% done in 4.0s, 34.1s to go
# on time step 147 (time=7.35), 0.0272426 s/step
# Meep progress: 19.25/70.0 = 27.5% done in 8.0s, 21.1s to go
# on time step 385 (time=19.25), 0.0168201 s/step
# Meep progress: 31.1/70.0 = 44.4% done in 12.0s, 15.0s to go
# on time step 622 (time=31.1), 0.0168832 s/step
# Meep progress: 42.5/70.0 = 60.7% done in 16.0s, 10.4s to go
# on time step 850 (time=42.5), 0.0176058 s/step
# Meep progress: 54.550000000000004/70.0 = 77.9% done in 20.0s, 5.7s to go
# on time step 1091 (time=54.55), 0.0166272 s/step
# Meep progress: 66.7/70.0 = 95.3% done in 24.1s, 1.2s to go
# on time step 1334 (time=66.7), 0.0166233 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 1.0471975511965976
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000421047 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.529371 s
# -----------
# Meep progress: 8.200000000000001/70.0 = 11.7% done in 4.0s, 30.2s to go
# on time step 164 (time=8.2), 0.0244232 s/step
# Meep progress: 19.85/70.0 = 28.4% done in 8.0s, 20.2s to go
# on time step 397 (time=19.85), 0.0171799 s/step
# Meep progress: 32.050000000000004/70.0 = 45.8% done in 12.0s, 14.2s to go
# on time step 641 (time=32.05), 0.0164002 s/step
# Meep progress: 44.6/70.0 = 63.7% done in 16.0s, 9.1s to go
# on time step 892 (time=44.6), 0.0159772 s/step
# Meep progress: 62.7/70.0 = 89.6% done in 20.0s, 2.3s to go
# on time step 1254 (time=62.7), 0.011053 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000385046 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 7.02883 s
# -----------
# Meep progress: 8.15/70.0 = 11.6% done in 4.0s, 30.4s to go
# on time step 163 (time=8.15), 0.0245566 s/step
# Meep progress: 19.85/70.0 = 28.4% done in 8.0s, 20.2s to go
# on time step 397 (time=19.85), 0.0171209 s/step
# Meep progress: 31.55/70.0 = 45.1% done in 12.0s, 14.6s to go
# on time step 631 (time=31.55), 0.0171185 s/step
# Meep progress: 43.300000000000004/70.0 = 61.9% done in 16.0s, 9.9s to go
# on time step 866 (time=43.3), 0.0170335 s/step
# Meep progress: 59.650000000000006/70.0 = 85.2% done in 20.0s, 3.5s to go
# on time step 1193 (time=59.65), 0.0122385 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00049901 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.502415 s
# -----------
# Meep progress: 7.8500000000000005/70.0 = 11.2% done in 4.0s, 31.7s to go
# on time step 157 (time=7.85), 0.0254921 s/step
# Meep progress: 19.55/70.0 = 27.9% done in 8.0s, 20.7s to go
# on time step 391 (time=19.55), 0.0171089 s/step
# Meep progress: 31.650000000000002/70.0 = 45.2% done in 12.0s, 14.6s to go
# on time step 633 (time=31.65), 0.0165748 s/step
# Meep progress: 42.85/70.0 = 61.2% done in 16.0s, 10.2s to go
# on time step 857 (time=42.85), 0.0179239 s/step
# Meep progress: 54.85/70.0 = 78.4% done in 20.0s, 5.5s to go
# on time step 1097 (time=54.85), 0.0166956 s/step
# Meep progress: 69.60000000000001/70.0 = 99.4% done in 24.0s, 0.1s to go
# on time step 1392 (time=69.6), 0.0135781 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00048089 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 7.20886 s
# -----------
# Meep progress: 8.0/70.0 = 11.4% done in 4.0s, 31.1s to go
# on time step 160 (time=8), 0.0250816 s/step
# Meep progress: 19.85/70.0 = 28.4% done in 8.0s, 20.3s to go
# on time step 397 (time=19.85), 0.0169159 s/step
# Meep progress: 31.400000000000002/70.0 = 44.9% done in 12.0s, 14.8s to go
# on time step 628 (time=31.4), 0.0173777 s/step
# Meep progress: 43.1/70.0 = 61.6% done in 16.1s, 10.0s to go
# on time step 862 (time=43.1), 0.017148 s/step
# Meep progress: 54.150000000000006/70.0 = 77.4% done in 20.1s, 5.9s to go
# on time step 1083 (time=54.15), 0.0181722 s/step
# Meep progress: 69.75/70.0 = 99.6% done in 24.1s, 0.1s to go
# on time step 1395 (time=69.75), 0.0128347 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 1.308996938995747
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000653028 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.520018 s
# -----------
# Meep progress: 8.3/70.0 = 11.9% done in 4.0s, 29.8s to go
# on time step 166 (time=8.3), 0.0241614 s/step
# Meep progress: 20.3/70.0 = 29.0% done in 8.0s, 19.6s to go
# on time step 406 (time=20.3), 0.0166947 s/step
# Meep progress: 32.45/70.0 = 46.4% done in 12.0s, 13.9s to go
# on time step 649 (time=32.45), 0.0164686 s/step
# Meep progress: 44.550000000000004/70.0 = 63.6% done in 16.0s, 9.2s to go
# on time step 891 (time=44.55), 0.0165493 s/step
# Meep progress: 56.800000000000004/70.0 = 81.1% done in 20.0s, 4.7s to go
# on time step 1136 (time=56.8), 0.0163283 s/step
# Meep progress: 68.95/70.0 = 98.5% done in 24.0s, 0.4s to go
# on time step 1379 (time=68.95), 0.016473 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000375986 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 5.50894 s
# -----------
# Meep progress: 8.0/70.0 = 11.4% done in 4.0s, 31.1s to go
# on time step 160 (time=8), 0.0250518 s/step
# Meep progress: 20.0/70.0 = 28.6% done in 8.0s, 20.0s to go
# on time step 400 (time=20), 0.0167113 s/step
# Meep progress: 31.8/70.0 = 45.4% done in 12.0s, 14.5s to go
# on time step 636 (time=31.8), 0.0170059 s/step
# Meep progress: 43.1/70.0 = 61.6% done in 16.0s, 10.0s to go
# on time step 862 (time=43.1), 0.0177376 s/step
# Meep progress: 49.650000000000006/70.0 = 70.9% done in 20.1s, 8.2s to go
# on time step 993 (time=49.65), 0.0308262 s/step
# Meep progress: 53.300000000000004/70.0 = 76.1% done in 24.1s, 7.6s to go
# on time step 1066 (time=53.3), 0.0550908 s/step
# Meep progress: 61.6/70.0 = 88.0% done in 28.1s, 3.8s to go
# on time step 1233 (time=61.65), 0.0240533 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000391006 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.601368 s
# -----------
# Meep progress: 6.25/70.0 = 8.9% done in 4.0s, 41.0s to go
# on time step 125 (time=6.25), 0.0321324 s/step
# Meep progress: 16.75/70.0 = 23.9% done in 8.0s, 25.5s to go
# on time step 335 (time=16.75), 0.0191009 s/step
# Meep progress: 27.5/70.0 = 39.3% done in 12.0s, 18.6s to go
# on time step 550 (time=27.5), 0.0186473 s/step
# Meep progress: 38.35/70.0 = 54.8% done in 16.0s, 13.2s to go
# on time step 767 (time=38.35), 0.0184557 s/step
# Meep progress: 49.1/70.0 = 70.1% done in 20.0s, 8.5s to go
# on time step 983 (time=49.15), 0.0186044 s/step
# Meep progress: 58.1/70.0 = 83.0% done in 24.1s, 4.9s to go
# on time step 1162 (time=58.1), 0.0224163 s/step
# Meep progress: 67.65/70.0 = 96.6% done in 28.1s, 1.0s to go
# on time step 1354 (time=67.7), 0.0209096 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00058794 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 5.50249 s
# -----------
# Meep progress: 6.9/70.0 = 9.9% done in 4.0s, 36.7s to go
# on time step 138 (time=6.9), 0.0290435 s/step
# Meep progress: 19.55/70.0 = 27.9% done in 8.0s, 20.7s to go
# on time step 391 (time=19.55), 0.0158223 s/step
# Meep progress: 32.1/70.0 = 45.9% done in 12.0s, 14.2s to go
# on time step 642 (time=32.1), 0.0159968 s/step
# Meep progress: 43.550000000000004/70.0 = 62.2% done in 16.0s, 9.7s to go
# on time step 871 (time=43.55), 0.0174966 s/step
# Meep progress: 54.5/70.0 = 77.9% done in 20.0s, 5.7s to go
# on time step 1090 (time=54.5), 0.0182912 s/step
# Meep progress: 66.15/70.0 = 94.5% done in 24.1s, 1.4s to go
# on time step 1323 (time=66.15), 0.0172176 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 1.5707963267948966
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000468016 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = -0.756203 s
# -----------
# Meep progress: 6.3500000000000005/70.0 = 9.1% done in 4.0s, 40.1s to go
# on time step 127 (time=6.35), 0.0315303 s/step
# Meep progress: 18.3/70.0 = 26.1% done in 8.0s, 22.7s to go
# on time step 366 (time=18.3), 0.0168247 s/step
# Meep progress: 28.05/70.0 = 40.1% done in 12.0s, 18.0s to go
# on time step 561 (time=28.05), 0.0205262 s/step
# Meep progress: 36.75/70.0 = 52.5% done in 16.0s, 14.5s to go
# on time step 735 (time=36.75), 0.0230305 s/step
# Meep progress: 44.5/70.0 = 63.6% done in 20.0s, 11.5s to go
# on time step 890 (time=44.5), 0.0258072 s/step
# Meep progress: 52.6/70.0 = 75.1% done in 24.1s, 8.0s to go
# on time step 1052 (time=52.6), 0.0247799 s/step
# Meep progress: 62.550000000000004/70.0 = 89.4% done in 28.1s, 3.3s to go
# on time step 1251 (time=62.55), 0.0201472 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00946093 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 10.2697 s
# -----------
# Meep progress: 6.1000000000000005/70.0 = 8.7% done in 4.0s, 42.0s to go
# on time step 122 (time=6.1), 0.0328356 s/step
# Meep progress: 16.25/70.0 = 23.2% done in 8.0s, 26.5s to go
# on time step 325 (time=16.25), 0.019759 s/step
# Meep progress: 26.700000000000003/70.0 = 38.1% done in 12.0s, 19.5s to go
# on time step 534 (time=26.7), 0.019198 s/step
# Meep progress: 38.800000000000004/70.0 = 55.4% done in 16.0s, 12.9s to go
# on time step 776 (time=38.8), 0.0165806 s/step
# Meep progress: 50.45/70.0 = 72.1% done in 20.1s, 7.8s to go
# on time step 1009 (time=50.45), 0.0172183 s/step
# Meep progress: 65.95/70.0 = 94.2% done in 24.1s, 1.5s to go
# on time step 1319 (time=65.95), 0.0129214 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.0004251 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.569964 s
# -----------
# Meep progress: 5.550000000000001/70.0 = 7.9% done in 4.0s, 46.6s to go
# on time step 111 (time=5.55), 0.0361601 s/step
# Meep progress: 13.75/70.0 = 19.6% done in 8.0s, 32.8s to go
# on time step 275 (time=13.75), 0.0243967 s/step
# Meep progress: 23.85/70.0 = 34.1% done in 12.0s, 23.3s to go
# on time step 477 (time=23.85), 0.0198284 s/step
# Meep progress: 36.9/70.0 = 52.7% done in 16.0s, 14.4s to go
# on time step 738 (time=36.9), 0.0153749 s/step
# Meep progress: 48.900000000000006/70.0 = 69.9% done in 20.0s, 8.6s to go
# on time step 979 (time=48.95), 0.0166625 s/step
# Meep progress: 61.650000000000006/70.0 = 88.1% done in 24.0s, 3.3s to go
# on time step 1234 (time=61.7), 0.0157073 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000323057 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 8.38419 s
# -----------
# Meep progress: 6.95/70.0 = 9.9% done in 4.0s, 36.4s to go
# on time step 139 (time=6.95), 0.0288928 s/step
# Meep progress: 19.400000000000002/70.0 = 27.7% done in 8.0s, 20.9s to go
# on time step 388 (time=19.4), 0.016118 s/step
# Meep progress: 31.1/70.0 = 44.4% done in 12.0s, 15.0s to go
# on time step 623 (time=31.15), 0.0170853 s/step
# Meep progress: 43.7/70.0 = 62.4% done in 16.0s, 9.7s to go
# on time step 875 (time=43.75), 0.0159063 s/step
# Meep progress: 56.0/70.0 = 80.0% done in 20.0s, 5.0s to go
# on time step 1121 (time=56.05), 0.0162998 s/step
# run 0 finished at t = 70.0 (1400 timesteps)

# %%
plt.plot([np.degrees(b) for b in betas], scatt_eff_list, marker='o')
plt.xlabel("Polarization angle β (degrees)")
plt.ylabel("Scattering efficiency")
plt.grid(True)
plt.title("Scattering efficiency vs. polarization angle")
plt.show()

# %%
from tabulate import tabulate

def scalar(val):
    return val.item() if isinstance(val, np.ndarray) else val

table_data = [
    [f"{scalar(row['beta']):.1f}°",
     f"{scalar(row['X1']):.5f}",
     f"{scalar(row['X2']):.5f}",
     f"{scalar(row['Y1']):.5f}",
     f"{scalar(row['Y2']):.5f}",
     f"{scalar(row['Z1']):.5f}",
     f"{scalar(row['Z2']):.5f}",
     f"{scalar(row['scatt_total']):.5f}"]
    for row in flux_results
]

headers = ["β (°)", "X1 (−x)", "X2 (+x)", "Y1 (−y)", "Y2 (+y)", "Z1 (−z)", "Z2 (+z)", "Scatt. Total"]
print(tabulate(table_data, headers=headers, tablefmt="github"))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 6
#       3 def scalar(val):
#       4     return val.item() if isinstance(val, np.ndarray) else val
# ----> 6 table_data = [
#       7     [f"{scalar(row['beta']):.1f}°",
#       8      f"{scalar(row['X1']):.5f}",
#       9      f"{scalar(row['X2']):.5f}",
#      10      f"{scalar(row['Y1']):.5f}",
#      11      f"{scalar(row['Y2']):.5f}",
#      12      f"{scalar(row['Z1']):.5f}",
#      13      f"{scalar(row['Z2']):.5f}",
#      14      f"{scalar(row['scatt_total']):.5f}"]
#      15     for row in flux_results
#      16 ]
#      18 headers = ["β (°)", "X1 (−x)", "X2 (+x)", "Y1 (−y)", "Y2 (+y)", "Z1 (−z)", "Z2 (+z)", "Scatt. Total"]
#      19 print(tabulate(table_data, headers=headers, tablefmt="github"))
#
# Cell In[4], line 14, in <listcomp>(.0)
#       3 def scalar(val):
#       4     return val.item() if isinstance(val, np.ndarray) else val
#       6 table_data = [
#       7     [f"{scalar(row['beta']):.1f}°",
#       8      f"{scalar(row['X1']):.5f}",
#       9      f"{scalar(row['X2']):.5f}",
#      10      f"{scalar(row['Y1']):.5f}",
#      11      f"{scalar(row['Y2']):.5f}",
#      12      f"{scalar(row['Z1']):.5f}",
#      13      f"{scalar(row['Z2']):.5f}",
# ---> 14      f"{scalar(row['scatt_total']):.5f}"]
#      15     for row in flux_results
#      16 ]
#      18 headers = ["β (°)", "X1 (−x)", "X2 (+x)", "Y1 (−y)", "Y2 (+y)", "Z1 (−z)", "Z2 (+z)", "Scatt. Total"]
#      19 print(tabulate(table_data, headers=headers, tablefmt="github"))
#
# KeyError: 'scatt_total'

# %%
def scalar(val):
    return val.item() if isinstance(val, np.ndarray) else val

for entry in flux_results:
    print(f"\n--- β = {scalar(entry['beta']):.1f}° ---")
    print(f"X1 (−x): {scalar(entry['X1']):.5f}")
    print(f"X2 (+x): {scalar(entry['X2']):.5f}")
    print(f"Y1 (−y): {scalar(entry['Y1']):.5f}")
    print(f"Y2 (+y): {scalar(entry['Y2']):.5f}")
    print(f"Z1 (−z): {scalar(entry['Z1']):.5f}")
    print(f"Z2 (+z): {scalar(entry['Z2']):.5f}")
    print(f"Scattered Total: {scalar(entry['scatt_total']):.5f}")
# Out:
# --- β = 0.0° ---
# X1 (−x): -0.00000
# X2 (+x): 0.00000
# Y1 (−y): 0.00004
# Y2 (+y): 0.00001
# Z1 (−z): 0.00221
# Z2 (+z): 0.00224
# Scattered Total: 0.00000
#
# --- β = 15.0° ---
# X1 (−x): -0.00000
# X2 (+x): -0.00000
# Y1 (−y): 0.00004
# Y2 (+y): 0.00001
# Z1 (−z): 0.00221
# Z2 (+z): 0.00224
# Scattered Total: 0.00000
#
# --- β = 30.0° ---
# X1 (−x): 0.00000
# X2 (+x): -0.00001
# Y1 (−y): 0.00003
# Y2 (+y): 0.00000
# Z1 (−z): 0.00220
# Z2 (+z): 0.00224
# Scattered Total: 0.00000
#
# --- β = 45.0° ---
# X1 (−x): 0.00001
# X2 (+x): -0.00002
# Y1 (−y): 0.00002
# Y2 (+y): -0.00000
# Z1 (−z): 0.00219
# Z2 (+z): 0.00224
# Scattered Total: 0.00000
#
# --- β = 60.0° ---
# X1 (−x): 0.00002
# X2 (+x): -0.00004
# Y1 (−y): 0.00001
# Y2 (+y): -0.00000
# Z1 (−z): 0.00217
# Z2 (+z): 0.00224
# Scattered Total: 0.00000
#
# --- β = 75.0° ---
# X1 (−x): 0.00002
# X2 (+x): -0.00005
# Y1 (−y): -0.00000
# Y2 (+y): -0.00001
# Z1 (−z): 0.00216
# Z2 (+z): 0.00224
# Scattered Total: 0.00000
#
# --- β = 90.0° ---
# X1 (−x): 0.00003
# X2 (+x): -0.00005
# Y1 (−y): -0.00000
# Y2 (+y): -0.00001
# Z1 (−z): 0.00216
# Z2 (+z): 0.00224
# Scattered Total: 0.00000

# %%
import numpy as np
import matplotlib.pyplot as plt

# Convert to scalar values if needed
def scalar(val):
    return val.item() if isinstance(val, np.ndarray) else val

# Extract data
betas = [scalar(entry['beta']) for entry in flux_results]
Z1 = [scalar(entry['Z1']) for entry in flux_results]
Z2 = [scalar(entry['Z2']) for entry in flux_results]
X1 = [scalar(entry['X1']) for entry in flux_results]
X2 = [scalar(entry['X2']) for entry in flux_results]
Y1 = [scalar(entry['Y1']) for entry in flux_results]
Y2 = [scalar(entry['Y2']) for entry in flux_results]


# Set up subplots
fig, axs = plt.subplots(3, 2, figsize=(12, 10))
axs = axs.flatten()

# Plot each component
labels = ['Z1 (−z)', 'Z2 (+z)', 'X1 (−x)', 'X2 (+x)', 'Y1 (−y)', 'Y2 (+y)']
values = [Z1, Z2, X1, X2, Y1, Y2]

for i, (label, val) in enumerate(zip(labels, values)):
    axs[i].plot(betas, val, marker='o')
    axs[i].set_title(label)
    axs[i].set_xlabel("β (degrees)")
    axs[i].set_ylabel("Flux")
    axs[i].grid(True)

# Hide unused subplot if any
if len(axs) > len(labels):
    axs[-1].axis('off')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       6     return val.item() if isinstance(val, np.ndarray) else val
#       8 # Extract data
# ----> 9 betas = [scalar(entry['beta']) for entry in flux_results]
#      10 Z1 = [scalar(entry['Z1']) for entry in flux_results]
#      11 Z2 = [scalar(entry['Z2']) for entry in flux_results]
#
# NameError: name 'flux_results' is not defined

# %% [markdown]
# The incident intensity (`intensity`) is the flux in one of the six monitor planes (the one closest to and facing the planewave source propagating in the $x$ direction) divided by its area. This is why the six sides of the flux box are defined separately. (Otherwise, the entire box could have been defined as a single flux object with different weights ±1 for each side.) The scattered power is multiplied by -1 since it is the *outgoing* power (a positive quantity) rather than the incoming power as defined by the orientation of the flux box. Note that because of the linear $E_z$ polarization of the source, the flux through the $y$ and $z$ planes will *not* be the same. A circularly-polarized source would have produced equal flux in these two monitor planes. The runtime of the scattering run is chosen to be sufficiently long to ensure that the Fourier-transformed fields have [converged](https://meep.readthedocs.io/en/latest/FAQ/checking-convergence).
