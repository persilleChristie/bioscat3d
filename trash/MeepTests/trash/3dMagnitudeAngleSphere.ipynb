# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt

# %%
# Simulation parameters
resolution = 10  # pixels/um
pml_thickness = 2
cell_x = 16
cell_y = 16
cell_z = 16

sphere_radius = 1.0
sphere_eps = 2.56
substrate_eps = 2.56
frequency = 1.0

cell_size = mp.Vector3(cell_x, cell_y, cell_z)

# Plane wave incidence defined by polar and azimuthal angles (in degrees)
theta_deg = 10  # Polar angle from +Z
phi_deg = 0    # Azimuthal angle in x–y plane

# Convert to radians
theta = np.radians(theta_deg)
phi = np.radians(phi_deg)

# Build normalized k-vector
k_unit = mp.Vector3(
    np.sin(theta) * np.cos(phi),
    np.sin(theta) * np.sin(phi),
    -np.cos(theta)  # negative for downward propagation
)

# Scale for Meep's eig_kpoint (|k| = frequency in Meep units)
eig_kpoint = k_unit.scale(frequency)

# %%
# Materials
default_material = mp.Medium(index=1.0)
sphere = mp.Sphere(
    center=mp.Vector3(0, 0, 1.5),  # place above substrate
    radius=sphere_radius,
    material=mp.Medium(epsilon=sphere_eps)
)

substrate = mp.Block(
    center=mp.Vector3(0, 0, -cell_z/4),
    size=mp.Vector3(mp.inf, mp.inf, cell_z/2),
    material=mp.Medium(epsilon=substrate_eps)
)

geometry = [sphere, substrate]

# Source: downward plane wave at angles
sources = [
    mp.EigenModeSource(
        src=mp.ContinuousSource(frequency=frequency),
        center=mp.Vector3(0, 0, 0.5 * cell_z - pml_thickness - 1),
        size=mp.Vector3(cell_x, cell_y, 0),
        direction=mp.Z,  # still Z, but mode defines propagation
        eig_kpoint=eig_kpoint,
        eig_band=1,
        eig_match_freq=True
    )
]


# PMLs on all sides
pml_layers = [
    mp.PML(thickness=pml_thickness, direction=mp.X),
    mp.PML(thickness=pml_thickness, direction=mp.Y),
    mp.PML(thickness=pml_thickness, direction=mp.Z),
]

# Simulation object
sim = mp.Simulation(
    cell_size=cell_size,
    resolution=resolution,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    default_material=default_material
)

# Add flux monitors (six directions)
flux_regions = {
    'top':    mp.FluxRegion(center=mp.Vector3(0, 0, 0.5*cell_z - pml_thickness - 0.1), size=mp.Vector3(cell_x, cell_y, 0)),
    'bottom': mp.FluxRegion(center=mp.Vector3(0, 0, -0.5*cell_z + pml_thickness + 0.1), size=mp.Vector3(cell_x, cell_y, 0)),
    'left':   mp.FluxRegion(center=mp.Vector3(-0.5*cell_x + pml_thickness + 0.1, 0, 0), size=mp.Vector3(0, cell_y, cell_z)),
    'right':  mp.FluxRegion(center=mp.Vector3(0.5*cell_x - pml_thickness - 0.1, 0, 0), size=mp.Vector3(0, cell_y, cell_z)),
    'front':  mp.FluxRegion(center=mp.Vector3(0, -0.5*cell_y + pml_thickness + 0.1, 0), size=mp.Vector3(cell_x, 0, cell_z)),
    'back':   mp.FluxRegion(center=mp.Vector3(0, 0.5*cell_y - pml_thickness - 0.1, 0), size=mp.Vector3(cell_x, 0, cell_z)),
}

flux_monitors = {name: sim.add_flux(frequency, 0, 1, region)
                 for name, region in flux_regions.items()}

# Run the simulation
sim.run(until=60)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00201392 s
# Working in 3D dimensions.
# Computational cell is 16 x 16 x 16 with resolution 10
#      sphere, center = (0,0,1.5)
#           radius 1
#           dielectric constant epsilon diagonal = (2.56,2.56,2.56)
#      block, center = (0,0,-4)
#           size (1e+20,1e+20,8)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.56,2.56,2.56)
# time for set_epsilon = 20.3366 s
# -----------
# MPB solved for frequency_1(0.00174533,0,-0.999998) = 1 after 108 iters
# Meep progress: 0.05/60.0 = 0.1% done in 9.7s, 11602.8s to go
# on time step 1 (time=0.05), 9.67748 s/step
# Meep progress: 1.1500000000000001/60.0 = 1.9% done in 13.8s, 708.2s to go
# on time step 23 (time=1.15), 0.189032 s/step
# Meep progress: 2.25/60.0 = 3.8% done in 18.0s, 462.1s to go
# on time step 45 (time=2.25), 0.189326 s/step
# Meep progress: 3.35/60.0 = 5.6% done in 22.2s, 375.1s to go
# on time step 67 (time=3.35), 0.18975 s/step
# Meep progress: 4.45/60.0 = 7.4% done in 26.3s, 328.2s to go
# on time step 89 (time=4.45), 0.186801 s/step
# Meep progress: 5.5/60.0 = 9.2% done in 30.4s, 301.4s to go
# on time step 110 (time=5.5), 0.196363 s/step
# Meep progress: 6.6000000000000005/60.0 = 11.0% done in 34.5s, 279.3s to go
# on time step 132 (time=6.6), 0.18663 s/step
# Meep progress: 7.7/60.0 = 12.8% done in 38.7s, 263.1s to go
# on time step 154 (time=7.7), 0.191332 s/step
# Meep progress: 8.75/60.0 = 14.6% done in 42.8s, 250.9s to go
# on time step 175 (time=8.75), 0.195598 s/step
# Meep progress: 9.600000000000001/60.0 = 16.0% done in 47.1s, 247.3s to go
# on time step 192 (time=9.6), 0.250186 s/step
# Meep progress: 10.350000000000001/60.0 = 17.3% done in 51.3s, 246.2s to go
# on time step 207 (time=10.35), 0.281849 s/step
# Meep progress: 11.450000000000001/60.0 = 19.1% done in 55.5s, 235.3s to go
# on time step 229 (time=11.45), 0.189436 s/step
# Meep progress: 12.450000000000001/60.0 = 20.8% done in 59.5s, 227.3s to go
# on time step 249 (time=12.45), 0.20001 s/step
# Meep progress: 13.4/60.0 = 22.3% done in 63.6s, 221.3s to go
# on time step 268 (time=13.4), 0.218219 s/step
# Meep progress: 14.450000000000001/60.0 = 24.1% done in 67.7s, 213.5s to go
# on time step 289 (time=14.45), 0.194853 s/step
# Meep progress: 15.55/60.0 = 25.9% done in 71.8s, 205.2s to go
# on time step 311 (time=15.55), 0.184144 s/step
# Meep progress: 16.650000000000002/60.0 = 27.8% done in 75.9s, 197.7s to go
# on time step 333 (time=16.65), 0.187878 s/step
# Meep progress: 17.7/60.0 = 29.5% done in 80.1s, 191.3s to go
# on time step 354 (time=17.7), 0.19639 s/step
# Meep progress: 18.8/60.0 = 31.3% done in 84.2s, 184.6s to go
# on time step 376 (time=18.8), 0.188871 s/step
# Meep progress: 19.85/60.0 = 33.1% done in 88.4s, 178.7s to go
# on time step 397 (time=19.85), 0.197425 s/step
# Meep progress: 20.950000000000003/60.0 = 34.9% done in 92.5s, 172.5s to go
# on time step 419 (time=20.95), 0.188864 s/step
# Meep progress: 22.05/60.0 = 36.8% done in 96.7s, 166.5s to go
# on time step 441 (time=22.05), 0.190703 s/step
# Meep progress: 23.1/60.0 = 38.5% done in 100.8s, 161.1s to go
# on time step 462 (time=23.1), 0.19579 s/step
# Meep progress: 24.05/60.0 = 40.1% done in 104.9s, 156.8s to go
# on time step 481 (time=24.05), 0.213375 s/step
# Meep progress: 25.1/60.0 = 41.8% done in 109.0s, 151.6s to go
# on time step 502 (time=25.1), 0.19727 s/step
# Meep progress: 26.1/60.0 = 43.5% done in 113.2s, 147.0s to go
# on time step 522 (time=26.1), 0.20632 s/step
# Meep progress: 27.150000000000002/60.0 = 45.3% done in 117.3s, 142.0s to go
# on time step 543 (time=27.15), 0.199466 s/step
# Meep progress: 28.25/60.0 = 47.1% done in 121.5s, 136.5s to go
# on time step 565 (time=28.25), 0.187868 s/step
# Meep progress: 29.25/60.0 = 48.8% done in 125.6s, 132.0s to go
# on time step 585 (time=29.25), 0.204046 s/step
# Meep progress: 30.25/60.0 = 50.4% done in 129.7s, 127.5s to go
# on time step 605 (time=30.25), 0.206065 s/step
# Meep progress: 31.3/60.0 = 52.2% done in 133.9s, 122.8s to go
# on time step 626 (time=31.3), 0.199632 s/step
# Meep progress: 32.4/60.0 = 54.0% done in 138.0s, 117.5s to go
# on time step 648 (time=32.4), 0.186793 s/step
# Meep progress: 33.5/60.0 = 55.8% done in 142.1s, 112.4s to go
# on time step 670 (time=33.5), 0.186995 s/step
# Meep progress: 34.550000000000004/60.0 = 57.6% done in 146.2s, 107.7s to go
# on time step 691 (time=34.55), 0.194655 s/step
# Meep progress: 35.65/60.0 = 59.4% done in 150.4s, 102.7s to go
# on time step 713 (time=35.65), 0.188932 s/step
# Meep progress: 36.7/60.0 = 61.2% done in 154.4s, 98.0s to go
# on time step 734 (time=36.7), 0.194188 s/step
# Meep progress: 37.800000000000004/60.0 = 63.0% done in 158.5s, 93.1s to go
# on time step 756 (time=37.8), 0.186578 s/step
# Meep progress: 38.900000000000006/60.0 = 64.8% done in 162.6s, 88.2s to go
# on time step 778 (time=38.9), 0.185608 s/step
# Meep progress: 39.95/60.0 = 66.6% done in 166.8s, 83.7s to go
# on time step 799 (time=39.95), 0.200388 s/step
# Meep progress: 40.95/60.0 = 68.3% done in 170.9s, 79.5s to go
# on time step 819 (time=40.95), 0.201265 s/step
# Meep progress: 42.0/60.0 = 70.0% done in 175.0s, 75.0s to go
# on time step 840 (time=42), 0.197039 s/step
# Meep progress: 43.1/60.0 = 71.8% done in 179.2s, 70.3s to go
# on time step 862 (time=43.1), 0.189249 s/step
# Meep progress: 44.1/60.0 = 73.5% done in 183.2s, 66.0s to go
# on time step 882 (time=44.1), 0.200924 s/step
# Meep progress: 45.2/60.0 = 75.3% done in 187.2s, 61.3s to go
# on time step 904 (time=45.2), 0.182289 s/step
# Meep progress: 46.25/60.0 = 77.1% done in 191.2s, 56.9s to go
# on time step 925 (time=46.25), 0.192173 s/step
# Meep progress: 47.300000000000004/60.0 = 78.8% done in 195.4s, 52.5s to go
# on time step 946 (time=47.3), 0.196745 s/step
# Meep progress: 48.1/60.0 = 80.2% done in 199.6s, 49.4s to go
# on time step 962 (time=48.1), 0.264432 s/step
# Meep progress: 48.900000000000006/60.0 = 81.5% done in 203.6s, 46.2s to go
# on time step 978 (time=48.9), 0.251741 s/step
# Meep progress: 49.900000000000006/60.0 = 83.2% done in 207.8s, 42.0s to go
# on time step 998 (time=49.9), 0.206166 s/step
# Meep progress: 50.95/60.0 = 84.9% done in 211.9s, 37.6s to go
# on time step 1019 (time=50.95), 0.196857 s/step
# Meep progress: 52.0/60.0 = 86.7% done in 215.9s, 33.2s to go
# on time step 1040 (time=52), 0.192681 s/step
# Meep progress: 53.050000000000004/60.0 = 88.4% done in 220.0s, 28.8s to go
# on time step 1061 (time=53.05), 0.195812 s/step
# Meep progress: 54.2/60.0 = 90.3% done in 224.1s, 24.0s to go
# on time step 1084 (time=54.2), 0.177154 s/step
# Meep progress: 55.35/60.0 = 92.2% done in 228.3s, 19.2s to go
# on time step 1107 (time=55.35), 0.181096 s/step
# Meep progress: 56.45/60.0 = 94.1% done in 232.3s, 14.6s to go
# on time step 1129 (time=56.45), 0.183766 s/step
# Meep progress: 57.6/60.0 = 96.0% done in 236.5s, 9.9s to go
# on time step 1152 (time=57.6), 0.179954 s/step
# Meep progress: 58.7/60.0 = 97.8% done in 240.6s, 5.3s to go
# on time step 1174 (time=58.7), 0.18907 s/step
# Meep progress: 59.800000000000004/60.0 = 99.7% done in 244.8s, 0.8s to go
# on time step 1196 (time=59.8), 0.191247 s/step
# run 0 finished at t = 60.0 (1200 timesteps)

# %%
# Print flux values
for name, monitor in flux_monitors.items():
    flux_val = mp.get_fluxes(monitor)[0]
    print(f"Flux through {name}: {flux_val:.6f}")

# Get all field components for total |E| calculation
ex = sim.get_array(center=mp.Vector3(), size=mp.Vector3(cell_x, 0, cell_z), component=mp.Ex)
ey = sim.get_array(center=mp.Vector3(), size=mp.Vector3(cell_x, 0, cell_z), component=mp.Ey)
ez = sim.get_array(center=mp.Vector3(), size=mp.Vector3(cell_x, 0, cell_z), component=mp.Ez)

abs_E = np.sqrt(np.abs(ex)**2 + np.abs(ey)**2 + np.abs(ez)**2)

# Plot total field magnitude
plt.figure(dpi=100)
plt.imshow(abs_E.T, cmap='inferno', origin='lower', extent=[-cell_x/2, cell_x/2, -cell_z/2, cell_z/2])
plt.colorbar(label='|E|')
plt.xlabel('x (µm)')
plt.ylabel('z (µm)')
plt.title('Total Electric Field Magnitude |E| (slice at y=0)')
plt.tight_layout()
plt.show()
# Out:
# Flux through top: 16.750088
# Flux through bottom: -269.144053
# Flux through left: 5.055997
# Flux through right: -4.141258
# Flux through front: 4.448790
# Flux through back: -4.556856
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
