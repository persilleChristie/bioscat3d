# %% [markdown]
# # Planewaves in Homogeneous Media

# %% [markdown]
# First, we'll load our necesarry modules:

# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Next, we'll create a function we can call multiple times that runs the simulation for different rotation angles:

# %%
def run_sim(rot_angle=0):
    sx = 64
    sy = 32

    resolution = 25  # pixels/μm

    cell_size = mp.Vector3(sx, sy, 0)  # for 2D

    pml_thickness = 4

    pml_layers = [
    mp.PML(thickness=pml_thickness, direction=mp.Y),
    #mp.PML(thickness=pml_thickness, direction=mp.X)
    ]


    fsrc = 1.0  # frequency of planewave (wavelength = 1/fsrc)

    n = 1  # refractive index of homogeneous material
    default_material = mp.Medium(index=n)

    k_point = mp.Vector3(y=-fsrc * n).rotate(mp.Vector3(z=1), rot_angle)

    geometry1 = [
        mp.Block(
            center=mp.Vector3(0, -sy/4),              # centered halfway down
            size=mp.Vector3(mp.inf, sy/2, mp.inf),    # fill y < 0
            material=mp.Medium(epsilon=2.56)
        )
    ]


    geometry2 = [
    mp.Cylinder(
        radius=1.0,
        height=mp.inf,                     # for 2D: extend infinitely in z
        center=mp.Vector3(0, 1),           # center at (0, 1)
        material=mp.Medium(epsilon=2.56)    # dielectric with ε=4 (or use mp.metal for PEC)
    )
    ]



    sources = [
        mp.EigenModeSource(
            src=mp.ContinuousSource(fsrc),
            center=mp.Vector3(0,sy/2 - 1.5 * pml_thickness),
            size=mp.Vector3(x=sx),
            direction=mp.AUTOMATIC if rot_angle == 0 else mp.NO_DIRECTION,
            eig_kpoint=k_point,
            eig_band=1,
            eig_parity=mp.EVEN_Y + mp.ODD_Z if rot_angle == 0 else mp.ODD_Z,
            eig_match_freq=True,
        )
    ]

    sim = mp.Simulation(
        cell_size=cell_size,
        resolution=resolution,
        geometry = geometry1 + geometry2,
        boundary_layers=pml_layers,
        sources=sources,
        k_point=k_point,
        default_material=default_material,
        symmetries=[mp.Mirror(mp.Y)] if rot_angle == 0 else [],
    )

    # Define positions of flux monitors (just inside the PML boundaries)
    flux_distance_from_boundary = pml_thickness + 0.1 # µm from boundary, adjust as needed

    # Top flux region (near top PML)
    flux_top = sim.add_flux(
        fsrc, 0, 1,
        mp.FluxRegion(center=mp.Vector3(0, 0.5*sy - flux_distance_from_boundary), size=mp.Vector3(sx, 0))
    )

    flux_1 = sim.add_flux(
    fsrc, 0, 1,
    mp.FluxRegion(center=mp.Vector3(0, sy/2 - 1.5 * pml_thickness -0.1), size=mp.Vector3(sx, 0))
    )

    flux_2 = sim.add_flux(
    fsrc, 0, 1,
    mp.FluxRegion(center=mp.Vector3(0, 3), size=mp.Vector3(sx, 0))
    )

    flux_3 = sim.add_flux(
    fsrc, 0, 1,
    mp.FluxRegion(center=mp.Vector3(0, -0.1), size=mp.Vector3(sx, 0))
    )


    # Bottom flux region (near bottom PML, behind the source)
    flux_bottom = sim.add_flux(
        fsrc, 0, 1,
        mp.FluxRegion(center=mp.Vector3(0, -0.5*sy + flux_distance_from_boundary), size=mp.Vector3(sx, 0))
    )

    # Run your simulation
    sim.run(until=60)

    # Retrieve flux data
    flux_top_data = mp.get_fluxes(flux_top)
    flux_1_data = mp.get_fluxes(flux_1)
    flux_2_data = mp.get_fluxes(flux_2)
    flux_3_data = mp.get_fluxes(flux_3)
    flux_bottom_data = mp.get_fluxes(flux_bottom)

    print(f"Flux near top PML boundary: {flux_top_data[0]:.6f}")
    print(f"Flux at y = sy/2 - (pml_thickness + 2.1): {flux_1_data[0]:.6f}")
    print(f"Flux at y = 3: {flux_2_data[0]:.6f}")
    print(f"Flux at y = -0.1: {flux_3_data[0]:.6f}")
    print(f"Flux near bottom boundary: {flux_bottom_data[0]:.6f}")

    # Get field data
    ez = sim.get_array(center=mp.Vector3(), size=cell_size, component=mp.Ez)
    ex = sim.get_array(center=mp.Vector3(), size=cell_size, component=mp.Ex)
    ey = sim.get_array(center=mp.Vector3(), size=cell_size, component=mp.Ey)

    # Calculate |E| = sqrt(|Ex|^2 + |Ey|^2 + |Ez|^2)
    abs_E = np.sqrt(np.abs(ex)**2 + np.abs(ey)**2 + np.abs(ez)**2)

    # Plot
    plt.figure(figsize=(8, 4))
    plt.imshow(abs_E.transpose(), interpolation='spline36', cmap='viridis', origin='lower')
    plt.colorbar(label='|E|')
    plt.title('Magnitude of Electric Field |E|')
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.show()

# %% [markdown]
# Next we'll iterate over three rotation angles and plot their steady-state fields profiles. Residues of the backward-propagating waves due to the discretization are slightly visible.

# %%
for rot_angle in np.radians([0, 1, 20, 45, 65,]):
    run_sim(rot_angle)
# Out:
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00191712 s
# Working in 2D dimensions.
# Computational cell is 64 x 32 x 0 with resolution 25
#      block, center = (0,-8,0)
#           size (1e+20,16,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.56,2.56,2.56)
#      cylinder, center = (0,1,0)
#           radius 1, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (2.56,2.56,2.56)
# time for set_epsilon = 1.09359 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0,-1,0) = 1 after 308 iters
# Meep progress: 5.7/60.0 = 9.5% done in 4.0s, 38.2s to go
# on time step 285 (time=5.7), 0.0140591 s/step
# Meep progress: 12.9/60.0 = 21.5% done in 8.0s, 29.2s to go
# on time step 645 (time=12.9), 0.0111211 s/step
# Meep progress: 19.78/60.0 = 33.0% done in 12.0s, 24.4s to go
# on time step 989 (time=19.78), 0.0116345 s/step
# Meep progress: 26.86/60.0 = 44.8% done in 16.0s, 19.8s to go
# on time step 1343 (time=26.86), 0.0113344 s/step
# Meep progress: 33.38/60.0 = 55.6% done in 20.0s, 16.0s to go
# on time step 1669 (time=33.38), 0.0122812 s/step
# Meep progress: 40.4/60.0 = 67.3% done in 24.0s, 11.7s to go
# on time step 2020 (time=40.4), 0.0114087 s/step
# Meep progress: 47.42/60.0 = 79.0% done in 28.0s, 7.4s to go
# on time step 2371 (time=47.42), 0.0114057 s/step
# Meep progress: 54.22/60.0 = 90.4% done in 32.1s, 3.4s to go
# on time step 2711 (time=54.22), 0.0117915 s/step
# run 0 finished at t = 60.0 (3000 timesteps)
# Flux near top PML boundary: 945.398929
# Flux at y = sy/2 - (pml_thickness + 2.1): -1293.020487
# Flux at y = 3: -403.022987
# Flux at y = -0.1: 16.298275
# Flux near bottom boundary: -945.398929
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000106812 s
# Working in 2D dimensions.
# Computational cell is 64 x 32 x 0 with resolution 25
#      block, center = (0,-8,0)
#           size (1e+20,16,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.56,2.56,2.56)
#      cylinder, center = (0,1,0)
#           radius 1, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (2.56,2.56,2.56)
# time for set_epsilon = 1.95803 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0.0174524,-0.999848,0) = 1 after 308 iters
# Meep progress: 3.88/60.0 = 6.5% done in 4.0s, 58.0s to go
# on time step 194 (time=3.88), 0.0206678 s/step
# Meep progress: 7.22/60.0 = 12.0% done in 8.0s, 58.6s to go
# on time step 361 (time=7.22), 0.0239699 s/step
# Meep progress: 10.46/60.0 = 17.4% done in 12.1s, 57.1s to go
# on time step 523 (time=10.46), 0.0249404 s/step
# Meep progress: 13.56/60.0 = 22.6% done in 16.1s, 55.0s to go
# on time step 678 (time=13.56), 0.0258182 s/step
# Meep progress: 16.78/60.0 = 28.0% done in 20.1s, 51.7s to go
# on time step 839 (time=16.78), 0.0249727 s/step
# Meep progress: 20.34/60.0 = 33.9% done in 24.1s, 47.0s to go
# on time step 1017 (time=20.34), 0.0225786 s/step
# Meep progress: 23.82/60.0 = 39.7% done in 28.1s, 42.7s to go
# on time step 1191 (time=23.82), 0.023071 s/step
# Meep progress: 27.5/60.0 = 45.8% done in 32.1s, 38.0s to go
# on time step 1375 (time=27.5), 0.0217711 s/step
# Meep progress: 31.0/60.0 = 51.7% done in 36.1s, 33.8s to go
# on time step 1550 (time=31), 0.0229222 s/step
# Meep progress: 34.56/60.0 = 57.6% done in 40.1s, 29.6s to go
# on time step 1728 (time=34.56), 0.0225484 s/step
# Meep progress: 38.06/60.0 = 63.4% done in 44.2s, 25.5s to go
# on time step 1903 (time=38.06), 0.0228846 s/step
# Meep progress: 41.86/60.0 = 69.8% done in 48.2s, 20.9s to go
# on time step 2093 (time=41.86), 0.0211233 s/step
# Meep progress: 45.54/60.0 = 75.9% done in 52.2s, 16.6s to go
# on time step 2277 (time=45.54), 0.0220857 s/step
# Meep progress: 49.02/60.0 = 81.7% done in 56.2s, 12.6s to go
# on time step 2451 (time=49.02), 0.0229973 s/step
# Meep progress: 52.18/60.0 = 87.0% done in 60.2s, 9.0s to go
# on time step 2609 (time=52.18), 0.025365 s/step
# Meep progress: 55.46/60.0 = 92.4% done in 64.2s, 5.3s to go
# on time step 2773 (time=55.46), 0.0244141 s/step
# Meep progress: 59.0/60.0 = 98.3% done in 68.3s, 1.2s to go
# on time step 2950 (time=59), 0.0226358 s/step
# run 0 finished at t = 60.0 (3000 timesteps)
# Flux near top PML boundary: 37.388384
# Flux at y = sy/2 - (pml_thickness + 2.1): -2248.722333
# Flux at y = 3: -1726.470377
# Flux at y = -0.1: -1504.400616
# Flux near bottom boundary: -563.001214
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000119209 s
# Working in 2D dimensions.
# Computational cell is 64 x 32 x 0 with resolution 25
#      block, center = (0,-8,0)
#           size (1e+20,16,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.56,2.56,2.56)
#      cylinder, center = (0,1,0)
#           radius 1, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (2.56,2.56,2.56)
# time for set_epsilon = 2.06352 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0.34202,-0.939693,0) = 1 after 246 iters
# MPB solved for frequency_1(0.34202,-0.939693,0) = 1 after 1 iters
# Meep progress: 3.42/60.0 = 5.7% done in 4.0s, 66.4s to go
# on time step 171 (time=3.42), 0.0234681 s/step
# Meep progress: 7.16/60.0 = 11.9% done in 8.0s, 59.1s to go
# on time step 358 (time=7.16), 0.0213932 s/step
# Meep progress: 10.74/60.0 = 17.9% done in 12.0s, 55.2s to go
# on time step 537 (time=10.74), 0.0224144 s/step
# Meep progress: 14.16/60.0 = 23.6% done in 16.0s, 51.9s to go
# on time step 708 (time=14.16), 0.0234188 s/step
# Meep progress: 17.96/60.0 = 29.9% done in 20.0s, 46.9s to go
# on time step 898 (time=17.96), 0.0210877 s/step
# Meep progress: 22.18/60.0 = 37.0% done in 24.1s, 41.0s to go
# on time step 1109 (time=22.18), 0.0190265 s/step
# Meep progress: 26.02/60.0 = 43.4% done in 28.1s, 36.7s to go
# on time step 1301 (time=26.02), 0.0209431 s/step
# Meep progress: 29.8/60.0 = 49.7% done in 32.1s, 32.5s to go
# on time step 1490 (time=29.8), 0.0212454 s/step
# Meep progress: 34.02/60.0 = 56.7% done in 36.1s, 27.6s to go
# on time step 1701 (time=34.02), 0.0190367 s/step
# Meep progress: 38.4/60.0 = 64.0% done in 40.1s, 22.6s to go
# on time step 1920 (time=38.4), 0.0182893 s/step
# Meep progress: 42.88/60.0 = 71.5% done in 44.1s, 17.6s to go
# on time step 2144 (time=42.88), 0.0178769 s/step
# Meep progress: 46.82/60.0 = 78.0% done in 48.1s, 13.6s to go
# on time step 2341 (time=46.82), 0.0203803 s/step
# Meep progress: 50.44/60.0 = 84.1% done in 52.1s, 9.9s to go
# on time step 2522 (time=50.44), 0.0221427 s/step
# Meep progress: 54.120000000000005/60.0 = 90.2% done in 56.2s, 6.1s to go
# on time step 2706 (time=54.12), 0.0217806 s/step
# Meep progress: 57.32/60.0 = 95.5% done in 60.2s, 2.8s to go
# on time step 2866 (time=57.32), 0.025112 s/step
# run 0 finished at t = 60.0 (3000 timesteps)
# Flux near top PML boundary: 46.462706
# Flux at y = sy/2 - (pml_thickness + 2.1): -2236.534528
# Flux at y = 3: -1682.401328
# Flux at y = -0.1: -1447.482144
# Flux near bottom boundary: -517.383781
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000172138 s
# Working in 2D dimensions.
# Computational cell is 64 x 32 x 0 with resolution 25
#      block, center = (0,-8,0)
#           size (1e+20,16,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.56,2.56,2.56)
#      cylinder, center = (0,1,0)
#           radius 1, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (2.56,2.56,2.56)
# time for set_epsilon = 2.93163 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0.707107,-0.707107,0) = 1 after 198 iters
# Meep progress: 3.94/60.0 = 6.6% done in 4.0s, 57.1s to go
# on time step 197 (time=3.94), 0.0203758 s/step
# Meep progress: 8.1/60.0 = 13.5% done in 8.0s, 51.4s to go
# on time step 405 (time=8.1), 0.0192954 s/step
# Meep progress: 11.98/60.0 = 20.0% done in 12.0s, 48.2s to go
# on time step 599 (time=11.98), 0.0206408 s/step
# Meep progress: 15.58/60.0 = 26.0% done in 16.0s, 45.7s to go
# on time step 779 (time=15.58), 0.0222524 s/step
# Meep progress: 19.36/60.0 = 32.3% done in 20.0s, 42.1s to go
# on time step 968 (time=19.36), 0.0212121 s/step
# Meep progress: 23.240000000000002/60.0 = 38.7% done in 24.1s, 38.1s to go
# on time step 1162 (time=23.24), 0.0206748 s/step
# Meep progress: 26.94/60.0 = 44.9% done in 28.1s, 34.5s to go
# on time step 1347 (time=26.94), 0.0217254 s/step
# Meep progress: 30.52/60.0 = 50.9% done in 32.1s, 31.0s to go
# on time step 1526 (time=30.52), 0.0224142 s/step
# Meep progress: 34.44/60.0 = 57.4% done in 36.1s, 26.8s to go
# on time step 1722 (time=34.44), 0.0204898 s/step
# Meep progress: 37.92/60.0 = 63.2% done in 40.1s, 23.4s to go
# on time step 1896 (time=37.92), 0.0230417 s/step
# Meep progress: 41.12/60.0 = 68.5% done in 44.1s, 20.3s to go
# on time step 2056 (time=41.12), 0.0250155 s/step
# Meep progress: 44.660000000000004/60.0 = 74.4% done in 48.1s, 16.5s to go
# on time step 2233 (time=44.66), 0.0226702 s/step
# Meep progress: 48.28/60.0 = 80.5% done in 52.1s, 12.7s to go
# on time step 2414 (time=48.28), 0.0221203 s/step
# Meep progress: 52.04/60.0 = 86.7% done in 56.2s, 8.6s to go
# on time step 2602 (time=52.04), 0.0213307 s/step
# Meep progress: 55.800000000000004/60.0 = 93.0% done in 60.2s, 4.5s to go
# on time step 2790 (time=55.8), 0.0213002 s/step
# Meep progress: 59.34/60.0 = 98.9% done in 64.2s, 0.7s to go
# on time step 2967 (time=59.34), 0.0227405 s/step
# run 0 finished at t = 60.0 (3000 timesteps)
# Flux near top PML boundary: 59.110341
# Flux at y = sy/2 - (pml_thickness + 2.1): -2194.976243
# Flux at y = 3: -1458.691703
# Flux at y = -0.1: -1161.136189
# Flux near bottom boundary: -327.955592
# -----------
# Initializing structure...
# time for choose_chunkdivision = 9.799e-05 s
# Working in 2D dimensions.
# Computational cell is 64 x 32 x 0 with resolution 25
#      block, center = (0,-8,0)
#           size (1e+20,16,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.56,2.56,2.56)
#      cylinder, center = (0,1,0)
#           radius 1, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (2.56,2.56,2.56)
# time for set_epsilon = 2.39744 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0.906308,-0.422618,0) = 1 after 112 iters
# Meep progress: 3.4/60.0 = 5.7% done in 4.0s, 66.8s to go
# on time step 170 (time=3.4), 0.0236081 s/step
# Meep progress: 6.96/60.0 = 11.6% done in 8.0s, 61.2s to go
# on time step 348 (time=6.96), 0.022539 s/step
# Meep progress: 10.6/60.0 = 17.7% done in 12.1s, 56.2s to go
# on time step 530 (time=10.6), 0.0221235 s/step
# Meep progress: 14.58/60.0 = 24.3% done in 16.1s, 50.0s to go
# on time step 729 (time=14.58), 0.0201278 s/step
# Meep progress: 17.88/60.0 = 29.8% done in 20.1s, 47.3s to go
# on time step 894 (time=17.88), 0.0242851 s/step
# Meep progress: 21.3/60.0 = 35.5% done in 24.1s, 43.8s to go
# on time step 1065 (time=21.3), 0.0235196 s/step
# Meep progress: 24.7/60.0 = 41.2% done in 28.1s, 40.1s to go
# on time step 1235 (time=24.7), 0.0235393 s/step
# Meep progress: 28.62/60.0 = 47.7% done in 32.1s, 35.2s to go
# on time step 1431 (time=28.62), 0.0204203 s/step
# Meep progress: 32.3/60.0 = 53.8% done in 36.1s, 31.0s to go
# on time step 1615 (time=32.3), 0.0217628 s/step
# Meep progress: 36.06/60.0 = 60.1% done in 40.1s, 26.6s to go
# on time step 1804 (time=36.08), 0.0212654 s/step
# Meep progress: 39.84/60.0 = 66.4% done in 44.1s, 22.3s to go
# on time step 1993 (time=39.86), 0.0212253 s/step
# Meep progress: 43.96/60.0 = 73.3% done in 48.1s, 17.6s to go
# on time step 2199 (time=43.98), 0.0194683 s/step
# Meep progress: 48.02/60.0 = 80.0% done in 52.1s, 13.0s to go
# on time step 2402 (time=48.04), 0.0197099 s/step
# Meep progress: 51.86/60.0 = 86.4% done in 56.1s, 8.8s to go
# on time step 2593 (time=51.86), 0.0209572 s/step
# Meep progress: 56.02/60.0 = 93.4% done in 60.2s, 4.3s to go
# on time step 2801 (time=56.02), 0.0192564 s/step
# Meep progress: 59.76/60.0 = 99.6% done in 64.2s, 0.3s to go
# on time step 2988 (time=59.76), 0.0214738 s/step
# run 0 finished at t = 60.0 (3000 timesteps)
# Flux near top PML boundary: 14.089507
# Flux at y = sy/2 - (pml_thickness + 2.1): -2204.539778
# Flux at y = 3: -1053.131052
# Flux at y = -0.1: -600.606347
# Flux near bottom boundary: -79.981358

# %%
for rot_angle in np.radians([65, 85, 89]):
    run_sim(rot_angle)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000162125 s
# Working in 2D dimensions.
# Computational cell is 64 x 32 x 0 with resolution 25
#      block, center = (0,-8,0)
#           size (1e+20,16,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (2.56,2.56,2.56)
#      cylinder, center = (0,1,0)
#           radius 1, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (2.56,2.56,2.56)
# time for set_epsilon = 2.49176 s
# -----------
# Meep: using complex fields.
# MPB solved for frequency_1(0.906308,-0.422618,0) = 1 after 112 iters
# Meep progress: 2.74/60.0 = 4.6% done in 4.0s, 83.8s to go
# on time step 137 (time=2.74), 0.0292576 s/step
# Meep progress: 5.22/60.0 = 8.7% done in 8.0s, 84.1s to go
# on time step 261 (time=5.22), 0.0322958 s/step
# Meep progress: 8.700000000000001/60.0 = 14.5% done in 12.0s, 70.9s to go
# on time step 435 (time=8.7), 0.0230608 s/step
# Meep progress: 11.94/60.0 = 19.9% done in 16.1s, 64.6s to go
# on time step 597 (time=11.94), 0.024833 s/step
# Meep progress: 15.280000000000001/60.0 = 25.5% done in 20.1s, 58.7s to go
# on time step 764 (time=15.28), 0.0240473 s/step
# Meep progress: 18.78/60.0 = 31.3% done in 24.1s, 52.9s to go
# on time step 939 (time=18.78), 0.0229337 s/step
# Meep progress: 22.3/60.0 = 37.2% done in 28.1s, 47.5s to go
# on time step 1115 (time=22.3), 0.0228244 s/step
# Meep progress: 25.26/60.0 = 42.1% done in 32.1s, 44.2s to go
# on time step 1263 (time=25.26), 0.0271224 s/step
# Meep progress: 28.12/60.0 = 46.9% done in 36.1s, 41.0s to go
# on time step 1406 (time=28.12), 0.0281672 s/step
# Meep progress: 30.2/60.0 = 50.3% done in 40.2s, 39.6s to go
# on time step 1510 (time=30.2), 0.0386282 s/step
# Meep progress: 32.38/60.0 = 54.0% done in 44.2s, 37.7s to go
# on time step 1619 (time=32.38), 0.0370194 s/step
# Meep progress: 34.5/60.0 = 57.5% done in 48.2s, 35.6s to go
# on time step 1725 (time=34.5), 0.03786 s/step
# Meep progress: 36.660000000000004/60.0 = 61.1% done in 52.2s, 33.3s to go
# on time step 1833 (time=36.66), 0.0372026 s/step
# Meep progress: 38.88/60.0 = 64.8% done in 56.3s, 30.6s to go
# on time step 1944 (time=38.88), 0.0362495 s/step
# Meep progress: 41.1/60.0 = 68.5% done in 60.3s, 27.7s to go
# on time step 2055 (time=41.1), 0.0361093 s/step
# Meep progress: 43.18/60.0 = 72.0% done in 64.3s, 25.0s to go
# on time step 2159 (time=43.18), 0.0387443 s/step
# Meep progress: 45.160000000000004/60.0 = 75.3% done in 68.3s, 22.4s to go
# on time step 2258 (time=45.16), 0.0404448 s/step
# Meep progress: 47.34/60.0 = 78.9% done in 72.3s, 19.3s to go
# on time step 2367 (time=47.34), 0.0367752 s/step
# Meep progress: 49.24/60.0 = 82.1% done in 76.3s, 16.7s to go
# on time step 2462 (time=49.24), 0.0421944 s/step
# Meep progress: 51.800000000000004/60.0 = 86.3% done in 80.3s, 12.7s to go
# on time step 2590 (time=51.8), 0.0313504 s/step
# Meep progress: 55.18/60.0 = 92.0% done in 84.3s, 7.4s to go
# on time step 2759 (time=55.18), 0.0236949 s/step

# %% [markdown]
# Note that this example involves a `ContinuousSource` for the time profile. For a pulsed source, the oblique planewave is incident at a given angle for only a *single* frequency component of the source. This is a fundamental feature of FDTD simulations and not of Meep per se. Thus, to simulate an incident planewave at multiple angles for a given frequency ω, you will need to do separate simulations involving different values of $\vec{k}$ (`k_point`) since each set of ($\vec{k}$,ω) specifying the Bloch-periodic boundaries and the frequency of the source will produce a different angle of the planewave. For more details, refer to Section 4.5 ("Efficient Frequency-Angle Coverage") in [Chapter 4](https://arxiv.org/abs/1301.5366) ("Electromagnetic Wave Source Conditions") of [Advances in FDTD Computational Electrodynamics: Photonics and Nanotechnology](https://www.amazon.com/Advances-FDTD-Computational-Electrodynamics-Nanotechnology/dp/1608071707).
