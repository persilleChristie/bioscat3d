# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
import json
import os
import math

keyword = "NormalNewGeom"
json_dir = "/home/tripleskull/bioscat3d/json"
path = os.path.join(json_dir, f"surfaceParams{keyword}.json")
def load_params(path = path):
    with open(path, "r") as f:
        return json.load(f)
params = load_params()

# Cell and resolution
pml_thickness = params["pml_thickness"]
monitor_size = params["monitor_size"]
half_x = params["halfWidth_x"]
half_y = params["halfWidth_y"]
half_z = params["halfWidth_z"]
cell_size = mp.Vector3(2*half_x + 2*pml_thickness,
                       2*half_y + 2*pml_thickness,
                       2*half_z + 2*pml_thickness)

omega = params["omega"]
betas = params["betas"]
# Material
epsilon1 = params["epsilon1"] 
substrate = mp.Medium(epsilon = epsilon1)
bumps = params["bumpData"]

## Must be at least 8 pixels per smallest wavelength, i.e. np.floor(8/wvl_min)
resolution = params["resolution"]

frq = params["omega"]/(2*np.pi)
wvl = 1 / frq

pml_layers = [mp.PML(thickness=pml_thickness)] 

def make_source(component):
    return [mp.Source(
        mp.GaussianSource(frequency=frq, fwidth=1, is_integrated=True),
        center=mp.Vector3(0, 0, half_z - 0.5),
        size=mp.Vector3(cell_size[0], cell_size[1], 0),
        component=component
    )]

def run_meep_simulation(sources):
    # Reference simulation (no bumps)
    sim = mp.Simulation(
        resolution=resolution,
        cell_size=cell_size,
        boundary_layers=pml_layers,
        sources=sources,
        k_point=mp.Vector3(),
    )

    box1_x1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(x=-monitor_size/2), size=mp.Vector3(0, monitor_size, monitor_size)))
    box1_x2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(x=+monitor_size/2), size=mp.Vector3(0, monitor_size, monitor_size)))
    box1_y1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(y=-monitor_size/2), size=mp.Vector3(monitor_size, 0, monitor_size)))
    box1_y2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(y=+monitor_size/2), size=mp.Vector3(monitor_size, 0, monitor_size)))
    box1_z1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(z=-monitor_size/2), size=mp.Vector3(monitor_size, monitor_size, 0)))
    box1_z2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(z=+monitor_size/2), size=mp.Vector3(monitor_size, monitor_size, 0)))


    sim.run(until_after_sources=60)

    box_x1 = mp.get_fluxes(box1_x1)
    box_x2 = mp.get_fluxes(box1_x2)
    box_y1 = mp.get_fluxes(box1_y1)
    box_y2 = mp.get_fluxes(box1_y2)
    box_z1 = mp.get_fluxes(box1_z1)
    box_z2 = mp.get_fluxes(box1_z2)

    # Save individual components for later printing/plotting
    inc_flux_components = {
        "X1": np.asarray(box_x1)[0],
        "X2": np.asarray(box_x2)[0],
        "Y1": np.asarray(box_y1)[0],
        "Y2": np.asarray(box_y2)[0],
        "Z1": np.asarray(box_z1)[0],
        "Z2": np.asarray(box_z2)[0],
    }

    box_x1_data = sim.get_flux_data(box1_x1)
    box_x2_data = sim.get_flux_data(box1_x2)
    box_y1_data = sim.get_flux_data(box1_y1)
    box_y2_data = sim.get_flux_data(box1_y2)
    box_z1_data = sim.get_flux_data(box1_z1)
    box_z2_data = sim.get_flux_data(box1_z2)

    sim.reset_meep()

# Structured simulation (with bumps) and edges
    def material_function(p):
        if abs(p.x) >= 1 or abs(p.y) >= 1:
            return mp.air
        z_surface = 0
        for b in bumps:
            dx = p.x - b["x0"]
            dy = p.y - b["y0"]
            exponent = - (dx**2 + dy**2) / (2 * b["sigma"]**2)
            z_surface += b["height"] * math.exp(exponent)
        return substrate if p.z + 1.5 < z_surface else mp.air



    sim = mp.Simulation(
        resolution=resolution,
        cell_size=cell_size,
        boundary_layers=pml_layers,
        sources=sources,
        k_point=mp.Vector3(),
        default_material=material_function,
    )

    box2_x1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(x=-monitor_size/2), size=mp.Vector3(0, monitor_size, monitor_size)))
    box2_x2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(x=+monitor_size/2), size=mp.Vector3(0, monitor_size, monitor_size)))
    box2_y1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(y=-monitor_size/2), size=mp.Vector3(monitor_size, 0, monitor_size)))
    box2_y2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(y=+monitor_size/2), size=mp.Vector3(monitor_size, 0, monitor_size)))
    box2_z1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(z=-monitor_size/2), size=mp.Vector3(monitor_size, monitor_size, 0)))
    box2_z2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(z=+monitor_size/2), size=mp.Vector3(monitor_size, monitor_size, 0)))

    sim.load_minus_flux_data(box2_x1, box_x1_data)
    sim.load_minus_flux_data(box2_x2, box_x2_data)
    sim.load_minus_flux_data(box2_y1, box_y1_data)
    sim.load_minus_flux_data(box2_y2, box_y2_data)
    sim.load_minus_flux_data(box2_z1, box_z1_data)
    sim.load_minus_flux_data(box2_z2, box_z2_data)

    sim.run(until_after_sources=60) # maybe 20 is too little? 

    box_x1_flux = mp.get_fluxes(box2_x1)
    box_x2_flux = mp.get_fluxes(box2_x2)
    box_y1_flux = mp.get_fluxes(box2_y1)
    box_y2_flux = mp.get_fluxes(box2_y2)
    box_z1_flux = mp.get_fluxes(box2_z1)
    box_z2_flux = mp.get_fluxes(box2_z2)

    # Save individual components for later printing/plotting
    scatt_flux_components = {
        "X1": np.asarray(box_x1_flux)[0],
        "X2": np.asarray(box_x2_flux)[0],
        "Y1": np.asarray(box_y1_flux)[0],
        "Y2": np.asarray(box_y2_flux)[0],
        "Z1": np.asarray(box_z1_flux)[0],
        "Z2": np.asarray(box_z2_flux)[0],
    }
    return scatt_flux_components, inc_flux_components

flux_results = []
inc_flux_results = []

def print_parameters():
    print("Simulation Parameters:")
    print(f"  omega      = {omega}")
    print(f"  frequency  = {frq}")
    print(f"  wavelength = {wvl}")
    print(f"  resolution = {resolution}")
    print(f"  cell_size  = ({cell_size.x}, {cell_size.y}, {cell_size.z})")
    print(f"  PML thickness = {pml_thickness}")
    print(f"  monitor size  = {monitor_size}")
    print(f"  substrate ε   = {epsilon1}")
    print(f"  number of bumps = {len(bumps)}")
    print("  betas (deg)    =", [round(np.degrees(b), 2) for b in betas])
    print()

print_parameters()


for beta in betas:
    print("beta = " + str(beta))
    cos2 = np.cos(beta)**2
    sin2 = np.sin(beta)**2

    sources_1 = make_source(mp.Ey)
    sources_2 = make_source(mp.Ex)
    
    flux_1, inc_flux_1 = run_meep_simulation(sources_1)
    flux_2, inc_flux_2 = run_meep_simulation(sources_2)

    # Combine flux components manually
    flux_combined = {
        "beta": np.degrees(beta),
        "X1": cos2 * flux_1["X1"] + sin2 * flux_2["X1"],
        "X2": cos2 * flux_1["X2"] + sin2 * flux_2["X2"],
        "Y1": cos2 * flux_1["Y1"] + sin2 * flux_2["Y1"],
        "Y2": cos2 * flux_1["Y2"] + sin2 * flux_2["Y2"],
        "Z1": cos2 * flux_1["Z1"] + sin2 * flux_2["Z1"],
        "Z2": cos2 * flux_1["Z2"] + sin2 * flux_2["Z2"],
    }
    
    flux_results.append(flux_combined)
    
    # Combine flux components manually
    inc_flux_combined = {
        "beta": np.degrees(beta),
        "X1": cos2 * inc_flux_1["X1"] + sin2 * inc_flux_2["X1"],
        "X2": cos2 * inc_flux_1["X2"] + sin2 * inc_flux_2["X2"],
        "Y1": cos2 * inc_flux_1["Y1"] + sin2 * inc_flux_2["Y1"],
        "Y2": cos2 * inc_flux_1["Y2"] + sin2 * inc_flux_2["Y2"],
        "Z1": cos2 * inc_flux_1["Z1"] + sin2 * inc_flux_2["Z1"],
        "Z2": cos2 * inc_flux_1["Z2"] + sin2 * inc_flux_2["Z2"],
    }

    inc_flux_results.append(inc_flux_combined)
# Out:
# Simulation Parameters:
#   omega      = 1.0
#   frequency  = 0.15915494309189535
#   wavelength = 6.283185307179586
#   resolution = 10
#   cell_size  = (7.0, 7.0, 8.0)
#   PML thickness = 2
#   monitor size  = 1
#   substrate ε   = 2.56
#   number of bumps = 3
#   betas (deg)    = [0.0, 30.0, 60.0, 90.0]
#
# beta = 0.0
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00207305 s
# Working in 3D dimensions.
# Computational cell is 7 x 7 x 8 with resolution 10
# time for set_epsilon = 1.005 s
# -----------
# Meep progress: 3.5/70.0 = 5.0% done in 4.0s, 76.3s to go
# on time step 70 (time=3.5), 0.0573467 s/step
# Meep progress: 14.350000000000001/70.0 = 20.5% done in 8.0s, 31.1s to go
# on time step 287 (time=14.35), 0.0185025 s/step
# Meep progress: 25.1/70.0 = 35.9% done in 12.0s, 21.5s to go
# on time step 502 (time=25.1), 0.0186481 s/step
# Meep progress: 35.800000000000004/70.0 = 51.1% done in 16.1s, 15.3s to go
# on time step 716 (time=35.8), 0.018746 s/step
# Meep progress: 46.650000000000006/70.0 = 66.6% done in 20.1s, 10.0s to go
# on time step 933 (time=46.65), 0.0184353 s/step
# Meep progress: 57.75/70.0 = 82.5% done in 24.1s, 5.1s to go
# on time step 1155 (time=57.75), 0.0180226 s/step
# Meep progress: 68.9/70.0 = 98.4% done in 28.1s, 0.4s to go
# on time step 1378 (time=68.9), 0.0179992 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000329018 s
# Working in 3D dimensions.
# Computational cell is 7 x 7 x 8 with resolution 10
# time for set_epsilon = 6.49685 s
# -----------
# Meep progress: 6.65/70.0 = 9.5% done in 4.0s, 38.2s to go
# on time step 133 (time=6.65), 0.0301526 s/step
# Meep progress: 16.2/70.0 = 23.1% done in 8.0s, 26.6s to go
# on time step 324 (time=16.2), 0.0209907 s/step
# Meep progress: 26.200000000000003/70.0 = 37.4% done in 12.0s, 20.1s to go
# on time step 524 (time=26.2), 0.0200666 s/step
# Meep progress: 37.45/70.0 = 53.5% done in 16.0s, 13.9s to go
# on time step 749 (time=37.45), 0.0177785 s/step
# Meep progress: 47.550000000000004/70.0 = 67.9% done in 20.1s, 9.5s to go
# on time step 951 (time=47.55), 0.0198971 s/step
# Meep progress: 57.85/70.0 = 82.6% done in 24.1s, 5.1s to go
# on time step 1157 (time=57.85), 0.0194213 s/step
# Meep progress: 68.2/70.0 = 97.4% done in 28.1s, 0.7s to go
# on time step 1364 (time=68.2), 0.0193695 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000294924 s
# Working in 3D dimensions.
# Computational cell is 7 x 7 x 8 with resolution 10
# time for set_epsilon = 0.658221 s
# -----------
# Meep progress: 5.1000000000000005/70.0 = 7.3% done in 4.0s, 51.3s to go
# on time step 102 (time=5.1), 0.0395322 s/step
# Meep progress: 14.200000000000001/70.0 = 20.3% done in 8.0s, 31.6s to go
# on time step 284 (time=14.2), 0.0219995 s/step
# Meep progress: 22.950000000000003/70.0 = 32.8% done in 12.1s, 24.7s to go
# on time step 459 (time=22.95), 0.022923 s/step
# Meep progress: 31.3/70.0 = 44.7% done in 16.1s, 19.9s to go
# on time step 626 (time=31.3), 0.0240423 s/step
# Meep progress: 40.0/70.0 = 57.1% done in 20.1s, 15.1s to go
# on time step 800 (time=40), 0.0230196 s/step
# Meep progress: 49.050000000000004/70.0 = 70.1% done in 24.1s, 10.3s to go
# on time step 981 (time=49.05), 0.0221834 s/step
# Meep progress: 58.7/70.0 = 83.9% done in 28.1s, 5.4s to go
# on time step 1174 (time=58.7), 0.0207779 s/step
# Meep progress: 67.55/70.0 = 96.5% done in 32.1s, 1.2s to go
# on time step 1351 (time=67.55), 0.0226904 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000356913 s
# Working in 3D dimensions.
# Computational cell is 7 x 7 x 8 with resolution 10
# time for set_epsilon = 8.76186 s
# -----------
# Meep progress: 5.800000000000001/70.0 = 8.3% done in 4.0s, 44.4s to go
# on time step 116 (time=5.8), 0.0345764 s/step
# Meep progress: 16.900000000000002/70.0 = 24.1% done in 8.0s, 25.2s to go
# on time step 338 (time=16.9), 0.0180459 s/step
# Meep progress: 26.5/70.0 = 37.9% done in 12.0s, 19.7s to go
# on time step 530 (time=26.5), 0.0208931 s/step
# Meep progress: 36.45/70.0 = 52.1% done in 16.0s, 14.8s to go
# on time step 729 (time=36.45), 0.0201537 s/step
# Meep progress: 45.650000000000006/70.0 = 65.2% done in 20.0s, 10.7s to go
# on time step 914 (time=45.7), 0.0217142 s/step
# Meep progress: 55.45/70.0 = 79.2% done in 24.0s, 6.3s to go
# on time step 1110 (time=55.5), 0.0204917 s/step
# Meep progress: 65.5/70.0 = 93.6% done in 28.1s, 1.9s to go
# on time step 1312 (time=65.6), 0.0198724 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 0.5235987755982988
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000589132 s
# Working in 3D dimensions.
# Computational cell is 7 x 7 x 8 with resolution 10
# time for set_epsilon = 0.745804 s
# -----------
# Meep progress: 5.3500000000000005/70.0 = 7.6% done in 4.0s, 48.5s to go
# on time step 107 (time=5.35), 0.0375034 s/step
# Meep progress: 14.55/70.0 = 20.8% done in 8.0s, 30.6s to go
# on time step 291 (time=14.55), 0.0217763 s/step
# Meep progress: 26.35/70.0 = 37.6% done in 12.0s, 19.9s to go
# on time step 527 (time=26.35), 0.0169682 s/step
# Meep progress: 35.95/70.0 = 51.4% done in 16.0s, 15.2s to go
# on time step 719 (time=35.95), 0.0208921 s/step
# Meep progress: 46.300000000000004/70.0 = 66.1% done in 20.1s, 10.3s to go
# on time step 926 (time=46.3), 0.0193826 s/step
# Meep progress: 55.550000000000004/70.0 = 79.4% done in 24.1s, 6.3s to go
# on time step 1111 (time=55.55), 0.0217357 s/step
# Meep progress: 65.60000000000001/70.0 = 93.7% done in 28.1s, 1.9s to go
# on time step 1312 (time=65.6), 0.019946 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000383139 s
# Working in 3D dimensions.
# Computational cell is 7 x 7 x 8 with resolution 10
# time for set_epsilon = 7.87755 s
# -----------
# Meep progress: 6.4/70.0 = 9.1% done in 4.0s, 39.8s to go
# on time step 128 (time=6.4), 0.0313239 s/step
# Meep progress: 16.7/70.0 = 23.9% done in 8.0s, 25.6s to go
# on time step 334 (time=16.7), 0.0194827 s/step
# Meep progress: 26.900000000000002/70.0 = 38.4% done in 12.0s, 19.3s to go
# on time step 538 (time=26.9), 0.0197193 s/step
# Meep progress: 36.25/70.0 = 51.8% done in 16.0s, 14.9s to go
# on time step 726 (time=36.3), 0.0213778 s/step
# Meep progress: 47.150000000000006/70.0 = 67.4% done in 20.1s, 9.7s to go
# on time step 944 (time=47.2), 0.0184002 s/step
# Meep progress: 57.75/70.0 = 82.5% done in 24.1s, 5.1s to go
# on time step 1156 (time=57.8), 0.0189003 s/step
# Meep progress: 67.25/70.0 = 96.1% done in 28.1s, 1.1s to go
# on time step 1346 (time=67.3), 0.0211067 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00062108 s
# Working in 3D dimensions.
# Computational cell is 7 x 7 x 8 with resolution 10
# time for set_epsilon = 1.02575 s
# -----------
# Meep progress: 2.0500000000000003/70.0 = 2.9% done in 4.0s, 133.4s to go
# on time step 41 (time=2.05), 0.0981688 s/step
# Meep progress: 10.950000000000001/70.0 = 15.6% done in 8.1s, 43.4s to go
# on time step 219 (time=10.95), 0.0226234 s/step
# Meep progress: 19.400000000000002/70.0 = 27.7% done in 12.1s, 31.5s to go
# on time step 388 (time=19.4), 0.0238216 s/step
# Meep progress: 28.25/70.0 = 40.4% done in 16.1s, 23.8s to go
# on time step 565 (time=28.25), 0.0226694 s/step
# Meep progress: 39.2/70.0 = 56.0% done in 20.1s, 15.8s to go
# on time step 784 (time=39.2), 0.0182667 s/step
# Meep progress: 49.650000000000006/70.0 = 70.9% done in 24.1s, 9.9s to go
# on time step 993 (time=49.65), 0.0191762 s/step
# Meep progress: 58.7/70.0 = 83.9% done in 28.1s, 5.4s to go
# on time step 1174 (time=58.7), 0.022208 s/step
# Meep progress: 67.55/70.0 = 96.5% done in 32.1s, 1.2s to go
# on time step 1351 (time=67.55), 0.0226344 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000437021 s
# Working in 3D dimensions.
# Computational cell is 7 x 7 x 8 with resolution 10
# time for set_epsilon = 10.2283 s
# -----------
# Meep progress: 6.300000000000001/70.0 = 9.0% done in 4.0s, 40.6s to go
# on time step 126 (time=6.3), 0.0318945 s/step
# Meep progress: 17.0/70.0 = 24.3% done in 8.0s, 25.0s to go
# on time step 340 (time=17), 0.0187133 s/step
# Meep progress: 26.150000000000002/70.0 = 37.4% done in 12.1s, 20.2s to go
# on time step 523 (time=26.15), 0.0220228 s/step
# Meep progress: 34.050000000000004/70.0 = 48.6% done in 16.1s, 17.0s to go
# on time step 681 (time=34.05), 0.02538 s/step
# Meep progress: 42.400000000000006/70.0 = 60.6% done in 20.1s, 13.1s to go
# on time step 848 (time=42.4), 0.0239658 s/step
# Meep progress: 49.95/70.0 = 71.4% done in 24.1s, 9.7s to go
# on time step 999 (time=49.95), 0.0265089 s/step
# Meep progress: 59.25/70.0 = 84.6% done in 28.1s, 5.1s to go
# on time step 1185 (time=59.25), 0.0215538 s/step
# Meep progress: 67.35000000000001/70.0 = 96.2% done in 32.1s, 1.3s to go
# on time step 1347 (time=67.35), 0.0246954 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 1.0471975511965976
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000472069 s
# Working in 3D dimensions.
# Computational cell is 7 x 7 x 8 with resolution 10
# time for set_epsilon = 0.789484 s
# -----------
# Meep progress: 3.85/70.0 = 5.5% done in 4.0s, 69.1s to go
# on time step 77 (time=3.85), 0.0522377 s/step
# Meep progress: 12.3/70.0 = 17.6% done in 8.0s, 37.7s to go
# on time step 246 (time=12.3), 0.0237004 s/step
# Meep progress: 20.55/70.0 = 29.4% done in 12.0s, 29.0s to go
# on time step 411 (time=20.55), 0.0243454 s/step
# Meep progress: 29.1/70.0 = 41.6% done in 16.0s, 22.6s to go
# on time step 583 (time=29.15), 0.0233692 s/step
# Meep progress: 37.550000000000004/70.0 = 53.6% done in 20.1s, 17.3s to go
# on time step 752 (time=37.6), 0.0236716 s/step
# Meep progress: 45.95/70.0 = 65.6% done in 24.1s, 12.6s to go
# on time step 920 (time=46), 0.0238853 s/step
# Meep progress: 54.75/70.0 = 78.2% done in 28.1s, 7.8s to go
# on time step 1095 (time=54.75), 0.0228633 s/step
# Meep progress: 63.6/70.0 = 90.9% done in 32.1s, 3.2s to go
# on time step 1272 (time=63.6), 0.0226126 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00148988 s
# Working in 3D dimensions.
# Computational cell is 7 x 7 x 8 with resolution 10
# time for set_epsilon = 11.2942 s
# -----------
# Meep progress: 3.95/70.0 = 5.6% done in 4.0s, 67.1s to go
# on time step 79 (time=3.95), 0.0508353 s/step
# Meep progress: 12.25/70.0 = 17.5% done in 8.0s, 37.9s to go
# on time step 245 (time=12.25), 0.0242026 s/step
# Meep progress: 21.35/70.0 = 30.5% done in 12.1s, 27.5s to go
# on time step 427 (time=21.35), 0.0220739 s/step
# Meep progress: 29.950000000000003/70.0 = 42.8% done in 16.1s, 21.5s to go
# on time step 599 (time=29.95), 0.0233427 s/step
# Meep progress: 38.5/70.0 = 55.0% done in 20.1s, 16.4s to go
# on time step 770 (time=38.5), 0.0235074 s/step
# Meep progress: 48.800000000000004/70.0 = 69.7% done in 24.1s, 10.5s to go
# on time step 977 (time=48.85), 0.0194014 s/step
# Meep progress: 60.85/70.0 = 86.9% done in 28.1s, 4.2s to go
# on time step 1218 (time=60.9), 0.0166489 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000360012 s
# Working in 3D dimensions.
# Computational cell is 7 x 7 x 8 with resolution 10
# time for set_epsilon = 0.55477 s
# -----------
# Meep progress: 7.050000000000001/70.0 = 10.1% done in 4.0s, 35.7s to go
# on time step 141 (time=7.05), 0.0283892 s/step
# Meep progress: 17.7/70.0 = 25.3% done in 8.0s, 23.7s to go
# on time step 354 (time=17.7), 0.018865 s/step
# Meep progress: 28.700000000000003/70.0 = 41.0% done in 12.0s, 17.3s to go
# on time step 574 (time=28.7), 0.0182135 s/step
# Meep progress: 41.400000000000006/70.0 = 59.1% done in 16.0s, 11.1s to go
# on time step 828 (time=41.4), 0.0157848 s/step
# Meep progress: 53.75/70.0 = 76.8% done in 20.1s, 6.1s to go
# on time step 1075 (time=53.75), 0.0162433 s/step
# Meep progress: 65.55/70.0 = 93.6% done in 24.1s, 1.6s to go
# on time step 1311 (time=65.55), 0.0169743 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000293016 s
# Working in 3D dimensions.
# Computational cell is 7 x 7 x 8 with resolution 10
# time for set_epsilon = 7.40406 s
# -----------
# Meep progress: 6.65/70.0 = 9.5% done in 4.0s, 38.2s to go
# on time step 133 (time=6.65), 0.0301664 s/step
# Meep progress: 17.5/70.0 = 25.0% done in 8.0s, 24.1s to go
# on time step 350 (time=17.5), 0.0185023 s/step
# Meep progress: 29.700000000000003/70.0 = 42.4% done in 12.0s, 16.3s to go
# on time step 594 (time=29.7), 0.0164542 s/step
# Meep progress: 40.900000000000006/70.0 = 58.4% done in 16.1s, 11.4s to go
# on time step 818 (time=40.9), 0.0179218 s/step
# Meep progress: 52.150000000000006/70.0 = 74.5% done in 20.1s, 6.9s to go
# on time step 1043 (time=52.15), 0.0178487 s/step
# Meep progress: 63.5/70.0 = 90.7% done in 24.1s, 2.5s to go
# on time step 1270 (time=63.5), 0.0176349 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 1.5707963267948966
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00032711 s
# Working in 3D dimensions.
# Computational cell is 7 x 7 x 8 with resolution 10
# time for set_epsilon = 0.668893 s
# -----------
# Meep progress: 7.300000000000001/70.0 = 10.4% done in 4.0s, 34.4s to go
# on time step 146 (time=7.3), 0.0274217 s/step
# Meep progress: 18.75/70.0 = 26.8% done in 8.0s, 21.9s to go
# on time step 375 (time=18.75), 0.0174961 s/step
# Meep progress: 30.6/70.0 = 43.7% done in 12.0s, 15.5s to go
# on time step 612 (time=30.6), 0.0169178 s/step
# Meep progress: 42.7/70.0 = 61.0% done in 16.0s, 10.2s to go
# on time step 854 (time=42.7), 0.0165684 s/step
# Meep progress: 55.0/70.0 = 78.6% done in 20.0s, 5.5s to go
# on time step 1100 (time=55), 0.0162621 s/step
# Meep progress: 67.0/70.0 = 95.7% done in 24.0s, 1.1s to go
# on time step 1340 (time=67), 0.0166909 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000311136 s
# Working in 3D dimensions.
# Computational cell is 7 x 7 x 8 with resolution 10
# time for set_epsilon = 6.88916 s
# -----------
# Meep progress: 7.0/70.0 = 10.0% done in 4.0s, 36.1s to go
# on time step 140 (time=7), 0.0286715 s/step
# Meep progress: 18.35/70.0 = 26.2% done in 8.0s, 22.6s to go
# on time step 367 (time=18.35), 0.0176994 s/step
# Meep progress: 28.35/70.0 = 40.5% done in 12.0s, 17.7s to go
# on time step 567 (time=28.35), 0.0200232 s/step
# Meep progress: 38.650000000000006/70.0 = 55.2% done in 16.0s, 13.0s to go
# on time step 773 (time=38.65), 0.0194723 s/step
# Meep progress: 46.95/70.0 = 67.1% done in 20.1s, 9.8s to go
# on time step 939 (time=46.95), 0.0241044 s/step
# Meep progress: 52.0/70.0 = 74.3% done in 24.1s, 8.3s to go
# on time step 1040 (time=52), 0.039693 s/step
# Meep progress: 58.45/70.0 = 83.5% done in 28.1s, 5.6s to go
# on time step 1169 (time=58.45), 0.0312297 s/step
# Meep progress: 65.2/70.0 = 93.1% done in 32.1s, 2.4s to go
# on time step 1304 (time=65.2), 0.0297888 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00033617 s
# Working in 3D dimensions.
# Computational cell is 7 x 7 x 8 with resolution 10
# time for set_epsilon = 0.651561 s
# -----------
# Meep progress: 5.8500000000000005/70.0 = 8.4% done in 4.0s, 43.9s to go
# on time step 117 (time=5.85), 0.0342022 s/step
# Meep progress: 17.75/70.0 = 25.4% done in 8.0s, 23.6s to go
# on time step 355 (time=17.75), 0.0168203 s/step
# Meep progress: 31.0/70.0 = 44.3% done in 12.0s, 15.1s to go
# on time step 620 (time=31), 0.0151262 s/step
# Meep progress: 42.75/70.0 = 61.1% done in 16.0s, 10.2s to go
# on time step 855 (time=42.75), 0.0170554 s/step
# Meep progress: 52.95/70.0 = 75.6% done in 20.0s, 6.4s to go
# on time step 1059 (time=52.95), 0.0196342 s/step
# Meep progress: 62.85/70.0 = 89.8% done in 24.0s, 2.7s to go
# on time step 1257 (time=62.85), 0.0202255 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000382185 s
# Working in 3D dimensions.
# Computational cell is 7 x 7 x 8 with resolution 10
# time for set_epsilon = 7.15785 s
# -----------
# Meep progress: 7.3500000000000005/70.0 = 10.5% done in 4.0s, 34.2s to go
# on time step 147 (time=7.35), 0.0272633 s/step
# Meep progress: 19.1/70.0 = 27.3% done in 8.0s, 21.4s to go
# on time step 382 (time=19.1), 0.0170553 s/step
# Meep progress: 31.150000000000002/70.0 = 44.5% done in 12.0s, 15.0s to go
# on time step 623 (time=31.15), 0.0166355 s/step
# Meep progress: 43.35/70.0 = 61.9% done in 16.0s, 9.9s to go
# on time step 867 (time=43.35), 0.0164252 s/step
# Meep progress: 55.45/70.0 = 79.2% done in 20.0s, 5.3s to go
# on time step 1110 (time=55.5), 0.0165274 s/step
# Meep progress: 67.4/70.0 = 96.3% done in 24.1s, 0.9s to go
# on time step 1349 (time=67.45), 0.0167985 s/step
# run 0 finished at t = 70.0 (1400 timesteps)

# %%
d = flux_1
#d = flux_1
print("Size of dict:", len(d))
d
# Out:
# Size of dict: 6
# {'X1': -0.00011930456096904726,
#  'X2': 0.00011985869665378161,
#  'Y1': -0.00010835624425925076,
#  'Y2': 8.86425347750049e-05,
#  'Z1': 0.0007030701629965506,
#  'Z2': 0.0002666572961904504}

# %%
from tabulate import tabulate

# Convert to scalar values if needed
def scalar(val):
    return val.item() if isinstance(val, np.ndarray) else val



table_data = [
    [f"{scalar(row['beta']):.1f}°",
     f"{scalar(row['X1']):.5f}",
     f"{scalar(row['X2']):.5f}",
     f"{scalar(row['Y1']):.5f}",
     f"{scalar(row['Y2']):.5f}",
     f"{scalar(row['Z1']):.5f}",
     f"{scalar(row['Z2']):.5f}"]
    for row in flux_results
]

headers = ["β (°)", "X1 (−x)", "X2 (+x)", "Y1 (−y)", "Y2 (+y)", "Z1 (−z)", "Z2 (+z)"]
print(tabulate(table_data, headers=headers, tablefmt="github"))
# Out:
# | β (°)   |   X1 (−x) |   X2 (+x) |   Y1 (−y) |   Y2 (+y) |   Z1 (−z) |   Z2 (+z) |
# |---------|-----------|-----------|-----------|-----------|-----------|-----------|
# | 0.0°    |  -0.00012 |   0.00012 |  -0.00011 |   9e-05   |    0.0007 |   0.00027 |
# | 30.0°   |  -0.00011 |   0.00012 |  -0.00011 |   0.0001  |    0.0007 |   0.00027 |
# | 60.0°   |  -0.0001  |   0.00011 |  -0.00012 |   0.00011 |    0.0007 |   0.00026 |
# | 90.0°   |  -0.0001  |   0.0001  |  -0.00012 |   0.00012 |    0.0007 |   0.00026 |

# %%
from tabulate import tabulate

# Convert to scalar values if needed
def scalar(val):
    return val.item() if isinstance(val, np.ndarray) else val



table_data = [
    [f"{scalar(row['beta']):.1f}°",
     f"{scalar(row['X1']):.15f}",
     f"{scalar(row['X2']):.15f}",
     f"{scalar(row['Y1']):.15f}",
     f"{scalar(row['Y2']):.15f}",
     f"{scalar(row['Z1']):.15f}",
     f"{scalar(row['Z2']):.15f}"]
    for row in inc_flux_results
]

headers = ["β (°)", "X1 (−x)", "X2 (+x)", "Y1 (−y)", "Y2 (+y)", "Z1 (−z)", "Z2 (+z)"]
print(tabulate(table_data, headers=headers, tablefmt="github"))
# Out:
# | β (°)   |   X1 (−x) |   X2 (+x) |   Y1 (−y) |   Y2 (+y) |    Z1 (−z) |    Z2 (+z) |
# |---------|-----------|-----------|-----------|-----------|------------|------------|
# | 0.0°    |         0 |        -0 |         0 |        -0 | -0.0467769 | -0.0467767 |
# | 30.0°   |         0 |        -0 |         0 |        -0 | -0.0467769 | -0.0467767 |
# | 60.0°   |         0 |        -0 |         0 |        -0 | -0.0467769 | -0.0467767 |
# | 90.0°   |         0 |        -0 |         0 |        -0 | -0.0467769 | -0.0467767 |

# %%
import numpy as np
import matplotlib.pyplot as plt

# Convert to scalar values if needed
def scalar(val):
    return val.item() if isinstance(val, np.ndarray) else val


# Extract data
betas = [scalar(entry['beta']) for entry in flux_results]
Z1 = [scalar(entry['Z1']) for entry in flux_results]
Z2 = [scalar(entry['Z2']) for entry in flux_results]
X1 = [scalar(entry['X1']) for entry in flux_results]
X2 = [scalar(entry['X2']) for entry in flux_results]
Y1 = [scalar(entry['Y1']) for entry in flux_results]
Y2 = [scalar(entry['Y2']) for entry in flux_results]


# Set up subplots
fig, axs = plt.subplots(3, 2, figsize=(12, 10))
axs = axs.flatten()

# Plot each component
labels = ['Z1 (−z)', 'Z2 (+z)', 'X1 (−x)', 'X2 (+x)', 'Y1 (−y)', 'Y2 (+y)']
values = [Z1, Z2, X1, X2, Y1, Y2]

for i, (label, val) in enumerate(zip(labels, values)):
    axs[i].plot(betas, val, marker='o')
    axs[i].set_title(label)
    axs[i].set_xlabel("β (degrees)")
    axs[i].set_ylabel("Flux")
    axs[i].grid(True)

# Hide unused subplot if any
if len(axs) > len(labels):
    axs[-1].axis('off')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Convert to scalar values if needed
def scalar(val):
    return val.item() if isinstance(val, np.ndarray) else val

# Extract data
betas = [scalar(entry['beta']) for entry in inc_flux_results]
Z1 = [scalar(entry['Z1']) for entry in inc_flux_results]
Z2 = [scalar(entry['Z2']) for entry in inc_flux_results]
X1 = [scalar(entry['X1']) for entry in inc_flux_results]
X2 = [scalar(entry['X2']) for entry in inc_flux_results]
Y1 = [scalar(entry['Y1']) for entry in inc_flux_results]
Y2 = [scalar(entry['Y2']) for entry in inc_flux_results]


# Set up subplots
fig, axs = plt.subplots(3, 2, figsize=(12, 10))
axs = axs.flatten()

# Plot each component
labels = ['Z1 (−z)', 'Z2 (+z)', 'X1 (−x)', 'X2 (+x)', 'Y1 (−y)', 'Y2 (+y)']
values = [Z1, Z2, X1, X2, Y1, Y2]

for i, (label, val) in enumerate(zip(labels, values)):
    axs[i].plot(betas, val, marker='o')
    axs[i].set_title(label)
    axs[i].set_xlabel("β (degrees)")
    axs[i].set_ylabel("Flux")
    axs[i].grid(True)

# Hide unused subplot if any
if len(axs) > len(labels):
    axs[-1].axis('off')

plt.tight_layout()
plt.show()
