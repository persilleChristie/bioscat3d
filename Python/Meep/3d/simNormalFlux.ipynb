# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
import json
import os

keyword = "Normal"
path = "../SurfaceData/surfaceParams" + keyword + ".json"
def load_params(path = path):
    with open(path, "r") as f:
        return json.load(f)
params = load_params()

# Cell and resolution
pml_thickness = params["pml_thickness"]
monitor_size = params["monitor_size"]
half_x = params["halfWidth_x"]
half_y = params["halfWidth_y"]
half_z = params["halfWidth_z"]
cell_size = mp.Vector3(2*half_x + 2*pml_thickness,
                       2*half_y + 2*pml_thickness,
                       2*half_z + 2*pml_thickness)

omega = params["omega"]
betas = params["betas"]
# Material
epsilon1 = params["epsilon1"] 
substrate = mp.Medium(epsilon = epsilon1)
bumps = params["bumpData"]

## Must be at least 8 pixels per smallest wavelength, i.e. np.floor(8/wvl_min)
resolution = params["resolution"]

frq = params["omega"]/(2*np.pi)
wvl = 1 / frq

pml_layers = [mp.PML(thickness=pml_thickness)] 

def make_source(component):
    return [mp.Source(
        mp.GaussianSource(frequency=frq, fwidth=1, is_integrated=True),
        center=mp.Vector3(0, 0, half_z - 0.5),
        size=mp.Vector3(cell_size[0], cell_size[1], 0),
        component=component
    )]

def run_meep_simulation(sources):
    # Reference simulation (no bumps)
    sim = mp.Simulation(
        resolution=resolution,
        cell_size=cell_size,
        boundary_layers=pml_layers,
        sources=sources,
        k_point=mp.Vector3(),
    )

    box1_x1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(x=-monitor_size/2), size=mp.Vector3(0, monitor_size, monitor_size)))
    box1_x2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(x=+monitor_size/2), size=mp.Vector3(0, monitor_size, monitor_size)))
    box1_y1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(y=-monitor_size/2), size=mp.Vector3(monitor_size, 0, monitor_size)))
    box1_y2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(y=+monitor_size/2), size=mp.Vector3(monitor_size, 0, monitor_size)))
    box1_z1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(z=-monitor_size/2), size=mp.Vector3(monitor_size, monitor_size, 0)))
    box1_z2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(z=+monitor_size/2), size=mp.Vector3(monitor_size, monitor_size, 0)))


    sim.run(until_after_sources=60)

    box_x1 = mp.get_fluxes(box1_x1)
    box_x2 = mp.get_fluxes(box1_x2)
    box_y1 = mp.get_fluxes(box1_y1)
    box_y2 = mp.get_fluxes(box1_y2)
    box_z1 = mp.get_fluxes(box1_z1)
    box_z2 = mp.get_fluxes(box1_z2)

    # Save individual components for later printing/plotting
    inc_flux_components = {
        "X1": np.asarray(box_x1)[0],
        "X2": np.asarray(box_x2)[0],
        "Y1": np.asarray(box_y1)[0],
        "Y2": np.asarray(box_y2)[0],
        "Z1": np.asarray(box_z1)[0],
        "Z2": np.asarray(box_z2)[0],
    }

    box_x1_data = sim.get_flux_data(box1_x1)
    box_x2_data = sim.get_flux_data(box1_x2)
    box_y1_data = sim.get_flux_data(box1_y1)
    box_y2_data = sim.get_flux_data(box1_y2)
    box_z1_data = sim.get_flux_data(box1_z1)
    box_z2_data = sim.get_flux_data(box1_z2)

    sim.reset_meep()

    # Structured simulation (with bumps)
    def material_function(p):
        z_surface = sum(
            b["height"] * np.exp(-((p.x - b["x0"])**2 + (p.y - b["y0"])**2) / (2 * b["sigma"]**2))
            for b in bumps
        )
        return substrate if p.z + 1.5 < z_surface else mp.air

    sim = mp.Simulation(
        resolution=resolution,
        cell_size=cell_size,
        boundary_layers=pml_layers,
        sources=sources,
        k_point=mp.Vector3(),
        default_material=material_function,
    )

    box2_x1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(x=-monitor_size/2), size=mp.Vector3(0, monitor_size, monitor_size)))
    box2_x2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(x=+monitor_size/2), size=mp.Vector3(0, monitor_size, monitor_size)))
    box2_y1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(y=-monitor_size/2), size=mp.Vector3(monitor_size, 0, monitor_size)))
    box2_y2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(y=+monitor_size/2), size=mp.Vector3(monitor_size, 0, monitor_size)))
    box2_z1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(z=-monitor_size/2), size=mp.Vector3(monitor_size, monitor_size, 0)))
    box2_z2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(z=+monitor_size/2), size=mp.Vector3(monitor_size, monitor_size, 0)))

    sim.load_minus_flux_data(box2_x1, box_x1_data)
    sim.load_minus_flux_data(box2_x2, box_x2_data)
    sim.load_minus_flux_data(box2_y1, box_y1_data)
    sim.load_minus_flux_data(box2_y2, box_y2_data)
    sim.load_minus_flux_data(box2_z1, box_z1_data)
    sim.load_minus_flux_data(box2_z2, box_z2_data)

    sim.run(until_after_sources=60) # maybe 20 is too little? 

    box_x1_flux = mp.get_fluxes(box2_x1)
    box_x2_flux = mp.get_fluxes(box2_x2)
    box_y1_flux = mp.get_fluxes(box2_y1)
    box_y2_flux = mp.get_fluxes(box2_y2)
    box_z1_flux = mp.get_fluxes(box2_z1)
    box_z2_flux = mp.get_fluxes(box2_z2)

    # Save individual components for later printing/plotting
    scatt_flux_components = {
        "X1": np.asarray(box_x1_flux)[0],
        "X2": np.asarray(box_x2_flux)[0],
        "Y1": np.asarray(box_y1_flux)[0],
        "Y2": np.asarray(box_y2_flux)[0],
        "Z1": np.asarray(box_z1_flux)[0],
        "Z2": np.asarray(box_z2_flux)[0],
    }
    return scatt_flux_components, inc_flux_components

flux_results = []
inc_flux_results = []

def print_parameters():
    print("Simulation Parameters:")
    print(f"  omega      = {omega}")
    print(f"  frequency  = {frq}")
    print(f"  wavelength = {wvl}")
    print(f"  resolution = {resolution}")
    print(f"  cell_size  = ({cell_size.x}, {cell_size.y}, {cell_size.z})")
    print(f"  PML thickness = {pml_thickness}")
    print(f"  monitor size  = {monitor_size}")
    print(f"  substrate ε   = {epsilon1}")
    print(f"  number of bumps = {len(bumps)}")
    print("  betas (deg)    =", [round(np.degrees(b), 2) for b in betas])
    print()

print_parameters()


for beta in betas:
    print("beta = " + str(beta))
    cos2 = np.cos(beta)**2
    sin2 = np.sin(beta)**2

    sources_1 = make_source(mp.Ey)
    sources_2 = make_source(mp.Ex)
    
    flux_1, inc_flux_1 = run_meep_simulation(sources_1)
    flux_2, inc_flux_2 = run_meep_simulation(sources_2)

    # Combine flux components manually
    flux_combined = {
        "beta": np.degrees(beta),
        "X1": cos2 * flux_1["X1"] + sin2 * flux_2["X1"],
        "X2": cos2 * flux_1["X2"] + sin2 * flux_2["X2"],
        "Y1": cos2 * flux_1["Y1"] + sin2 * flux_2["Y1"],
        "Y2": cos2 * flux_1["Y2"] + sin2 * flux_2["Y2"],
        "Z1": cos2 * flux_1["Z1"] + sin2 * flux_2["Z1"],
        "Z2": cos2 * flux_1["Z2"] + sin2 * flux_2["Z2"],
    }
    
    flux_results.append(flux_combined)
    
    # Combine flux components manually
    inc_flux_combined = {
        "beta": np.degrees(beta),
        "X1": cos2 * inc_flux_1["X1"] + sin2 * inc_flux_2["X1"],
        "X2": cos2 * inc_flux_1["X2"] + sin2 * inc_flux_2["X2"],
        "Y1": cos2 * inc_flux_1["Y1"] + sin2 * inc_flux_2["Y1"],
        "Y2": cos2 * inc_flux_1["Y2"] + sin2 * inc_flux_2["Y2"],
        "Z1": cos2 * inc_flux_1["Z1"] + sin2 * inc_flux_2["Z1"],
        "Z2": cos2 * inc_flux_1["Z2"] + sin2 * inc_flux_2["Z2"],
    }

    inc_flux_results.append(inc_flux_combined)
# Out:
# Simulation Parameters:
#   omega      = 1.0
#   frequency  = 0.15915494309189535
#   wavelength = 6.283185307179586
#   resolution = 10
#   cell_size  = (6.0, 6.0, 8.0)
#   PML thickness = 2
#   monitor size  = 1
#   substrate ε   = 2.56
#   number of bumps = 3
#   betas (deg)    = [0.0, 15.0, 30.0, 45.0, 60.0, 75.0, 90.0]
#
# beta = 0.0
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.0284641 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.4307 s
# -----------
# Meep progress: 7.050000000000001/70.0 = 10.1% done in 4.0s, 35.7s to go
# on time step 141 (time=7.05), 0.02839 s/step
# Meep progress: 18.400000000000002/70.0 = 26.3% done in 8.0s, 22.5s to go
# on time step 368 (time=18.4), 0.0176528 s/step
# Meep progress: 30.5/70.0 = 43.6% done in 12.0s, 15.6s to go
# on time step 610 (time=30.5), 0.016576 s/step
# Meep progress: 42.45/70.0 = 60.6% done in 16.0s, 10.4s to go
# on time step 849 (time=42.45), 0.0167434 s/step
# Meep progress: 54.650000000000006/70.0 = 78.1% done in 20.0s, 5.6s to go
# on time step 1093 (time=54.65), 0.0164103 s/step
# Meep progress: 66.0/70.0 = 94.3% done in 24.0s, 1.5s to go
# on time step 1320 (time=66), 0.0177013 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000748873 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 20.9061 s
# -----------
# Meep progress: 4.4/70.0 = 6.3% done in 4.0s, 59.9s to go
# on time step 88 (time=4.4), 0.0456706 s/step
# Meep progress: 13.850000000000001/70.0 = 19.8% done in 8.0s, 32.6s to go
# on time step 277 (time=13.85), 0.0212303 s/step
# Meep progress: 22.950000000000003/70.0 = 32.8% done in 12.0s, 24.7s to go
# on time step 459 (time=22.95), 0.0220351 s/step
# Meep progress: 31.8/70.0 = 45.4% done in 16.0s, 19.3s to go
# on time step 636 (time=31.8), 0.022607 s/step
# Meep progress: 41.35/70.0 = 59.1% done in 20.1s, 13.9s to go
# on time step 827 (time=41.35), 0.0209985 s/step
# Meep progress: 51.25/70.0 = 73.2% done in 24.1s, 8.8s to go
# on time step 1025 (time=51.25), 0.0203039 s/step
# Meep progress: 61.95/70.0 = 88.5% done in 28.1s, 3.6s to go
# on time step 1239 (time=61.95), 0.0187237 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000462055 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.762278 s
# -----------
# Meep progress: 4.1000000000000005/70.0 = 5.9% done in 4.0s, 64.5s to go
# on time step 82 (time=4.1), 0.0489473 s/step
# Meep progress: 15.15/70.0 = 21.6% done in 8.0s, 29.1s to go
# on time step 303 (time=15.15), 0.0181394 s/step
# Meep progress: 26.3/70.0 = 37.6% done in 12.0s, 20.0s to go
# on time step 526 (time=26.3), 0.017945 s/step
# Meep progress: 38.75/70.0 = 55.4% done in 16.0s, 12.9s to go
# on time step 775 (time=38.75), 0.0160862 s/step
# Meep progress: 50.85/70.0 = 72.6% done in 20.0s, 7.5s to go
# on time step 1017 (time=50.85), 0.0165302 s/step
# Meep progress: 63.25/70.0 = 90.4% done in 24.0s, 2.6s to go
# on time step 1265 (time=63.25), 0.0161758 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000669956 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 20.3632 s
# -----------
# Meep progress: 6.75/70.0 = 9.6% done in 4.0s, 37.7s to go
# on time step 135 (time=6.75), 0.0297922 s/step
# Meep progress: 17.7/70.0 = 25.3% done in 8.0s, 23.8s to go
# on time step 354 (time=17.7), 0.0183365 s/step
# Meep progress: 30.400000000000002/70.0 = 43.4% done in 12.1s, 15.7s to go
# on time step 608 (time=30.4), 0.0157821 s/step
# Meep progress: 42.35/70.0 = 60.5% done in 16.1s, 10.5s to go
# on time step 847 (time=42.35), 0.0167797 s/step
# Meep progress: 54.300000000000004/70.0 = 77.6% done in 20.1s, 5.8s to go
# on time step 1086 (time=54.3), 0.0167809 s/step
# Meep progress: 65.8/70.0 = 94.0% done in 24.1s, 1.5s to go
# on time step 1316 (time=65.8), 0.0174608 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 0.2617993877991494
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000847101 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.912201 s
# -----------
# Meep progress: 2.25/70.0 = 3.2% done in 4.0s, 120.8s to go
# on time step 45 (time=2.25), 0.0891401 s/step
# Meep progress: 13.8/70.0 = 19.7% done in 8.0s, 32.7s to go
# on time step 276 (time=13.8), 0.0173408 s/step
# Meep progress: 26.25/70.0 = 37.5% done in 12.0s, 20.1s to go
# on time step 525 (time=26.25), 0.0161266 s/step
# Meep progress: 36.9/70.0 = 52.7% done in 16.0s, 14.4s to go
# on time step 738 (time=36.9), 0.0188344 s/step
# Meep progress: 47.75/70.0 = 68.2% done in 20.1s, 9.3s to go
# on time step 955 (time=47.75), 0.0185026 s/step
# Meep progress: 59.45/70.0 = 84.9% done in 24.1s, 4.3s to go
# on time step 1189 (time=59.45), 0.0171707 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000314951 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 17.4545 s
# -----------
# Meep progress: 7.15/70.0 = 10.2% done in 4.0s, 35.2s to go
# on time step 143 (time=7.15), 0.0280414 s/step
# Meep progress: 20.0/70.0 = 28.6% done in 8.0s, 20.0s to go
# on time step 400 (time=20), 0.0155981 s/step
# Meep progress: 33.2/70.0 = 47.4% done in 12.0s, 13.3s to go
# on time step 664 (time=33.2), 0.0151712 s/step
# Meep progress: 45.95/70.0 = 65.6% done in 16.0s, 8.4s to go
# on time step 919 (time=45.95), 0.0157054 s/step
# Meep progress: 59.25/70.0 = 84.6% done in 20.0s, 3.6s to go
# on time step 1185 (time=59.25), 0.0150631 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000498056 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.487398 s
# -----------
# Meep progress: 8.1/70.0 = 11.6% done in 4.0s, 30.7s to go
# on time step 162 (time=8.1), 0.0247597 s/step
# Meep progress: 21.950000000000003/70.0 = 31.4% done in 8.0s, 17.6s to go
# on time step 439 (time=21.95), 0.0144608 s/step
# Meep progress: 35.800000000000004/70.0 = 51.1% done in 12.0s, 11.5s to go
# on time step 716 (time=35.8), 0.0144876 s/step
# Meep progress: 47.400000000000006/70.0 = 67.7% done in 16.0s, 7.7s to go
# on time step 948 (time=47.4), 0.017309 s/step
# Meep progress: 55.650000000000006/70.0 = 79.5% done in 20.0s, 5.2s to go
# on time step 1114 (time=55.7), 0.0242439 s/step
# Meep progress: 67.15/70.0 = 95.9% done in 24.1s, 1.0s to go
# on time step 1344 (time=67.2), 0.0175649 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00111294 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 46.4828 s
# -----------
# Meep progress: 2.45/70.0 = 3.5% done in 4.0s, 110.6s to go
# on time step 49 (time=2.45), 0.0819054 s/step
# Meep progress: 8.950000000000001/70.0 = 12.8% done in 8.0s, 54.7s to go
# on time step 179 (time=8.95), 0.0307945 s/step
# Meep progress: 14.4/70.0 = 20.6% done in 12.1s, 46.5s to go
# on time step 288 (time=14.4), 0.0369904 s/step
# Meep progress: 19.950000000000003/70.0 = 28.5% done in 16.1s, 40.3s to go
# on time step 399 (time=19.95), 0.0361034 s/step
# Meep progress: 26.3/70.0 = 37.6% done in 20.1s, 33.3s to go
# on time step 527 (time=26.35), 0.0314667 s/step
# Meep progress: 32.800000000000004/70.0 = 46.9% done in 24.1s, 27.3s to go
# on time step 657 (time=32.85), 0.0309841 s/step
# Meep progress: 43.25/70.0 = 61.8% done in 28.1s, 17.4s to go
# on time step 868 (time=43.4), 0.0189802 s/step
# Meep progress: 55.050000000000004/70.0 = 78.6% done in 32.1s, 8.7s to go
# on time step 1104 (time=55.2), 0.0170049 s/step
# Meep progress: 67.5/70.0 = 96.4% done in 36.1s, 1.3s to go
# on time step 1354 (time=67.7), 0.016045 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 0.5235987755982988
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000355959 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.582496 s
# -----------
# Meep progress: 6.6000000000000005/70.0 = 9.4% done in 4.0s, 38.4s to go
# on time step 132 (time=6.6), 0.0303196 s/step
# Meep progress: 19.8/70.0 = 28.3% done in 8.0s, 20.3s to go
# on time step 396 (time=19.8), 0.0151665 s/step
# Meep progress: 32.4/70.0 = 46.3% done in 12.0s, 13.9s to go
# on time step 648 (time=32.4), 0.0159142 s/step
# Meep progress: 44.95/70.0 = 64.2% done in 16.0s, 8.9s to go
# on time step 899 (time=44.95), 0.0159412 s/step
# Meep progress: 57.75/70.0 = 82.5% done in 20.0s, 4.2s to go
# on time step 1155 (time=57.75), 0.0156359 s/step
# Meep progress: 69.5/70.0 = 99.3% done in 24.0s, 0.2s to go
# on time step 1390 (time=69.5), 0.0170258 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000385046 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 22.9645 s
# -----------
# Meep progress: 1.85/70.0 = 2.6% done in 4.0s, 147.4s to go
# on time step 37 (time=1.85), 0.108122 s/step
# Meep progress: 8.05/70.0 = 11.5% done in 8.0s, 61.6s to go
# on time step 162 (time=8.1), 0.0322814 s/step
# Meep progress: 14.25/70.0 = 20.4% done in 12.0s, 47.1s to go
# on time step 285 (time=14.25), 0.0325743 s/step
# Meep progress: 18.75/70.0 = 26.8% done in 16.0s, 43.9s to go
# on time step 376 (time=18.8), 0.0444137 s/step
# Meep progress: 23.950000000000003/70.0 = 34.2% done in 20.0s, 38.5s to go
# on time step 480 (time=24), 0.0384697 s/step
# Meep progress: 29.700000000000003/70.0 = 42.4% done in 24.1s, 32.6s to go
# on time step 596 (time=29.8), 0.0347097 s/step
# Meep progress: 35.95/70.0 = 51.4% done in 28.1s, 26.6s to go
# on time step 721 (time=36.05), 0.0320986 s/step
# Meep progress: 42.050000000000004/70.0 = 60.1% done in 32.1s, 21.3s to go
# on time step 842 (time=42.1), 0.0330597 s/step
# Meep progress: 48.550000000000004/70.0 = 69.4% done in 36.1s, 16.0s to go
# on time step 972 (time=48.6), 0.0308032 s/step
# Meep progress: 54.85/70.0 = 78.4% done in 40.1s, 11.1s to go
# on time step 1098 (time=54.9), 0.0318435 s/step
# Meep progress: 61.35/70.0 = 87.6% done in 44.1s, 6.2s to go
# on time step 1228 (time=61.4), 0.0308824 s/step
# Meep progress: 65.5/70.0 = 93.6% done in 48.1s, 3.3s to go
# on time step 1311 (time=65.55), 0.0486701 s/step
# Meep progress: 69.7/70.0 = 99.6% done in 52.2s, 0.2s to go
# on time step 1395 (time=69.75), 0.047797 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00201821 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 1.47873 s
# -----------
# Meep progress: 0.75/70.0 = 1.1% done in 4.0s, 370.0s to go
# on time step 15 (time=0.75), 0.267193 s/step
# Meep progress: 5.1000000000000005/70.0 = 7.3% done in 8.0s, 102.0s to go
# on time step 102 (time=5.1), 0.0460234 s/step
# Meep progress: 7.3500000000000005/70.0 = 10.5% done in 12.1s, 103.3s to go
# on time step 147 (time=7.35), 0.0910621 s/step
# Meep progress: 10.15/70.0 = 14.5% done in 16.1s, 95.0s to go
# on time step 203 (time=10.15), 0.0714432 s/step
# Meep progress: 17.0/70.0 = 24.3% done in 20.1s, 62.8s to go
# on time step 340 (time=17), 0.0292376 s/step
# Meep progress: 28.0/70.0 = 40.0% done in 24.1s, 36.2s to go
# on time step 560 (time=28), 0.0181902 s/step
# Meep progress: 38.400000000000006/70.0 = 54.9% done in 28.1s, 23.2s to go
# on time step 768 (time=38.4), 0.0192382 s/step
# Meep progress: 45.050000000000004/70.0 = 64.4% done in 32.1s, 17.8s to go
# on time step 901 (time=45.05), 0.0301107 s/step
# Meep progress: 52.400000000000006/70.0 = 74.9% done in 36.2s, 12.2s to go
# on time step 1048 (time=52.4), 0.0274671 s/step
# Meep progress: 62.2/70.0 = 88.9% done in 40.2s, 5.0s to go
# on time step 1244 (time=62.2), 0.0204573 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00036788 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 21.9807 s
# -----------
# Meep progress: 5.4/70.0 = 7.7% done in 4.0s, 47.9s to go
# on time step 108 (time=5.4), 0.0371049 s/step
# Meep progress: 14.700000000000001/70.0 = 21.0% done in 8.0s, 30.2s to go
# on time step 294 (time=14.7), 0.0215825 s/step
# Meep progress: 24.05/70.0 = 34.4% done in 12.0s, 23.0s to go
# on time step 481 (time=24.05), 0.0214631 s/step
# Meep progress: 36.15/70.0 = 51.6% done in 16.0s, 15.0s to go
# on time step 723 (time=36.15), 0.0165644 s/step
# Meep progress: 47.45/70.0 = 67.8% done in 20.1s, 9.5s to go
# on time step 949 (time=47.45), 0.0177248 s/step
# Meep progress: 59.7/70.0 = 85.3% done in 24.1s, 4.2s to go
# on time step 1194 (time=59.7), 0.0163922 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 0.7853981633974483
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000381947 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.521958 s
# -----------
# Meep progress: 5.3500000000000005/70.0 = 7.6% done in 4.0s, 48.5s to go
# on time step 107 (time=5.35), 0.0375184 s/step
# Meep progress: 15.350000000000001/70.0 = 21.9% done in 8.0s, 28.6s to go
# on time step 307 (time=15.35), 0.020088 s/step
# Meep progress: 25.400000000000002/70.0 = 36.3% done in 12.1s, 21.2s to go
# on time step 508 (time=25.4), 0.0199891 s/step
# Meep progress: 35.35/70.0 = 50.5% done in 16.1s, 15.8s to go
# on time step 707 (time=35.35), 0.0201688 s/step
# Meep progress: 43.650000000000006/70.0 = 62.4% done in 20.1s, 12.1s to go
# on time step 873 (time=43.65), 0.0241495 s/step
# Meep progress: 54.5/70.0 = 77.9% done in 24.1s, 6.9s to go
# on time step 1090 (time=54.5), 0.0185024 s/step
# Meep progress: 65.05/70.0 = 92.9% done in 28.1s, 2.1s to go
# on time step 1301 (time=65.05), 0.0190044 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000407934 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 31.3661 s
# -----------
# Meep progress: 1.6500000000000001/70.0 = 2.4% done in 4.0s, 166.7s to go
# on time step 33 (time=1.65), 0.121944 s/step
# Meep progress: 8.4/70.0 = 12.0% done in 8.1s, 59.1s to go
# on time step 168 (time=8.4), 0.0298917 s/step
# Meep progress: 14.75/70.0 = 21.1% done in 12.1s, 45.2s to go
# on time step 295 (time=14.75), 0.0315319 s/step
# Meep progress: 20.700000000000003/70.0 = 29.6% done in 16.1s, 38.3s to go
# on time step 414 (time=20.7), 0.0338439 s/step
# Meep progress: 25.85/70.0 = 36.9% done in 20.1s, 34.4s to go
# on time step 517 (time=25.85), 0.0391356 s/step
# Meep progress: 34.25/70.0 = 48.9% done in 24.1s, 25.2s to go
# on time step 685 (time=34.25), 0.0238432 s/step
# Meep progress: 46.050000000000004/70.0 = 65.8% done in 28.1s, 14.6s to go
# on time step 921 (time=46.05), 0.016992 s/step
# Meep progress: 57.400000000000006/70.0 = 82.0% done in 32.2s, 7.1s to go
# on time step 1148 (time=57.4), 0.0177689 s/step
# Meep progress: 67.55/70.0 = 96.5% done in 36.2s, 1.3s to go
# on time step 1351 (time=67.55), 0.0197824 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000381947 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.607947 s
# -----------
# Meep progress: 4.5/70.0 = 6.4% done in 4.0s, 58.5s to go
# on time step 90 (time=4.5), 0.0446436 s/step
# Meep progress: 15.850000000000001/70.0 = 22.6% done in 8.0s, 27.4s to go
# on time step 317 (time=15.85), 0.0176233 s/step
# Meep progress: 26.05/70.0 = 37.2% done in 12.0s, 20.3s to go
# on time step 521 (time=26.05), 0.0196917 s/step
# Meep progress: 34.95/70.0 = 49.9% done in 16.1s, 16.1s to go
# on time step 699 (time=34.95), 0.0226063 s/step
# Meep progress: 43.800000000000004/70.0 = 62.6% done in 20.1s, 12.0s to go
# on time step 876 (time=43.8), 0.0226514 s/step
# Meep progress: 51.300000000000004/70.0 = 73.3% done in 24.1s, 8.8s to go
# on time step 1026 (time=51.3), 0.0267766 s/step
# Meep progress: 60.650000000000006/70.0 = 86.6% done in 28.1s, 4.3s to go
# on time step 1213 (time=60.65), 0.021423 s/step
# Meep progress: 69.05/70.0 = 98.6% done in 32.1s, 0.4s to go
# on time step 1381 (time=69.05), 0.0238651 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00133896 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 23.5297 s
# -----------
# Meep progress: 0.7000000000000001/70.0 = 1.0% done in 4.0s, 398.5s to go
# on time step 14 (time=0.7), 0.287569 s/step
# Meep progress: 8.200000000000001/70.0 = 11.7% done in 8.0s, 60.5s to go
# on time step 165 (time=8.25), 0.0267208 s/step
# Meep progress: 13.600000000000001/70.0 = 19.4% done in 12.1s, 50.0s to go
# on time step 273 (time=13.65), 0.037199 s/step
# Meep progress: 19.05/70.0 = 27.2% done in 16.1s, 43.1s to go
# on time step 381 (time=19.05), 0.0372981 s/step
# Meep progress: 26.0/70.0 = 37.1% done in 20.1s, 34.0s to go
# on time step 520 (time=26), 0.0287984 s/step
# Meep progress: 34.050000000000004/70.0 = 48.6% done in 24.1s, 25.5s to go
# on time step 681 (time=34.05), 0.0249275 s/step
# Meep progress: 40.900000000000006/70.0 = 58.4% done in 28.1s, 20.0s to go
# on time step 818 (time=40.9), 0.0291981 s/step
# Meep progress: 47.45/70.0 = 67.8% done in 32.1s, 15.3s to go
# on time step 949 (time=47.45), 0.0306239 s/step
# Meep progress: 57.35/70.0 = 81.9% done in 36.2s, 8.0s to go
# on time step 1147 (time=57.35), 0.0202147 s/step
# Meep progress: 65.55/70.0 = 93.6% done in 40.2s, 2.7s to go
# on time step 1311 (time=65.55), 0.0244073 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 1.0471975511965976
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000469923 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.5926 s
# -----------
# Meep progress: 6.3500000000000005/70.0 = 9.1% done in 4.0s, 40.3s to go
# on time step 127 (time=6.35), 0.0316325 s/step
# Meep progress: 15.65/70.0 = 22.4% done in 8.0s, 27.9s to go
# on time step 313 (time=15.65), 0.0215156 s/step
# Meep progress: 23.6/70.0 = 33.7% done in 12.0s, 23.7s to go
# on time step 472 (time=23.6), 0.0253168 s/step
# Meep progress: 28.8/70.0 = 41.1% done in 16.1s, 23.0s to go
# on time step 576 (time=28.8), 0.0386566 s/step
# Meep progress: 33.85/70.0 = 48.4% done in 20.1s, 21.5s to go
# on time step 677 (time=33.85), 0.0398702 s/step
# Meep progress: 36.35/70.0 = 51.9% done in 24.2s, 22.4s to go
# on time step 727 (time=36.35), 0.0813964 s/step
# Meep progress: 38.900000000000006/70.0 = 55.6% done in 28.2s, 22.6s to go
# on time step 778 (time=38.9), 0.0790665 s/step
# Meep progress: 41.1/70.0 = 58.7% done in 32.2s, 22.7s to go
# on time step 822 (time=41.1), 0.0909175 s/step
# Meep progress: 44.900000000000006/70.0 = 64.1% done in 36.3s, 20.3s to go
# on time step 898 (time=44.9), 0.0535697 s/step
# Meep progress: 49.300000000000004/70.0 = 70.4% done in 40.3s, 16.9s to go
# on time step 986 (time=49.3), 0.0457907 s/step
# Meep progress: 54.300000000000004/70.0 = 77.6% done in 44.3s, 12.8s to go
# on time step 1086 (time=54.3), 0.0400122 s/step
# Meep progress: 59.6/70.0 = 85.1% done in 48.4s, 8.4s to go
# on time step 1192 (time=59.6), 0.0378242 s/step
# Meep progress: 63.75/70.0 = 91.1% done in 52.4s, 5.1s to go
# on time step 1275 (time=63.75), 0.0484478 s/step
# Meep progress: 67.8/70.0 = 96.9% done in 56.4s, 1.8s to go
# on time step 1356 (time=67.8), 0.0496081 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00081706 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 34.7547 s
# -----------
# Meep progress: 2.6/70.0 = 3.7% done in 4.0s, 104.4s to go
# on time step 52 (time=2.6), 0.0774543 s/step
# Meep progress: 8.4/70.0 = 12.0% done in 8.0s, 58.9s to go
# on time step 169 (time=8.45), 0.0345216 s/step
# Meep progress: 19.400000000000002/70.0 = 27.7% done in 12.0s, 31.4s to go
# on time step 391 (time=19.55), 0.0180881 s/step
# Meep progress: 29.55/70.0 = 42.2% done in 16.0s, 22.0s to go
# on time step 594 (time=29.7), 0.0197229 s/step
# Meep progress: 38.95/70.0 = 55.6% done in 20.1s, 16.0s to go
# on time step 782 (time=39.1), 0.0212842 s/step
# Meep progress: 46.400000000000006/70.0 = 66.3% done in 24.1s, 12.2s to go
# on time step 930 (time=46.5), 0.0271963 s/step
# Meep progress: 52.35/70.0 = 74.8% done in 28.1s, 9.5s to go
# on time step 1049 (time=52.45), 0.0337004 s/step
# Meep progress: 60.0/70.0 = 85.7% done in 32.1s, 5.3s to go
# on time step 1203 (time=60.15), 0.0261142 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000473022 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.603245 s
# -----------
# Meep progress: 3.85/70.0 = 5.5% done in 4.0s, 68.9s to go
# on time step 77 (time=3.85), 0.0520503 s/step
# Meep progress: 11.05/70.0 = 15.8% done in 8.0s, 42.8s to go
# on time step 221 (time=11.05), 0.0278459 s/step
# Meep progress: 21.400000000000002/70.0 = 30.6% done in 12.0s, 27.4s to go
# on time step 428 (time=21.4), 0.0194556 s/step
# Meep progress: 33.1/70.0 = 47.3% done in 16.1s, 17.9s to go
# on time step 662 (time=33.1), 0.0171392 s/step
# Meep progress: 43.300000000000004/70.0 = 61.9% done in 20.1s, 12.4s to go
# on time step 866 (time=43.3), 0.0196688 s/step
# Meep progress: 55.95/70.0 = 79.9% done in 24.1s, 6.0s to go
# on time step 1119 (time=55.95), 0.0158537 s/step
# Meep progress: 68.0/70.0 = 97.1% done in 28.1s, 0.8s to go
# on time step 1360 (time=68), 0.0166904 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000635147 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 21.386 s
# -----------
# Meep progress: 3.75/70.0 = 5.4% done in 4.0s, 71.0s to go
# on time step 75 (time=3.75), 0.0535569 s/step
# Meep progress: 14.9/70.0 = 21.3% done in 8.0s, 29.7s to go
# on time step 298 (time=14.9), 0.017991 s/step
# Meep progress: 24.700000000000003/70.0 = 35.3% done in 12.1s, 22.1s to go
# on time step 494 (time=24.7), 0.0205094 s/step
# Meep progress: 35.0/70.0 = 50.0% done in 16.1s, 16.1s to go
# on time step 700 (time=35), 0.0194412 s/step
# Meep progress: 46.900000000000006/70.0 = 67.0% done in 20.1s, 9.9s to go
# on time step 938 (time=46.9), 0.0168471 s/step
# Meep progress: 58.7/70.0 = 83.9% done in 24.1s, 4.6s to go
# on time step 1174 (time=58.7), 0.0169749 s/step
# Meep progress: 69.60000000000001/70.0 = 99.4% done in 28.1s, 0.2s to go
# on time step 1392 (time=69.6), 0.018467 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 1.308996938995747
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000689983 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.650509 s
# -----------
# Meep progress: 0.9/70.0 = 1.3% done in 4.0s, 308.5s to go
# on time step 18 (time=0.9), 0.223233 s/step
# Meep progress: 11.15/70.0 = 15.9% done in 8.0s, 42.4s to go
# on time step 223 (time=11.15), 0.0195635 s/step
# Meep progress: 23.0/70.0 = 32.9% done in 12.0s, 24.6s to go
# on time step 460 (time=23), 0.0169325 s/step
# Meep progress: 34.550000000000004/70.0 = 49.4% done in 16.1s, 16.5s to go
# on time step 691 (time=34.55), 0.0173637 s/step
# Meep progress: 44.85/70.0 = 64.1% done in 20.1s, 11.2s to go
# on time step 897 (time=44.85), 0.0194349 s/step
# Meep progress: 54.6/70.0 = 78.0% done in 24.1s, 6.8s to go
# on time step 1092 (time=54.6), 0.0205163 s/step
# Meep progress: 64.10000000000001/70.0 = 91.6% done in 28.1s, 2.6s to go
# on time step 1282 (time=64.1), 0.0210665 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00028801 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 21.3434 s
# -----------
# Meep progress: 7.6000000000000005/70.0 = 10.9% done in 4.0s, 32.9s to go
# on time step 152 (time=7.6), 0.0263263 s/step
# Meep progress: 17.75/70.0 = 25.4% done in 8.0s, 23.6s to go
# on time step 355 (time=17.75), 0.0197287 s/step
# Meep progress: 26.1/70.0 = 37.3% done in 12.0s, 20.2s to go
# on time step 522 (time=26.1), 0.0239557 s/step
# Meep progress: 34.45/70.0 = 49.2% done in 16.0s, 16.5s to go
# on time step 689 (time=34.45), 0.0240063 s/step
# Meep progress: 46.35/70.0 = 66.2% done in 20.0s, 10.2s to go
# on time step 927 (time=46.35), 0.0168454 s/step
# Meep progress: 57.35/70.0 = 81.9% done in 24.0s, 5.3s to go
# on time step 1147 (time=57.35), 0.0182096 s/step
# Meep progress: 66.85000000000001/70.0 = 95.5% done in 28.1s, 1.3s to go
# on time step 1337 (time=66.85), 0.0211162 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000891924 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 1.39686 s
# -----------
# Meep progress: 0.05/70.0 = 0.1% done in 5.3s, 7373.2s to go
# on time step 1 (time=0.05), 5.27072 s/step
# Meep progress: 4.800000000000001/70.0 = 6.9% done in 9.3s, 126.1s to go
# on time step 96 (time=4.8), 0.042233 s/step
# Meep progress: 10.25/70.0 = 14.6% done in 13.3s, 77.6s to go
# on time step 205 (time=10.25), 0.036868 s/step
# Meep progress: 15.200000000000001/70.0 = 21.7% done in 17.3s, 62.5s to go
# on time step 304 (time=15.2), 0.0406599 s/step
# Meep progress: 21.5/70.0 = 30.7% done in 21.4s, 48.2s to go
# on time step 430 (time=21.5), 0.0319118 s/step
# Meep progress: 27.6/70.0 = 39.4% done in 25.4s, 39.0s to go
# on time step 552 (time=27.6), 0.0331644 s/step
# Meep progress: 34.4/70.0 = 49.1% done in 29.4s, 30.4s to go
# on time step 688 (time=34.4), 0.0294582 s/step
# Meep progress: 40.75/70.0 = 58.2% done in 33.4s, 24.0s to go
# on time step 815 (time=40.75), 0.0315863 s/step
# Meep progress: 47.6/70.0 = 68.0% done in 37.4s, 17.6s to go
# on time step 952 (time=47.6), 0.0292284 s/step
# Meep progress: 53.25/70.0 = 76.1% done in 41.5s, 13.0s to go
# on time step 1065 (time=53.25), 0.035583 s/step
# Meep progress: 58.45/70.0 = 83.5% done in 45.5s, 9.0s to go
# on time step 1169 (time=58.45), 0.0386155 s/step
# Meep progress: 63.75/70.0 = 91.1% done in 49.5s, 4.9s to go
# on time step 1275 (time=63.75), 0.0381133 s/step
# Meep progress: 68.15/70.0 = 97.4% done in 53.5s, 1.5s to go
# on time step 1363 (time=68.15), 0.0457867 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000857115 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 29.167 s
# -----------
# Meep progress: 6.15/70.0 = 8.8% done in 4.0s, 41.6s to go
# on time step 123 (time=6.15), 0.0325677 s/step
# Meep progress: 17.0/70.0 = 24.3% done in 8.0s, 25.0s to go
# on time step 340 (time=17), 0.0185161 s/step
# Meep progress: 27.3/70.0 = 39.0% done in 12.0s, 18.8s to go
# on time step 546 (time=27.3), 0.019453 s/step
# Meep progress: 37.5/70.0 = 53.6% done in 16.0s, 13.9s to go
# on time step 751 (time=37.55), 0.0195998 s/step
# Meep progress: 46.95/70.0 = 67.1% done in 20.0s, 9.8s to go
# on time step 941 (time=47.05), 0.0211288 s/step
# Meep progress: 56.650000000000006/70.0 = 80.9% done in 24.0s, 5.7s to go
# on time step 1134 (time=56.7), 0.020785 s/step
# Meep progress: 66.10000000000001/70.0 = 94.4% done in 28.1s, 1.7s to go
# on time step 1323 (time=66.15), 0.0212303 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 1.5707963267948966
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00160909 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.88973 s
# -----------
# Meep progress: 3.85/70.0 = 5.5% done in 4.0s, 68.9s to go
# on time step 77 (time=3.85), 0.0521031 s/step
# Meep progress: 12.8/70.0 = 18.3% done in 8.0s, 35.8s to go
# on time step 256 (time=12.8), 0.0223705 s/step
# Meep progress: 20.650000000000002/70.0 = 29.5% done in 12.1s, 28.8s to go
# on time step 413 (time=20.65), 0.0256988 s/step
# Meep progress: 27.950000000000003/70.0 = 39.9% done in 16.1s, 24.2s to go
# on time step 559 (time=27.95), 0.0274851 s/step
# Meep progress: 35.25/70.0 = 50.4% done in 20.1s, 19.8s to go
# on time step 705 (time=35.25), 0.0274685 s/step
# Meep progress: 45.650000000000006/70.0 = 65.2% done in 24.1s, 12.8s to go
# on time step 913 (time=45.65), 0.0192647 s/step
# Meep progress: 56.95/70.0 = 81.4% done in 28.1s, 6.4s to go
# on time step 1139 (time=56.95), 0.0177495 s/step
# Meep progress: 63.35/70.0 = 90.5% done in 32.1s, 3.4s to go
# on time step 1267 (time=63.35), 0.0315034 s/step
# Meep progress: 68.55/70.0 = 97.9% done in 36.1s, 0.8s to go
# on time step 1371 (time=68.55), 0.0385293 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000560999 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 41.8436 s
# -----------
# Meep progress: 2.95/70.0 = 4.2% done in 4.0s, 91.1s to go
# on time step 59 (time=2.95), 0.0679048 s/step
# Meep progress: 9.35/70.0 = 13.4% done in 8.0s, 52.0s to go
# on time step 187 (time=9.35), 0.0312643 s/step
# Meep progress: 16.25/70.0 = 23.2% done in 12.0s, 39.8s to go
# on time step 325 (time=16.25), 0.0290413 s/step
# Meep progress: 22.950000000000003/70.0 = 32.8% done in 16.0s, 32.9s to go
# on time step 459 (time=22.95), 0.0298897 s/step
# Meep progress: 28.650000000000002/70.0 = 40.9% done in 20.0s, 28.9s to go
# on time step 573 (time=28.65), 0.0351928 s/step
# Meep progress: 34.35/70.0 = 49.1% done in 24.1s, 25.0s to go
# on time step 687 (time=34.35), 0.0352559 s/step
# Meep progress: 39.95/70.0 = 57.1% done in 28.1s, 21.1s to go
# on time step 800 (time=40), 0.0356819 s/step
# Meep progress: 46.050000000000004/70.0 = 65.8% done in 32.1s, 16.7s to go
# on time step 923 (time=46.15), 0.0327038 s/step
# Meep progress: 52.900000000000006/70.0 = 75.6% done in 36.1s, 11.7s to go
# on time step 1060 (time=53), 0.0293954 s/step
# Meep progress: 59.5/70.0 = 85.0% done in 40.1s, 7.1s to go
# on time step 1192 (time=59.6), 0.0304737 s/step
# Meep progress: 66.15/70.0 = 94.5% done in 44.1s, 2.6s to go
# on time step 1325 (time=66.25), 0.0301763 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00056982 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 1.01818 s
# -----------
# Meep progress: 0.05/70.0 = 0.1% done in 4.6s, 6471.4s to go
# on time step 1 (time=0.05), 4.62621 s/step
# Meep progress: 6.25/70.0 = 8.9% done in 8.6s, 88.1s to go
# on time step 125 (time=6.25), 0.032283 s/step
# Meep progress: 13.15/70.0 = 18.8% done in 12.7s, 54.7s to go
# on time step 263 (time=13.15), 0.0291043 s/step
# Meep progress: 19.5/70.0 = 27.9% done in 16.7s, 43.2s to go
# on time step 390 (time=19.5), 0.0316788 s/step
# Meep progress: 25.3/70.0 = 36.1% done in 20.7s, 36.5s to go
# on time step 506 (time=25.3), 0.0345234 s/step
# Meep progress: 32.7/70.0 = 46.7% done in 24.7s, 28.2s to go
# on time step 654 (time=32.7), 0.0271785 s/step
# Meep progress: 40.6/70.0 = 58.0% done in 28.7s, 20.8s to go
# on time step 813 (time=40.65), 0.0253268 s/step
# Meep progress: 47.800000000000004/70.0 = 68.3% done in 32.7s, 15.2s to go
# on time step 957 (time=47.85), 0.0279136 s/step
# Meep progress: 55.550000000000004/70.0 = 79.4% done in 36.8s, 9.6s to go
# on time step 1112 (time=55.6), 0.0259506 s/step
# Meep progress: 61.75/70.0 = 88.2% done in 40.8s, 5.5s to go
# on time step 1235 (time=61.75), 0.0326113 s/step
# Meep progress: 69.0/70.0 = 98.6% done in 44.8s, 0.6s to go
# on time step 1380 (time=69), 0.0276167 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000609159 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 29.8334 s
# -----------
# Meep progress: 2.35/70.0 = 3.4% done in 4.0s, 115.5s to go
# on time step 47 (time=2.35), 0.0854028 s/step
# Meep progress: 8.8/70.0 = 12.6% done in 8.0s, 55.8s to go
# on time step 176 (time=8.8), 0.0310966 s/step
# Meep progress: 15.450000000000001/70.0 = 22.1% done in 12.0s, 42.5s to go
# on time step 309 (time=15.45), 0.0301852 s/step
# Meep progress: 20.55/70.0 = 29.4% done in 16.1s, 38.6s to go
# on time step 411 (time=20.55), 0.0392498 s/step
# Meep progress: 26.700000000000003/70.0 = 38.1% done in 20.1s, 32.5s to go
# on time step 534 (time=26.7), 0.0326014 s/step
# Meep progress: 32.45/70.0 = 46.4% done in 24.1s, 27.9s to go
# on time step 649 (time=32.45), 0.0350012 s/step
# Meep progress: 38.7/70.0 = 55.3% done in 28.1s, 22.7s to go
# on time step 774 (time=38.7), 0.0320724 s/step
# Meep progress: 44.800000000000004/70.0 = 64.0% done in 32.1s, 18.1s to go
# on time step 896 (time=44.8), 0.0328752 s/step
# Meep progress: 51.550000000000004/70.0 = 73.6% done in 36.1s, 12.9s to go
# on time step 1031 (time=51.55), 0.0298454 s/step
# Meep progress: 59.45/70.0 = 84.9% done in 40.2s, 7.1s to go
# on time step 1189 (time=59.45), 0.0255366 s/step
# Meep progress: 63.35/70.0 = 90.5% done in 44.2s, 4.6s to go
# on time step 1267 (time=63.35), 0.0516111 s/step
# Meep progress: 67.05/70.0 = 95.8% done in 48.3s, 2.1s to go
# on time step 1341 (time=67.05), 0.0545407 s/step
# run 0 finished at t = 70.0 (1400 timesteps)

# %%
d = flux_1
#d = flux_1
print("Size of dict:", len(d))
d
# Out:
# Size of dict: 6
# {'X1': 2.517478249013646e-05,
#  'X2': -4.923507200340001e-05,
#  'Y1': -3.4629734088580992e-06,
#  'Y2': -7.823180776755396e-06,
#  'Z1': 0.002156991009579839,
#  'Z2': 0.0022352765634445593}

# %%
from tabulate import tabulate

# Convert to scalar values if needed
def scalar(val):
    return val.item() if isinstance(val, np.ndarray) else val



table_data = [
    [f"{scalar(row['beta']):.1f}°",
     f"{scalar(row['X1']):.5f}",
     f"{scalar(row['X2']):.5f}",
     f"{scalar(row['Y1']):.5f}",
     f"{scalar(row['Y2']):.5f}",
     f"{scalar(row['Z1']):.5f}",
     f"{scalar(row['Z2']):.5f}"]
    for row in flux_results
]

headers = ["β (°)", "X1 (−x)", "X2 (+x)", "Y1 (−y)", "Y2 (+y)", "Z1 (−z)", "Z2 (+z)"]
print(tabulate(table_data, headers=headers, tablefmt="github"))
# Out:
# | β (°)   |   X1 (−x) |   X2 (+x) |   Y1 (−y) |   Y2 (+y) |   Z1 (−z) |   Z2 (+z) |
# |---------|-----------|-----------|-----------|-----------|-----------|-----------|
# | 0.0°    |     3e-05 |    -5e-05 |    -0     |    -1e-05 |   0.00216 |   0.00224 |
# | 15.0°   |     2e-05 |    -5e-05 |    -0     |    -1e-05 |   0.00216 |   0.00224 |
# | 30.0°   |     2e-05 |    -4e-05 |     1e-05 |    -0     |   0.00217 |   0.00224 |
# | 45.0°   |     1e-05 |    -2e-05 |     2e-05 |    -0     |   0.00219 |   0.00224 |
# | 60.0°   |     0     |    -1e-05 |     3e-05 |     0     |   0.0022  |   0.00224 |
# | 75.0°   |    -0     |    -0     |     4e-05 |     1e-05 |   0.00221 |   0.00224 |
# | 90.0°   |    -0     |     0     |     4e-05 |     1e-05 |   0.00221 |   0.00224 |

# %%
from tabulate import tabulate

# Convert to scalar values if needed
def scalar(val):
    return val.item() if isinstance(val, np.ndarray) else val



table_data = [
    [f"{scalar(row['beta']):.1f}°",
     f"{scalar(row['X1']):.15f}",
     f"{scalar(row['X2']):.15f}",
     f"{scalar(row['Y1']):.15f}",
     f"{scalar(row['Y2']):.15f}",
     f"{scalar(row['Z1']):.15f}",
     f"{scalar(row['Z2']):.15f}"]
    for row in inc_flux_results
]

headers = ["β (°)", "X1 (−x)", "X2 (+x)", "Y1 (−y)", "Y2 (+y)", "Z1 (−z)", "Z2 (+z)"]
print(tabulate(table_data, headers=headers, tablefmt="github"))
# Out:
# | β (°)   |   X1 (−x) |   X2 (+x) |   Y1 (−y) |   Y2 (+y) |    Z1 (−z) |    Z2 (+z) |
# |---------|-----------|-----------|-----------|-----------|------------|------------|
# | 0.0°    |        -0 |         0 |         0 |        -0 | -0.0467769 | -0.0467767 |
# | 15.0°   |        -0 |         0 |         0 |        -0 | -0.0467769 | -0.0467767 |
# | 30.0°   |        -0 |         0 |         0 |        -0 | -0.0467769 | -0.0467767 |
# | 45.0°   |         0 |         0 |         0 |        -0 | -0.0467769 | -0.0467767 |
# | 60.0°   |         0 |        -0 |        -0 |        -0 | -0.0467769 | -0.0467767 |
# | 75.0°   |         0 |        -0 |        -0 |         0 | -0.0467769 | -0.0467767 |
# | 90.0°   |         0 |        -0 |        -0 |         0 | -0.0467769 | -0.0467767 |

# %%
import numpy as np
import matplotlib.pyplot as plt

# Convert to scalar values if needed
def scalar(val):
    return val.item() if isinstance(val, np.ndarray) else val


# Extract data
betas = [scalar(entry['beta']) for entry in flux_results]
Z1 = [scalar(entry['Z1']) for entry in flux_results]
Z2 = [scalar(entry['Z2']) for entry in flux_results]
X1 = [scalar(entry['X1']) for entry in flux_results]
X2 = [scalar(entry['X2']) for entry in flux_results]
Y1 = [scalar(entry['Y1']) for entry in flux_results]
Y2 = [scalar(entry['Y2']) for entry in flux_results]


# Set up subplots
fig, axs = plt.subplots(3, 2, figsize=(12, 10))
axs = axs.flatten()

# Plot each component
labels = ['Z1 (−z)', 'Z2 (+z)', 'X1 (−x)', 'X2 (+x)', 'Y1 (−y)', 'Y2 (+y)']
values = [Z1, Z2, X1, X2, Y1, Y2]

for i, (label, val) in enumerate(zip(labels, values)):
    axs[i].plot(betas, val, marker='o')
    axs[i].set_title(label)
    axs[i].set_xlabel("β (degrees)")
    axs[i].set_ylabel("Flux")
    axs[i].grid(True)

# Hide unused subplot if any
if len(axs) > len(labels):
    axs[-1].axis('off')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Convert to scalar values if needed
def scalar(val):
    return val.item() if isinstance(val, np.ndarray) else val

# Extract data
betas = [scalar(entry['beta']) for entry in inc_flux_results]
Z1 = [scalar(entry['Z1']) for entry in inc_flux_results]
Z2 = [scalar(entry['Z2']) for entry in inc_flux_results]
X1 = [scalar(entry['X1']) for entry in inc_flux_results]
X2 = [scalar(entry['X2']) for entry in inc_flux_results]
Y1 = [scalar(entry['Y1']) for entry in inc_flux_results]
Y2 = [scalar(entry['Y2']) for entry in inc_flux_results]


# Set up subplots
fig, axs = plt.subplots(3, 2, figsize=(12, 10))
axs = axs.flatten()

# Plot each component
labels = ['Z1 (−z)', 'Z2 (+z)', 'X1 (−x)', 'X2 (+x)', 'Y1 (−y)', 'Y2 (+y)']
values = [Z1, Z2, X1, X2, Y1, Y2]

for i, (label, val) in enumerate(zip(labels, values)):
    axs[i].plot(betas, val, marker='o')
    axs[i].set_title(label)
    axs[i].set_xlabel("β (degrees)")
    axs[i].set_ylabel("Flux")
    axs[i].grid(True)

# Hide unused subplot if any
if len(axs) > len(labels):
    axs[-1].axis('off')

plt.tight_layout()
plt.show()
