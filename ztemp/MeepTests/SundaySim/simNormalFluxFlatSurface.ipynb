# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
import json
import os

keyword = "Normal"
path = "SurfaceData/surfaceParams" + keyword + ".json"
def load_params(path = path):
    with open(path, "r") as f:
        return json.load(f)
params = load_params()

# Cell and resolution
pml_thickness = params["pml_thickness"]
monitor_size = params["monitor_size"]
half_x = params["halfWidth_x"]
half_y = params["halfWidth_y"]
half_z = params["halfWidth_z"]
cell_size = mp.Vector3(2*half_x + 2*pml_thickness,
                       2*half_y + 2*pml_thickness,
                       2*half_z + 2*pml_thickness)

omega = params["omega"]
betas = params["betas"]
# Material
epsilon1 = params["epsilon1"] 
substrate = mp.Medium(epsilon = epsilon1)
bumps = []

## Must be at least 8 pixels per smallest wavelength, i.e. np.floor(8/wvl_min)
resolution = params["resolution"]

frq = params["omega"]/(2*np.pi)
wvl = 1 / frq

pml_layers = [mp.PML(thickness=pml_thickness)] 

def make_source(component):
    return [mp.Source(
        mp.GaussianSource(frequency=frq, fwidth=1, is_integrated=True),
        center=mp.Vector3(0, 0, half_z - 0.5),
        size=mp.Vector3(cell_size[0], cell_size[1], 0),
        component=component
    )]

def run_meep_simulation(sources):
    # Reference simulation (no bumps)
    sim = mp.Simulation(
        resolution=resolution,
        cell_size=cell_size,
        boundary_layers=pml_layers,
        sources=sources,
        k_point=mp.Vector3(),
    )

    box1_x1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(x=-monitor_size/2), size=mp.Vector3(0, monitor_size, monitor_size)))
    box1_x2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(x=+monitor_size/2), size=mp.Vector3(0, monitor_size, monitor_size)))
    box1_y1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(y=-monitor_size/2), size=mp.Vector3(monitor_size, 0, monitor_size)))
    box1_y2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(y=+monitor_size/2), size=mp.Vector3(monitor_size, 0, monitor_size)))
    box1_z1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(z=-monitor_size/2), size=mp.Vector3(monitor_size, monitor_size, 0)))
    box1_z2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(z=+monitor_size/2), size=mp.Vector3(monitor_size, monitor_size, 0)))


    sim.run(until_after_sources=60)

    box_x1 = mp.get_fluxes(box1_x1)
    box_x2 = mp.get_fluxes(box1_x2)
    box_y1 = mp.get_fluxes(box1_y1)
    box_y2 = mp.get_fluxes(box1_y2)
    box_z1 = mp.get_fluxes(box1_z1)
    box_z2 = mp.get_fluxes(box1_z2)

    # Save individual components for later printing/plotting
    inc_flux_components = {
        "X1": np.asarray(box_x1)[0],
        "X2": np.asarray(box_x2)[0],
        "Y1": np.asarray(box_y1)[0],
        "Y2": np.asarray(box_y2)[0],
        "Z1": np.asarray(box_z1)[0],
        "Z2": np.asarray(box_z2)[0],
    }

    box_x1_data = sim.get_flux_data(box1_x1)
    box_x2_data = sim.get_flux_data(box1_x2)
    box_y1_data = sim.get_flux_data(box1_y1)
    box_y2_data = sim.get_flux_data(box1_y2)
    box_z1_data = sim.get_flux_data(box1_z1)
    box_z2_data = sim.get_flux_data(box1_z2)

    sim.reset_meep()

    # Structured simulation (with bumps)
    def material_function(p):
        z_surface = -1.5
        z_surface += sum(
            b["height"] * np.exp(-((p.x - b["x0"])**2 + (p.y - b["y0"])**2) / (2 * b["sigma"]**2))
            for b in bumps
        )
        return substrate if p.z < z_surface else mp.air

    sim = mp.Simulation(
        resolution=resolution,
        cell_size=cell_size,
        boundary_layers=pml_layers,
        sources=sources,
        k_point=mp.Vector3(),
        default_material=material_function,
    )

    box2_x1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(x=-monitor_size/2), size=mp.Vector3(0, monitor_size, monitor_size)))
    box2_x2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(x=+monitor_size/2), size=mp.Vector3(0, monitor_size, monitor_size)))
    box2_y1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(y=-monitor_size/2), size=mp.Vector3(monitor_size, 0, monitor_size)))
    box2_y2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(y=+monitor_size/2), size=mp.Vector3(monitor_size, 0, monitor_size)))
    box2_z1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(z=-monitor_size/2), size=mp.Vector3(monitor_size, monitor_size, 0)))
    box2_z2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(z=+monitor_size/2), size=mp.Vector3(monitor_size, monitor_size, 0)))

    sim.load_minus_flux_data(box2_x1, box_x1_data)
    sim.load_minus_flux_data(box2_x2, box_x2_data)
    sim.load_minus_flux_data(box2_y1, box_y1_data)
    sim.load_minus_flux_data(box2_y2, box_y2_data)
    sim.load_minus_flux_data(box2_z1, box_z1_data)
    sim.load_minus_flux_data(box2_z2, box_z2_data)

    sim.run(until_after_sources=60) # maybe 20 is too little? 

    box_x1_flux = mp.get_fluxes(box2_x1)
    box_x2_flux = mp.get_fluxes(box2_x2)
    box_y1_flux = mp.get_fluxes(box2_y1)
    box_y2_flux = mp.get_fluxes(box2_y2)
    box_z1_flux = mp.get_fluxes(box2_z1)
    box_z2_flux = mp.get_fluxes(box2_z2)

    # Save individual components for later printing/plotting
    scatt_flux_components = {
        "X1": np.asarray(box_x1_flux)[0],
        "X2": np.asarray(box_x2_flux)[0],
        "Y1": np.asarray(box_y1_flux)[0],
        "Y2": np.asarray(box_y2_flux)[0],
        "Z1": np.asarray(box_z1_flux)[0],
        "Z2": np.asarray(box_z2_flux)[0],
    }
    return scatt_flux_components, inc_flux_components

flux_results = []
inc_flux_results = []

def print_parameters():
    print("Simulation Parameters:")
    print(f"  omega      = {omega}")
    print(f"  frequency  = {frq}")
    print(f"  wavelength = {wvl}")
    print(f"  resolution = {resolution}")
    print(f"  cell_size  = ({cell_size.x}, {cell_size.y}, {cell_size.z})")
    print(f"  PML thickness = {pml_thickness}")
    print(f"  monitor size  = {monitor_size}")
    print(f"  substrate ε   = {epsilon1}")
    print(f"  number of bumps = {len(bumps)}")
    print("  betas (deg)    =", [round(np.degrees(b), 2) for b in betas])
    print()

print_parameters()


for beta in betas:
    print("beta = " + str(beta))
    cos2 = np.cos(beta)**2
    sin2 = np.sin(beta)**2

    sources_1 = make_source(mp.Ey)
    sources_2 = make_source(mp.Ex)
    
    flux_1, inc_flux_1 = run_meep_simulation(sources_1)
    flux_2, inc_flux_2 = run_meep_simulation(sources_2)

    # Combine flux components manually
    flux_combined = {
        "beta": np.degrees(beta),
        "X1": cos2 * flux_1["X1"] + sin2 * flux_2["X1"],
        "X2": cos2 * flux_1["X2"] + sin2 * flux_2["X2"],
        "Y1": cos2 * flux_1["Y1"] + sin2 * flux_2["Y1"],
        "Y2": cos2 * flux_1["Y2"] + sin2 * flux_2["Y2"],
        "Z1": cos2 * flux_1["Z1"] + sin2 * flux_2["Z1"],
        "Z2": cos2 * flux_1["Z2"] + sin2 * flux_2["Z2"],
    }
    
    flux_results.append(flux_combined)
    
    # Combine flux components manually
    inc_flux_combined = {
        "beta": np.degrees(beta),
        "X1": cos2 * inc_flux_1["X1"] + sin2 * inc_flux_2["X1"],
        "X2": cos2 * inc_flux_1["X2"] + sin2 * inc_flux_2["X2"],
        "Y1": cos2 * inc_flux_1["Y1"] + sin2 * inc_flux_2["Y1"],
        "Y2": cos2 * inc_flux_1["Y2"] + sin2 * inc_flux_2["Y2"],
        "Z1": cos2 * inc_flux_1["Z1"] + sin2 * inc_flux_2["Z1"],
        "Z2": cos2 * inc_flux_1["Z2"] + sin2 * inc_flux_2["Z2"],
    }

    inc_flux_results.append(inc_flux_combined)
# Out:
# Simulation Parameters:
#   omega      = 1.0
#   frequency  = 0.15915494309189535
#   wavelength = 6.283185307179586
#   resolution = 10
#   cell_size  = (6.0, 6.0, 8.0)
#   PML thickness = 2
#   monitor size  = 1
#   substrate ε   = 2.56
#   number of bumps = 0
#   betas (deg)    = [0.0, 15.0, 30.0, 45.0, 60.0, 75.0, 90.0]
#
# beta = 0.0
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.0158491 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.480212 s
# -----------
# Meep progress: 6.45/70.0 = 9.2% done in 4.0s, 39.5s to go
# on time step 129 (time=6.45), 0.0310627 s/step
# Meep progress: 18.05/70.0 = 25.8% done in 8.0s, 23.1s to go
# on time step 361 (time=18.05), 0.017299 s/step
# Meep progress: 30.3/70.0 = 43.3% done in 12.0s, 15.8s to go
# on time step 606 (time=30.3), 0.016353 s/step
# Meep progress: 42.85/70.0 = 61.2% done in 16.0s, 10.2s to go
# on time step 857 (time=42.85), 0.0159598 s/step
# Meep progress: 55.300000000000004/70.0 = 79.0% done in 20.0s, 5.3s to go
# on time step 1106 (time=55.3), 0.0160868 s/step
# Meep progress: 67.60000000000001/70.0 = 96.6% done in 24.0s, 0.9s to go
# on time step 1352 (time=67.6), 0.0162794 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000300884 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 5.56459 s
# -----------
# Meep progress: 6.8500000000000005/70.0 = 9.8% done in 4.0s, 37.0s to go
# on time step 137 (time=6.85), 0.0292572 s/step
# Meep progress: 17.400000000000002/70.0 = 24.9% done in 8.0s, 24.2s to go
# on time step 348 (time=17.4), 0.0189622 s/step
# Meep progress: 29.85/70.0 = 42.6% done in 12.0s, 16.2s to go
# on time step 597 (time=29.85), 0.0160851 s/step
# Meep progress: 41.800000000000004/70.0 = 59.7% done in 16.0s, 10.8s to go
# on time step 836 (time=41.8), 0.0167548 s/step
# Meep progress: 52.6/70.0 = 75.1% done in 20.0s, 6.6s to go
# on time step 1053 (time=52.65), 0.0185018 s/step
# Meep progress: 64.3/70.0 = 91.9% done in 24.0s, 2.1s to go
# on time step 1287 (time=64.35), 0.0171398 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000468969 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.548575 s
# -----------
# Meep progress: 7.1000000000000005/70.0 = 10.1% done in 4.0s, 35.4s to go
# on time step 142 (time=7.1), 0.0281743 s/step
# Meep progress: 18.2/70.0 = 26.0% done in 8.0s, 22.8s to go
# on time step 364 (time=18.2), 0.0180735 s/step
# Meep progress: 30.0/70.0 = 42.9% done in 12.0s, 16.0s to go
# on time step 600 (time=30), 0.0170055 s/step
# Meep progress: 41.0/70.0 = 58.6% done in 16.0s, 11.3s to go
# on time step 820 (time=41), 0.0181875 s/step
# Meep progress: 51.800000000000004/70.0 = 74.0% done in 20.0s, 7.0s to go
# on time step 1036 (time=51.8), 0.0185325 s/step
# Meep progress: 64.10000000000001/70.0 = 91.6% done in 24.0s, 2.2s to go
# on time step 1282 (time=64.1), 0.0163034 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000370026 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 6.54546 s
# -----------
# Meep progress: 8.25/70.0 = 11.8% done in 4.0s, 30.0s to go
# on time step 165 (time=8.25), 0.0243079 s/step
# Meep progress: 20.35/70.0 = 29.1% done in 8.0s, 19.6s to go
# on time step 407 (time=20.35), 0.016537 s/step
# Meep progress: 31.450000000000003/70.0 = 44.9% done in 12.0s, 14.7s to go
# on time step 629 (time=31.45), 0.0180415 s/step
# Meep progress: 42.75/70.0 = 61.1% done in 16.0s, 10.2s to go
# on time step 855 (time=42.75), 0.0177345 s/step
# Meep progress: 54.650000000000006/70.0 = 78.1% done in 20.0s, 5.6s to go
# on time step 1093 (time=54.65), 0.0168556 s/step
# Meep progress: 66.4/70.0 = 94.9% done in 24.1s, 1.3s to go
# on time step 1328 (time=66.4), 0.0170931 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 0.2617993877991494
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000396013 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.529994 s
# -----------
# Meep progress: 7.45/70.0 = 10.6% done in 4.0s, 33.6s to go
# on time step 149 (time=7.45), 0.0268877 s/step
# Meep progress: 17.8/70.0 = 25.4% done in 8.0s, 23.5s to go
# on time step 356 (time=17.8), 0.0193593 s/step
# Meep progress: 30.150000000000002/70.0 = 43.1% done in 12.0s, 15.9s to go
# on time step 603 (time=30.15), 0.0162074 s/step
# Meep progress: 40.900000000000006/70.0 = 58.4% done in 16.0s, 11.4s to go
# on time step 818 (time=40.9), 0.0186569 s/step
# Meep progress: 52.1/70.0 = 74.4% done in 20.0s, 6.9s to go
# on time step 1042 (time=52.1), 0.0178581 s/step
# Meep progress: 62.300000000000004/70.0 = 89.0% done in 24.0s, 3.0s to go
# on time step 1246 (time=62.3), 0.0196687 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000750065 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 7.62474 s
# -----------
# Meep progress: 8.200000000000001/70.0 = 11.7% done in 4.0s, 30.2s to go
# on time step 164 (time=8.2), 0.0244081 s/step
# Meep progress: 20.55/70.0 = 29.4% done in 8.0s, 19.3s to go
# on time step 411 (time=20.55), 0.0162266 s/step
# Meep progress: 32.0/70.0 = 45.7% done in 12.0s, 14.3s to go
# on time step 641 (time=32.05), 0.0174747 s/step
# Meep progress: 43.800000000000004/70.0 = 62.6% done in 16.0s, 9.6s to go
# on time step 877 (time=43.85), 0.0169872 s/step
# Meep progress: 56.1/70.0 = 80.1% done in 20.0s, 5.0s to go
# on time step 1123 (time=56.15), 0.0163048 s/step
# Meep progress: 67.8/70.0 = 96.9% done in 24.0s, 0.8s to go
# on time step 1357 (time=67.85), 0.0171447 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000396013 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.521031 s
# -----------
# Meep progress: 7.25/70.0 = 10.4% done in 4.0s, 34.7s to go
# on time step 145 (time=7.25), 0.0276524 s/step
# Meep progress: 17.650000000000002/70.0 = 25.2% done in 8.0s, 23.8s to go
# on time step 353 (time=17.65), 0.0192419 s/step
# Meep progress: 28.900000000000002/70.0 = 41.3% done in 12.0s, 17.1s to go
# on time step 578 (time=28.9), 0.0177863 s/step
# Meep progress: 40.800000000000004/70.0 = 58.3% done in 16.0s, 11.5s to go
# on time step 816 (time=40.8), 0.0168594 s/step
# Meep progress: 52.900000000000006/70.0 = 75.6% done in 20.0s, 6.5s to go
# on time step 1058 (time=52.9), 0.0165492 s/step
# Meep progress: 64.75/70.0 = 92.5% done in 24.0s, 1.9s to go
# on time step 1295 (time=64.75), 0.0169207 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000374079 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 6.4799 s
# -----------
# Meep progress: 8.15/70.0 = 11.6% done in 4.0s, 30.5s to go
# on time step 163 (time=8.15), 0.0246282 s/step
# Meep progress: 19.85/70.0 = 28.4% done in 8.0s, 20.3s to go
# on time step 397 (time=19.85), 0.0171097 s/step
# Meep progress: 31.700000000000003/70.0 = 45.3% done in 12.0s, 14.5s to go
# on time step 634 (time=31.7), 0.016898 s/step
# Meep progress: 41.900000000000006/70.0 = 59.9% done in 16.0s, 10.7s to go
# on time step 839 (time=41.95), 0.0196262 s/step
# Meep progress: 51.7/70.0 = 73.9% done in 20.0s, 7.1s to go
# on time step 1036 (time=51.8), 0.0204034 s/step
# Meep progress: 63.300000000000004/70.0 = 90.4% done in 24.0s, 2.5s to go
# on time step 1268 (time=63.4), 0.0172488 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 0.5235987755982988
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00037694 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.551995 s
# -----------
# Meep progress: 7.15/70.0 = 10.2% done in 4.0s, 35.3s to go
# on time step 143 (time=7.15), 0.0280741 s/step
# Meep progress: 18.2/70.0 = 26.0% done in 8.0s, 22.8s to go
# on time step 364 (time=18.2), 0.0181219 s/step
# Meep progress: 28.35/70.0 = 40.5% done in 12.0s, 17.7s to go
# on time step 567 (time=28.35), 0.0197162 s/step
# Meep progress: 40.2/70.0 = 57.4% done in 16.0s, 11.9s to go
# on time step 804 (time=40.2), 0.0168963 s/step
# Meep progress: 51.550000000000004/70.0 = 73.6% done in 20.0s, 7.2s to go
# on time step 1031 (time=51.55), 0.0176507 s/step
# Meep progress: 63.0/70.0 = 90.0% done in 24.0s, 2.7s to go
# on time step 1260 (time=63), 0.0175185 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000529051 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 6.98916 s
# -----------
# Meep progress: 8.35/70.0 = 11.9% done in 4.0s, 29.6s to go
# on time step 167 (time=8.35), 0.0239719 s/step
# Meep progress: 20.5/70.0 = 29.3% done in 8.0s, 19.3s to go
# on time step 410 (time=20.5), 0.0164793 s/step
# Meep progress: 31.1/70.0 = 44.4% done in 12.0s, 15.0s to go
# on time step 622 (time=31.1), 0.0189638 s/step
# Meep progress: 41.300000000000004/70.0 = 59.0% done in 16.0s, 11.1s to go
# on time step 826 (time=41.3), 0.0196645 s/step
# Meep progress: 52.7/70.0 = 75.3% done in 20.1s, 6.6s to go
# on time step 1054 (time=52.7), 0.0175876 s/step
# Meep progress: 64.35000000000001/70.0 = 91.9% done in 24.1s, 2.1s to go
# on time step 1287 (time=64.35), 0.01722 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000467062 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.585427 s
# -----------
# Meep progress: 5.0/70.0 = 7.1% done in 4.0s, 52.2s to go
# on time step 100 (time=5), 0.0401531 s/step
# Meep progress: 15.75/70.0 = 22.5% done in 8.0s, 27.6s to go
# on time step 316 (time=15.8), 0.0185665 s/step
# Meep progress: 25.900000000000002/70.0 = 37.0% done in 12.0s, 20.5s to go
# on time step 519 (time=25.95), 0.0197335 s/step
# Meep progress: 36.15/70.0 = 51.6% done in 16.0s, 15.0s to go
# on time step 724 (time=36.2), 0.0195984 s/step
# Meep progress: 43.150000000000006/70.0 = 61.6% done in 20.0s, 12.5s to go
# on time step 864 (time=43.2), 0.0285966 s/step
# Meep progress: 53.5/70.0 = 76.4% done in 24.0s, 7.4s to go
# on time step 1072 (time=53.6), 0.0192731 s/step
# Meep progress: 64.35000000000001/70.0 = 91.9% done in 28.1s, 2.5s to go
# on time step 1289 (time=64.45), 0.0184928 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000432014 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 7.09641 s
# -----------
# Meep progress: 6.8500000000000005/70.0 = 9.8% done in 4.0s, 37.0s to go
# on time step 137 (time=6.85), 0.0293339 s/step
# Meep progress: 18.3/70.0 = 26.1% done in 8.0s, 22.6s to go
# on time step 367 (time=18.35), 0.0174626 s/step
# Meep progress: 29.25/70.0 = 41.8% done in 12.0s, 16.8s to go
# on time step 586 (time=29.3), 0.0182991 s/step
# Meep progress: 37.550000000000004/70.0 = 53.6% done in 16.1s, 13.9s to go
# on time step 751 (time=37.55), 0.0244874 s/step
# Meep progress: 42.550000000000004/70.0 = 60.8% done in 20.1s, 12.9s to go
# on time step 851 (time=42.55), 0.0402395 s/step
# Meep progress: 44.75/70.0 = 63.9% done in 24.2s, 13.6s to go
# on time step 895 (time=44.75), 0.0982268 s/step
# Meep progress: 46.45/70.0 = 66.4% done in 32.5s, 16.5s to go
# on time step 929 (time=46.45), 0.263252 s/step
# Meep progress: 46.7/70.0 = 66.7% done in 36.6s, 18.2s to go
# on time step 934 (time=46.7), 1.14298 s/step
# Meep progress: 46.75/70.0 = 66.8% done in 40.6s, 20.2s to go
# on time step 1046 (time=52.3), 0.0357876 s/step
# Meep progress: 52.35/70.0 = 74.8% done in 44.7s, 15.1s to go
# on time step 1203 (time=60.15), 0.0255752 s/step
# Meep progress: 60.2/70.0 = 86.0% done in 48.7s, 7.9s to go
# on time step 1352 (time=67.6), 0.0268597 s/step
# Meep progress: 67.65/70.0 = 96.6% done in 52.7s, 1.8s to go
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 0.7853981633974483
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00191307 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 1.22158 s
# -----------
# on time step 3 (time=0.15), 1.35624 s/step
# Meep progress: 0.2/70.0 = 0.3% done in 6.9s, 2401.2s to go
# on time step 9 (time=0.45), 0.67913 s/step
# Meep progress: 0.5/70.0 = 0.7% done in 11.6s, 1616.3s to go
# on time step 25 (time=1.25), 0.26656 s/step
# Meep progress: 1.3/70.0 = 1.9% done in 19.2s, 1014.4s to go
# on time step 31 (time=1.55), 0.707811 s/step
# Meep progress: 1.6/70.0 = 2.3% done in 30.5s, 1303.2s to go
# on time step 40 (time=2), 0.468017 s/step
# Meep progress: 2.0500000000000003/70.0 = 2.9% done in 36.8s, 1221.3s to go
# Meep progress: 2.4000000000000004/70.0 = 3.4% done in 41.3s, 1162.4s to go
# on time step 48 (time=2.4), 0.760159 s/step
# Meep progress: 5.15/70.0 = 7.4% done in 45.3s, 570.4s to go
# on time step 172 (time=8.6), 0.0323145 s/step
# Meep progress: 13.4/70.0 = 19.1% done in 49.3s, 208.3s to go
# on time step 330 (time=16.5), 0.0253749 s/step
# Meep progress: 23.5/70.0 = 33.6% done in 53.3s, 105.5s to go
# on time step 559 (time=27.95), 0.0175193 s/step
# Meep progress: 35.2/70.0 = 50.3% done in 57.3s, 56.7s to go
# on time step 793 (time=39.65), 0.0171019 s/step
# Meep progress: 46.95/70.0 = 67.1% done in 61.4s, 30.1s to go
# on time step 1034 (time=51.7), 0.0166186 s/step
# Meep progress: 59.050000000000004/70.0 = 84.4% done in 65.4s, 12.1s to go
# on time step 1274 (time=63.7), 0.0167325 s/step
# Meep progress: 69.75/70.0 = 99.6% done in 69.4s, 0.2s to go
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00068593 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 11.2251 s
# -----------
# Meep progress: 4.1000000000000005/70.0 = 5.9% done in 4.0s, 64.5s to go
# on time step 82 (time=4.1), 0.0489654 s/step
# Meep progress: 14.600000000000001/70.0 = 20.9% done in 8.0s, 30.4s to go
# on time step 292 (time=14.6), 0.0190998 s/step
# Meep progress: 25.05/70.0 = 35.8% done in 12.0s, 21.6s to go
# on time step 501 (time=25.05), 0.0191736 s/step
# Meep progress: 33.75/70.0 = 48.2% done in 16.1s, 17.2s to go
# on time step 675 (time=33.75), 0.0230854 s/step
# Meep progress: 42.35/70.0 = 60.5% done in 20.1s, 13.1s to go
# on time step 847 (time=42.35), 0.023353 s/step
# Meep progress: 51.25/70.0 = 73.2% done in 24.1s, 8.8s to go
# on time step 1025 (time=51.25), 0.0224831 s/step
# Meep progress: 59.6/70.0 = 85.1% done in 28.1s, 4.9s to go
# on time step 1192 (time=59.6), 0.024075 s/step
# Meep progress: 69.2/70.0 = 98.9% done in 32.1s, 0.4s to go
# on time step 1384 (time=69.2), 0.0208947 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00119996 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.636922 s
# -----------
# Meep progress: 6.3500000000000005/70.0 = 9.1% done in 4.0s, 40.3s to go
# on time step 127 (time=6.35), 0.0316291 s/step
# Meep progress: 17.150000000000002/70.0 = 24.5% done in 8.0s, 24.7s to go
# on time step 344 (time=17.2), 0.0185291 s/step
# Meep progress: 25.5/70.0 = 36.4% done in 12.0s, 21.0s to go
# on time step 511 (time=25.55), 0.024008 s/step
# Meep progress: 33.050000000000004/70.0 = 47.2% done in 16.1s, 17.9s to go
# on time step 661 (time=33.05), 0.0266873 s/step
# Meep progress: 39.650000000000006/70.0 = 56.6% done in 20.1s, 15.4s to go
# on time step 794 (time=39.7), 0.0303182 s/step
# Meep progress: 46.35/70.0 = 66.2% done in 24.1s, 12.3s to go
# on time step 929 (time=46.45), 0.0297914 s/step
# Meep progress: 55.800000000000004/70.0 = 79.7% done in 28.1s, 7.1s to go
# on time step 1118 (time=55.9), 0.0212282 s/step
# Meep progress: 64.0/70.0 = 91.4% done in 32.1s, 3.0s to go
# on time step 1282 (time=64.1), 0.0244337 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000503063 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 6.82856 s
# -----------
# Meep progress: 6.95/70.0 = 9.9% done in 4.0s, 36.5s to go
# on time step 139 (time=6.95), 0.028908 s/step
# Meep progress: 18.5/70.0 = 26.4% done in 8.0s, 22.3s to go
# on time step 370 (time=18.5), 0.0173543 s/step
# Meep progress: 29.25/70.0 = 41.8% done in 12.0s, 16.8s to go
# on time step 585 (time=29.25), 0.0186521 s/step
# Meep progress: 40.400000000000006/70.0 = 57.7% done in 16.0s, 11.8s to go
# on time step 808 (time=40.4), 0.0179376 s/step
# Meep progress: 52.7/70.0 = 75.3% done in 20.1s, 6.6s to go
# on time step 1054 (time=52.7), 0.0162837 s/step
# Meep progress: 63.45/70.0 = 90.6% done in 24.1s, 2.5s to go
# on time step 1269 (time=63.45), 0.0186319 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 1.0471975511965976
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000377893 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.517127 s
# -----------
# Meep progress: 5.75/70.0 = 8.2% done in 4.0s, 44.9s to go
# on time step 115 (time=5.75), 0.0349199 s/step
# Meep progress: 17.45/70.0 = 24.9% done in 8.0s, 24.2s to go
# on time step 349 (time=17.45), 0.0171419 s/step
# Meep progress: 29.200000000000003/70.0 = 41.7% done in 12.0s, 16.8s to go
# on time step 584 (time=29.2), 0.0170528 s/step
# Meep progress: 40.95/70.0 = 58.5% done in 16.0s, 11.4s to go
# on time step 819 (time=40.95), 0.0170341 s/step
# Meep progress: 52.900000000000006/70.0 = 75.6% done in 20.0s, 6.5s to go
# on time step 1059 (time=52.95), 0.0167404 s/step
# Meep progress: 64.95/70.0 = 92.8% done in 24.0s, 1.9s to go
# on time step 1300 (time=65), 0.0166127 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000356913 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 6.68677 s
# -----------
# Meep progress: 7.45/70.0 = 10.6% done in 4.0s, 33.7s to go
# on time step 149 (time=7.45), 0.0270228 s/step
# Meep progress: 18.650000000000002/70.0 = 26.6% done in 8.0s, 22.1s to go
# on time step 374 (time=18.7), 0.0178396 s/step
# Meep progress: 29.450000000000003/70.0 = 42.1% done in 12.0s, 16.6s to go
# on time step 591 (time=29.55), 0.018497 s/step
# Meep progress: 39.7/70.0 = 56.7% done in 16.0s, 12.2s to go
# on time step 795 (time=39.75), 0.0196227 s/step
# Meep progress: 50.95/70.0 = 72.8% done in 20.1s, 7.5s to go
# on time step 1021 (time=51.05), 0.017758 s/step
# Meep progress: 61.95/70.0 = 88.5% done in 24.1s, 3.1s to go
# on time step 1241 (time=62.05), 0.0182102 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00146389 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.520246 s
# -----------
# Meep progress: 0.05/70.0 = 0.1% done in 40.9s, 57249.8s to go
# on time step 1 (time=0.05), 50.3841 s/step
# Meep progress: 0.1/70.0 = 0.1% done in 95.8s, 66969.2s to go
# on time step 2 (time=0.1), 66.0439 s/step
# Meep progress: 0.15000000000000002/70.0 = 0.2% done in 219.9s, 102418.3s to go
# on time step 3 (time=0.15), 21.1947 s/step
# IOStream.flush timed out
# IOStream.flush timed out
# Meep progress: 0.2/70.0 = 0.3% done in 232.2s, 81037.4s to go
# on time step 150 (time=7.5), 0.027327 s/step
# Meep progress: 7.550000000000001/70.0 = 10.8% done in 236.2s, 1953.9s to go
# on time step 333 (time=16.65), 0.0219029 s/step
# Meep progress: 16.7/70.0 = 23.9% done in 240.2s, 766.8s to go
# on time step 568 (time=28.4), 0.0170456 s/step
# Meep progress: 28.450000000000003/70.0 = 40.6% done in 244.3s, 356.7s to go
# on time step 813 (time=40.65), 0.0163638 s/step
# Meep progress: 40.7/70.0 = 58.1% done in 248.3s, 178.8s to go
# on time step 1058 (time=52.9), 0.0163752 s/step
# Meep progress: 52.95/70.0 = 75.6% done in 252.4s, 81.3s to go
# on time step 1305 (time=65.25), 0.0161967 s/step
# Meep progress: 65.3/70.0 = 93.3% done in 256.4s, 18.5s to go
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00124598 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 6.85667 s
# -----------
# Meep progress: 8.35/70.0 = 11.9% done in 4.0s, 29.5s to go
# on time step 167 (time=8.35), 0.0240458 s/step
# Meep progress: 19.8/70.0 = 28.3% done in 8.0s, 20.3s to go
# on time step 396 (time=19.8), 0.0174821 s/step
# Meep progress: 31.25/70.0 = 44.6% done in 12.0s, 14.9s to go
# on time step 625 (time=31.25), 0.0174991 s/step
# Meep progress: 43.6/70.0 = 62.3% done in 16.0s, 9.7s to go
# on time step 873 (time=43.65), 0.0161541 s/step
# Meep progress: 53.85/70.0 = 76.9% done in 20.1s, 6.0s to go
# on time step 1079 (time=53.95), 0.019425 s/step
# Meep progress: 65.7/70.0 = 93.9% done in 24.1s, 1.6s to go
# on time step 1317 (time=65.85), 0.0168512 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 1.308996938995747
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000409126 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.530768 s
# -----------
# Meep progress: 0.05/70.0 = 0.1% done in 44.8s, 62631.3s to go
# on time step 1 (time=0.05), 44.9273 s/step
# Meep progress: 0.1/70.0 = 0.1% done in 58.6s, 40993.2s to go
# on time step 2 (time=0.1), 9.3023 s/step
# Meep progress: 0.15000000000000002/70.0 = 0.2% done in 71.4s, 33270.6s to go
# on time step 8 (time=0.4), 0.763234 s/step
# Meep progress: 0.45/70.0 = 0.6% done in 81.4s, 12588.3s to go
# on time step 10 (time=0.5), 2.62622 s/step
# Meep progress: 0.55/70.0 = 0.8% done in 89.6s, 11311.0s to go
# Meep progress: 0.9/70.0 = 1.3% done in 93.9s, 7210.8s to go
# on time step 18 (time=0.9), 0.685356 s/step
# Meep progress: 0.9500000000000001/70.0 = 1.4% done in 101.4s, 7367.8s to go
# on time step 19 (time=0.95), 4.92979 s/step
# Meep progress: 1.0/70.0 = 1.4% done in 111.2s, 7673.0s to go
# on time step 22 (time=1.1), 1.34689 s/step
# Meep progress: 1.1500000000000001/70.0 = 1.6% done in 117.7s, 7046.0s to go
# Meep progress: 1.35/70.0 = 1.9% done in 122.4s, 6226.1s to go
# on time step 27 (time=1.35), 1.17746 s/step
# Meep progress: 1.4000000000000001/70.0 = 2.0% done in 128.2s, 6281.4s to go
# Meep progress: 1.4500000000000002/70.0 = 2.1% done in 138.3s, 6538.7s to go
# on time step 29 (time=1.45), 8.10824 s/step
# Meep progress: 1.5/70.0 = 2.1% done in 154.1s, 7036.7s to go
# Meep progress: 1.85/70.0 = 2.6% done in 158.2s, 5826.3s to go
# on time step 37 (time=1.85), 0.729285 s/step
# Meep progress: 1.9000000000000001/70.0 = 2.7% done in 164.1s, 5880.9s to go
# on time step 42 (time=2.1), 0.880315 s/step
# Meep progress: 2.15/70.0 = 3.1% done in 173.2s, 5464.8s to go
# Meep progress: 2.35/70.0 = 3.4% done in 177.5s, 5108.6s to go
# on time step 47 (time=2.35), 1.12733 s/step
# Meep progress: 2.4000000000000004/70.0 = 3.4% done in 184.5s, 5196.5s to go
# on time step 49 (time=2.45), 2.34637 s/step
# Meep progress: 2.5/70.0 = 3.6% done in 193.5s, 5224.1s to go
# on time step 58 (time=2.9), 0.446234 s/step
# Meep progress: 2.95/70.0 = 4.2% done in 200.1s, 4548.6s to go
# on time step 77 (time=3.85), 0.219951 s/step
# Meep progress: 3.9000000000000004/70.0 = 5.6% done in 206.8s, 3505.4s to go
# on time step 83 (time=4.15), 0.737876 s/step
# Meep progress: 4.2/70.0 = 6.0% done in 225.9s, 3538.9s to go
# on time step 89 (time=4.45), 0.717464 s/step
# Meep progress: 4.5/70.0 = 6.4% done in 232.7s, 3387.5s to go
# on time step 101 (time=5.05), 0.333522 s/step
# IOStream.flush timed out
# Meep progress: 5.1000000000000005/70.0 = 7.3% done in 239.2s, 3043.6s to go
# on time step 110 (time=5.5), 0.471345 s/step
# Meep progress: 5.550000000000001/70.0 = 7.9% done in 248.2s, 2881.7s to go
# Meep progress: 5.8500000000000005/70.0 = 8.4% done in 252.5s, 2768.3s to go
# on time step 117 (time=5.85), 0.756741 s/step
# Meep progress: 5.9/70.0 = 8.4% done in 258.9s, 2812.9s to go
# on time step 123 (time=6.15), 0.686059 s/step
# Meep progress: 6.2/70.0 = 8.9% done in 265.1s, 2727.5s to go
# Meep progress: 6.65/70.0 = 9.5% done in 269.2s, 2564.4s to go
# on time step 133 (time=6.65), 0.458507 s/step
# Meep progress: 6.800000000000001/70.0 = 9.7% done in 273.6s, 2542.7s to go
# on time step 141 (time=7.05), 0.551341 s/step
# Meep progress: 7.1000000000000005/70.0 = 10.1% done in 280.2s, 2482.0s to go
# Meep progress: 7.550000000000001/70.0 = 10.8% done in 284.4s, 2352.4s to go
# on time step 151 (time=7.55), 0.696165 s/step
# Meep progress: 7.6000000000000005/70.0 = 10.9% done in 295.5s, 2426.3s to go
# on time step 162 (time=8.1), 0.396695 s/step
# Meep progress: 8.15/70.0 = 11.6% done in 305.7s, 2320.1s to go
# on time step 173 (time=8.65), 0.38333 s/step
# Meep progress: 8.700000000000001/70.0 = 12.4% done in 310.4s, 2187.3s to go
# on time step 191 (time=9.55), 0.234472 s/step
# Meep progress: 9.600000000000001/70.0 = 13.7% done in 316.5s, 1991.2s to go
# Meep progress: 9.75/70.0 = 13.9% done in 323.3s, 1997.9s to go
# on time step 195 (time=9.75), 2.44416 s/step
# Meep progress: 9.8/70.0 = 14.0% done in 342.4s, 2103.0s to go
# on time step 196 (time=9.8), 6.87522 s/step
# Meep progress: 9.850000000000001/70.0 = 14.1% done in 364.3s, 2224.6s to go
# on time step 197 (time=9.85), 17.0796 s/step
# Meep progress: 9.9/70.0 = 14.1% done in 409.3s, 2484.5s to go
# IOStream.flush timed out
# on time step 327 (time=16.35), 0.0310289 s/step
# Meep progress: 16.45/70.0 = 23.5% done in 413.3s, 1345.5s to go
# on time step 501 (time=25.05), 0.0230096 s/step
# Meep progress: 25.450000000000003/70.0 = 36.4% done in 417.3s, 730.6s to go
# on time step 687 (time=34.35), 0.0216027 s/step
# Meep progress: 34.6/70.0 = 49.4% done in 421.4s, 431.1s to go
# on time step 841 (time=42.05), 0.0260871 s/step
# Meep progress: 42.35/70.0 = 60.5% done in 425.4s, 277.7s to go
# on time step 976 (time=48.8), 0.0297972 s/step
# Meep progress: 49.050000000000004/70.0 = 70.1% done in 429.4s, 183.4s to go
# on time step 1093 (time=54.65), 0.0344263 s/step
# Meep progress: 54.800000000000004/70.0 = 78.3% done in 433.4s, 120.2s to go
# on time step 1212 (time=60.6), 0.0339988 s/step
# Meep progress: 60.7/70.0 = 86.7% done in 437.4s, 67.0s to go
# on time step 1363 (time=68.15), 0.0265386 s/step
# Meep progress: 68.3/70.0 = 97.6% done in 441.5s, 11.0s to go
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00893998 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 20.5479 s
# -----------
# Meep progress: 5.65/70.0 = 8.1% done in 4.0s, 45.6s to go
# on time step 113 (time=5.65), 0.0354384 s/step
# Meep progress: 17.150000000000002/70.0 = 24.5% done in 8.0s, 24.7s to go
# on time step 343 (time=17.15), 0.0173993 s/step
# Meep progress: 29.35/70.0 = 41.9% done in 12.0s, 16.7s to go
# on time step 587 (time=29.35), 0.0164531 s/step
# Meep progress: 40.75/70.0 = 58.2% done in 16.0s, 11.5s to go
# on time step 815 (time=40.75), 0.0175556 s/step
# Meep progress: 51.95/70.0 = 74.2% done in 20.0s, 7.0s to go
# on time step 1039 (time=51.95), 0.017901 s/step
# Meep progress: 63.6/70.0 = 90.9% done in 24.0s, 2.4s to go
# on time step 1272 (time=63.6), 0.0171913 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000381947 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.491236 s
# -----------
# Meep progress: 6.45/70.0 = 9.2% done in 4.0s, 39.5s to go
# on time step 129 (time=6.45), 0.0310503 s/step
# Meep progress: 18.900000000000002/70.0 = 27.0% done in 8.0s, 21.6s to go
# on time step 379 (time=18.95), 0.0160688 s/step
# Meep progress: 29.85/70.0 = 42.6% done in 12.0s, 16.2s to go
# on time step 597 (time=29.85), 0.0183628 s/step
# Meep progress: 42.0/70.0 = 60.0% done in 16.0s, 10.7s to go
# on time step 840 (time=42), 0.0164627 s/step
# Meep progress: 54.550000000000004/70.0 = 77.9% done in 20.0s, 5.7s to go
# on time step 1091 (time=54.55), 0.0159635 s/step
# Meep progress: 66.60000000000001/70.0 = 95.1% done in 24.0s, 1.2s to go
# on time step 1332 (time=66.6), 0.0166336 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000335932 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 6.04297 s
# -----------
# Meep progress: 8.65/70.0 = 12.4% done in 4.0s, 28.5s to go
# on time step 173 (time=8.65), 0.0232111 s/step
# Meep progress: 20.35/70.0 = 29.1% done in 8.0s, 19.6s to go
# on time step 407 (time=20.35), 0.0171312 s/step
# Meep progress: 31.85/70.0 = 45.5% done in 12.0s, 14.4s to go
# on time step 637 (time=31.85), 0.0174039 s/step
# Meep progress: 44.5/70.0 = 63.6% done in 16.0s, 9.2s to go
# on time step 890 (time=44.5), 0.0158535 s/step
# Meep progress: 57.050000000000004/70.0 = 81.5% done in 20.0s, 4.6s to go
# on time step 1141 (time=57.05), 0.0159562 s/step
# Meep progress: 69.75/70.0 = 99.6% done in 24.1s, 0.1s to go
# on time step 1395 (time=69.75), 0.0157783 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 1.5707963267948966
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000411987 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.505335 s
# -----------
# Meep progress: 5.45/70.0 = 7.8% done in 4.0s, 47.5s to go
# on time step 109 (time=5.45), 0.0367981 s/step
# Meep progress: 17.6/70.0 = 25.1% done in 8.0s, 23.9s to go
# on time step 352 (time=17.6), 0.0165107 s/step
# Meep progress: 29.900000000000002/70.0 = 42.7% done in 12.0s, 16.1s to go
# on time step 598 (time=29.9), 0.0162628 s/step
# Meep progress: 42.150000000000006/70.0 = 60.2% done in 16.0s, 10.6s to go
# on time step 843 (time=42.15), 0.0163887 s/step
# Meep progress: 54.95/70.0 = 78.5% done in 20.0s, 5.5s to go
# on time step 1100 (time=55), 0.0156243 s/step
# Meep progress: 67.55/70.0 = 96.5% done in 24.1s, 0.9s to go
# on time step 1352 (time=67.6), 0.0159336 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000288963 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 6.28686 s
# -----------
# Meep progress: 8.15/70.0 = 11.6% done in 4.0s, 30.5s to go
# on time step 163 (time=8.15), 0.0246261 s/step
# Meep progress: 20.1/70.0 = 28.7% done in 8.0s, 19.9s to go
# on time step 402 (time=20.1), 0.0167496 s/step
# Meep progress: 32.1/70.0 = 45.9% done in 12.0s, 14.2s to go
# on time step 642 (time=32.1), 0.0167257 s/step
# Meep progress: 40.5/70.0 = 57.9% done in 16.1s, 11.7s to go
# on time step 810 (time=40.5), 0.0239318 s/step
# Meep progress: 50.2/70.0 = 71.7% done in 20.1s, 7.9s to go
# on time step 1004 (time=50.2), 0.0206414 s/step
# Meep progress: 61.25/70.0 = 87.5% done in 24.1s, 3.4s to go
# on time step 1225 (time=61.25), 0.0181209 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000477791 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.483169 s
# -----------
# Meep progress: 7.4/70.0 = 10.6% done in 4.0s, 34.0s to go
# on time step 148 (time=7.4), 0.0271384 s/step
# Meep progress: 19.950000000000003/70.0 = 28.5% done in 8.0s, 20.1s to go
# on time step 399 (time=19.95), 0.0159712 s/step
# Meep progress: 31.75/70.0 = 45.4% done in 12.0s, 14.5s to go
# on time step 635 (time=31.75), 0.0169757 s/step
# Meep progress: 43.7/70.0 = 62.4% done in 16.0s, 9.7s to go
# on time step 874 (time=43.7), 0.0167997 s/step
# Meep progress: 55.0/70.0 = 78.6% done in 20.1s, 5.5s to go
# on time step 1100 (time=55), 0.0177459 s/step
# Meep progress: 67.45/70.0 = 96.4% done in 24.1s, 0.9s to go
# on time step 1349 (time=67.45), 0.0161097 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00028801 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 6.17808 s
# -----------
# Meep progress: 8.1/70.0 = 11.6% done in 4.0s, 30.7s to go
# on time step 162 (time=8.1), 0.0247963 s/step
# Meep progress: 19.55/70.0 = 27.9% done in 8.0s, 20.7s to go
# on time step 391 (time=19.55), 0.0174714 s/step
# Meep progress: 30.150000000000002/70.0 = 43.1% done in 12.0s, 15.9s to go
# on time step 603 (time=30.15), 0.0188831 s/step
# Meep progress: 41.550000000000004/70.0 = 59.4% done in 16.0s, 11.0s to go
# on time step 831 (time=41.55), 0.0175481 s/step
# Meep progress: 53.95/70.0 = 77.1% done in 20.0s, 6.0s to go
# on time step 1079 (time=53.95), 0.0161684 s/step
# Meep progress: 64.9/70.0 = 92.7% done in 24.0s, 1.9s to go
# on time step 1298 (time=64.9), 0.0183191 s/step
# run 0 finished at t = 70.0 (1400 timesteps)

# %%
d = flux_1
#d = flux_1
print("Size of dict:", len(d))
d
# Out:
# Size of dict: 6
# {'X1': 6.000428223480643e-19,
#  'X2': -7.491760100543548e-20,
#  'Y1': 5.940215916379039e-19,
#  'Y2': -3.8035170879493104e-19,
#  'Z1': 0.0025108845680653327,
#  'Z2': 0.0025110339246317286}

# %%
from tabulate import tabulate

# Convert to scalar values if needed
def scalar(val):
    return val.item() if isinstance(val, np.ndarray) else val



table_data = [
    [f"{scalar(row['beta']):.1f}°",
     f"{scalar(row['X1']):.5f}",
     f"{scalar(row['X2']):.5f}",
     f"{scalar(row['Y1']):.5f}",
     f"{scalar(row['Y2']):.5f}",
     f"{scalar(row['Z1']):.5f}",
     f"{scalar(row['Z2']):.5f}"]
    for row in flux_results
]

headers = ["β (°)", "X1 (−x)", "X2 (+x)", "Y1 (−y)", "Y2 (+y)", "Z1 (−z)", "Z2 (+z)"]
print(tabulate(table_data, headers=headers, tablefmt="github"))
# Out:
# | β (°)   |   X1 (−x) |   X2 (+x) |   Y1 (−y) |   Y2 (+y) |   Z1 (−z) |   Z2 (+z) |
# |---------|-----------|-----------|-----------|-----------|-----------|-----------|
# | 0.0°    |         0 |        -0 |         0 |        -0 |   0.00251 |   0.00251 |
# | 15.0°   |         0 |        -0 |         0 |        -0 |   0.00251 |   0.00251 |
# | 30.0°   |         0 |        -0 |         0 |        -0 |   0.00251 |   0.00251 |
# | 45.0°   |         0 |        -0 |         0 |         0 |   0.00251 |   0.00251 |
# | 60.0°   |         0 |        -0 |         0 |         0 |   0.00251 |   0.00251 |
# | 75.0°   |         0 |        -0 |         0 |         0 |   0.00251 |   0.00251 |
# | 90.0°   |         0 |        -0 |        -0 |         0 |   0.00251 |   0.00251 |

# %%
from tabulate import tabulate

# Convert to scalar values if needed
def scalar(val):
    return val.item() if isinstance(val, np.ndarray) else val



table_data = [
    [f"{scalar(row['beta']):.1f}°",
     f"{scalar(row['X1']):.15f}",
     f"{scalar(row['X2']):.15f}",
     f"{scalar(row['Y1']):.15f}",
     f"{scalar(row['Y2']):.15f}",
     f"{scalar(row['Z1']):.15f}",
     f"{scalar(row['Z2']):.15f}"]
    for row in inc_flux_results
]

headers = ["β (°)", "X1 (−x)", "X2 (+x)", "Y1 (−y)", "Y2 (+y)", "Z1 (−z)", "Z2 (+z)"]
print(tabulate(table_data, headers=headers, tablefmt="github"))
# Out:
# | β (°)   |   X1 (−x) |   X2 (+x) |   Y1 (−y) |   Y2 (+y) |    Z1 (−z) |    Z2 (+z) |
# |---------|-----------|-----------|-----------|-----------|------------|------------|
# | 0.0°    |        -0 |         0 |         0 |        -0 | -0.0467769 | -0.0467767 |
# | 15.0°   |        -0 |         0 |         0 |        -0 | -0.0467769 | -0.0467767 |
# | 30.0°   |        -0 |         0 |         0 |        -0 | -0.0467769 | -0.0467767 |
# | 45.0°   |         0 |         0 |         0 |        -0 | -0.0467769 | -0.0467767 |
# | 60.0°   |         0 |        -0 |        -0 |        -0 | -0.0467769 | -0.0467767 |
# | 75.0°   |         0 |        -0 |        -0 |         0 | -0.0467769 | -0.0467767 |
# | 90.0°   |         0 |        -0 |        -0 |         0 | -0.0467769 | -0.0467767 |

# %%
import numpy as np
import matplotlib.pyplot as plt

# Convert to scalar values if needed
def scalar(val):
    return val.item() if isinstance(val, np.ndarray) else val


# Extract data
betas = [scalar(entry['beta']) for entry in flux_results]
Z1 = [scalar(entry['Z1']) for entry in flux_results]
Z2 = [scalar(entry['Z2']) for entry in flux_results]
X1 = [scalar(entry['X1']) for entry in flux_results]
X2 = [scalar(entry['X2']) for entry in flux_results]
Y1 = [scalar(entry['Y1']) for entry in flux_results]
Y2 = [scalar(entry['Y2']) for entry in flux_results]


# Set up subplots
fig, axs = plt.subplots(3, 2, figsize=(12, 10))
axs = axs.flatten()

# Plot each component
labels = ['Z1 (−z)', 'Z2 (+z)', 'X1 (−x)', 'X2 (+x)', 'Y1 (−y)', 'Y2 (+y)']
values = [Z1, Z2, X1, X2, Y1, Y2]

for i, (label, val) in enumerate(zip(labels, values)):
    axs[i].plot(betas, val, marker='o')
    axs[i].set_title(label)
    axs[i].set_xlabel("β (degrees)")
    axs[i].set_ylabel("Flux")
    axs[i].grid(True)

# Hide unused subplot if any
if len(axs) > len(labels):
    axs[-1].axis('off')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Convert to scalar values if needed
def scalar(val):
    return val.item() if isinstance(val, np.ndarray) else val

# Extract data
betas = [scalar(entry['beta']) for entry in inc_flux_results]
Z1 = [scalar(entry['Z1']) for entry in inc_flux_results]
Z2 = [scalar(entry['Z2']) for entry in inc_flux_results]
X1 = [scalar(entry['X1']) for entry in inc_flux_results]
X2 = [scalar(entry['X2']) for entry in inc_flux_results]
Y1 = [scalar(entry['Y1']) for entry in inc_flux_results]
Y2 = [scalar(entry['Y2']) for entry in inc_flux_results]


# Set up subplots
fig, axs = plt.subplots(3, 2, figsize=(12, 10))
axs = axs.flatten()

# Plot each component
labels = ['Z1 (−z)', 'Z2 (+z)', 'X1 (−x)', 'X2 (+x)', 'Y1 (−y)', 'Y2 (+y)']
values = [Z1, Z2, X1, X2, Y1, Y2]

for i, (label, val) in enumerate(zip(labels, values)):
    axs[i].plot(betas, val, marker='o')
    axs[i].set_title(label)
    axs[i].set_xlabel("β (degrees)")
    axs[i].set_ylabel("Flux")
    axs[i].grid(True)

# Hide unused subplot if any
if len(axs) > len(labels):
    axs[-1].axis('off')

plt.tight_layout()
plt.show()
