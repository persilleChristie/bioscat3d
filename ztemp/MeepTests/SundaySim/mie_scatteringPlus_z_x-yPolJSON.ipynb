# %% [markdown]
# # Mie Scattering of a Lossless Dielectric Sphere
#
# A common reference calculation in computational electromagnetics for which an analytical solution is known is [Mie scattering](https://en.wikipedia.org/wiki/Mie_scattering) which involves computing the [scattering efficiency](http://www.thermopedia.com/content/956/) of a single, homogeneous sphere given an incident planewave. The scattered power of any object (absorbing or non) can be computed by surrounding it with a *closed* [DFT flux](https://meep.readthedocs.io/en/latest/Python_User_Interface/#flux-spectra) box (its size and orientation are irrelevant because of Poynting's theorem) and performing two simulations: (1) a normalization run involving an empty cell to save the incident fields from the source and (2) the scattering run with the object but first subtracting the incident fields in order to obtain just the scattered fields. This approach has already been described in [Transmittance Spectrum of a Waveguide Bend](https://meep.readthedocs.io/en/latest/Python_Tutorials/Basics#transmittance-spectrum-of-a-waveguide-bend).
#
# The scattering cross section is the scattered power in all directions divided by the incident intensity. The scattering efficiency, a dimensionless quantity, is the ratio of the scattering cross section to the cross sectional area of the sphere. In this demonstration, the sphere is a lossless dielectric with wavelength-independent refractive index of 2.0. This way, [subpixel smoothing](https://meep.readthedocs.io/en/latest/Subpixel_Smoothing) can improve accuracy at low resolutions which is important for reducing the size of this 3d simulation. The source is an $E_z$-polarized, planewave pulse (its `size` parameter fills the *entire* cell in 2d) spanning the broadband wavelength spectrum of 10% to 50% the circumference of the sphere. There is one subtlety: since the [planewave source extends into the PML](https://meep.readthedocs.io/en/latest/Perfectly_Matched_Layer/#planewave-sources-extending-into-pml) which surrounds the cell on all sides, `is_integrated=True` must be specified in the source object definition. A `k_point` of zero specifying periodic boundary conditions is necessary in order for the source to be infinitely extended. Also, given the [symmetry of the fields and the structure](https://meep.readthedocs.io/en/latest/Exploiting_Symmetry), two mirror symmery planes can be used to reduce the cell size by a factor of four. The simulation results are validated by comparing with the analytic theory obtained from the [PyMieScatt](https://pymiescatt.readthedocs.io/en/latest/) module (which you will have to install in order to run the script below).

# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
import json
import os

keyword = "Normal"
path = "SurfaceData/surfaceParams" + keyword + ".json"
def load_params(path = path):
    with open(path, "r") as f:
        return json.load(f)
params = load_params()

# Cell and resolution
pml_thickness = params["pml_thickness"]
monitor_size = params["monitor_size"]
half_x = params["halfWidth_x"]
half_y = params["halfWidth_y"]
half_z = params["halfWidth_z"]
cell_size = mp.Vector3(2*half_x + 2*pml_thickness,
                       2*half_y + 2*pml_thickness,
                       2*half_z + 2*pml_thickness)

omega = params["omega"]
betas = params["betas"]
# Material
epsilon1 = params["epsilon1"] 
substrate = mp.Medium(epsilon = epsilon1)
bumps = params["bumpData"]

## Must be at least 8 pixels per smallest wavelength, i.e. np.floor(8/wvl_min)
resolution = params["resolution"]

frq = params["omega"]/(2*np.pi)
wvl = 1 / frq

pml_layers = [mp.PML(thickness=pml_thickness)] 

def make_source(component):
    return [mp.Source(
        mp.GaussianSource(frequency=frq, fwidth=1, is_integrated=True),
        center=mp.Vector3(0, 0, half_z - 0.5),
        size=mp.Vector3(cell_size[0], cell_size[1], 0),
        component=component
    )]

def run_meep_simulation(sources):
    # Reference simulation (no bumps)
    sim = mp.Simulation(
        resolution=resolution,
        cell_size=cell_size,
        boundary_layers=pml_layers,
        sources=sources,
        k_point=mp.Vector3(),
    )

    box_x1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(x=-monitor_size/2), size=mp.Vector3(0, monitor_size, monitor_size)))
    box_x2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(x=+monitor_size/2), size=mp.Vector3(0, monitor_size, monitor_size)))
    box_y1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(y=-monitor_size/2), size=mp.Vector3(monitor_size, 0, monitor_size)))
    box_y2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(y=+monitor_size/2), size=mp.Vector3(monitor_size, 0, monitor_size)))
    box_z1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(z=-monitor_size/2), size=mp.Vector3(monitor_size, monitor_size, 0)))
    box_z2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(z=+monitor_size/2), size=mp.Vector3(monitor_size, monitor_size, 0)))

    sim.run(until_after_sources=60)

    box_x1_data = sim.get_flux_data(box_x1)
    box_x2_data = sim.get_flux_data(box_x2)
    box_y1_data = sim.get_flux_data(box_y1)
    box_y2_data = sim.get_flux_data(box_y2)
    box_z1_data = sim.get_flux_data(box_z1)
    box_z2_data = sim.get_flux_data(box_z2)

    box_x1_flux0 = mp.get_fluxes(box_x1)
    sim.reset_meep()

    # Structured simulation (with bumps)
    def material_function(p):
        z_surface = sum(
            b["height"] * np.exp(-((p.x - b["x0"])**2 + (p.y - b["y0"])**2) / (2 * b["sigma"]**2))
            for b in bumps
        )
        return substrate if p.z + 1.5 < z_surface else mp.air

    sim = mp.Simulation(
        resolution=resolution,
        cell_size=cell_size,
        boundary_layers=pml_layers,
        sources=sources,
        k_point=mp.Vector3(),
        default_material=material_function,
    )

    box_x1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(x=-monitor_size/2), size=mp.Vector3(0, monitor_size, monitor_size)))
    box_x2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(x=+monitor_size/2), size=mp.Vector3(0, monitor_size, monitor_size)))
    box_y1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(y=-monitor_size/2), size=mp.Vector3(monitor_size, 0, monitor_size)))
    box_y2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(y=+monitor_size/2), size=mp.Vector3(monitor_size, 0, monitor_size)))
    box_z1 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(z=-monitor_size/2), size=mp.Vector3(monitor_size, monitor_size, 0)))
    box_z2 = sim.add_flux(frq, 0, 1, mp.FluxRegion(center=mp.Vector3(z=+monitor_size/2), size=mp.Vector3(monitor_size, monitor_size, 0)))

    sim.load_minus_flux_data(box_x1, box_x1_data)
    sim.load_minus_flux_data(box_x2, box_x2_data)
    sim.load_minus_flux_data(box_y1, box_y1_data)
    sim.load_minus_flux_data(box_y2, box_y2_data)
    sim.load_minus_flux_data(box_z1, box_z1_data)
    sim.load_minus_flux_data(box_z2, box_z2_data)

    sim.run(until_after_sources=60) # maybe 20 is too little? 

    box_x1_flux = mp.get_fluxes(box_x1)
    box_x2_flux = mp.get_fluxes(box_x2)
    box_y1_flux = mp.get_fluxes(box_y1)
    box_y2_flux = mp.get_fluxes(box_y2)
    box_z1_flux = mp.get_fluxes(box_z1)
    box_z2_flux = mp.get_fluxes(box_z2)

    scatt_flux = (
        np.asarray(box_x1_flux)
        - np.asarray(box_x2_flux)
        + np.asarray(box_y1_flux)
        - np.asarray(box_y2_flux)
        + np.asarray(box_z1_flux)
        - np.asarray(box_z2_flux)
    )
    # Normalize by incident flux density (assuming monitor area = monitor_size²)
    intensity = np.asarray(box_x1_flux0) / (monitor_size)**2
    scatt_cross_section = np.divide(scatt_flux, intensity)
    # Meep flux convention: power leaving the box is positive
    scatt_eff = scatt_cross_section * -1 / (np.pi * 1**2) # r=1

    # Save individual components for later printing/plotting
    scatt_flux_components = {
        "X1": np.asarray(box_x1_flux)[0],
        "X2": np.asarray(box_x2_flux)[0],
        "Y1": np.asarray(box_y1_flux)[0],
        "Y2": np.asarray(box_y2_flux)[0],
        "Z1": np.asarray(box_z1_flux)[0],
        "Z2": np.asarray(box_z2_flux)[0],
        "scatt_total": scatt_flux[0],
    }


    return scatt_eff, scatt_flux_components

scatt_eff_list = []
flux_results = []

def print_parameters():
    print("Simulation Parameters:")
    print(f"  omega      = {omega}")
    print(f"  frequency  = {frq}")
    print(f"  wavelength = {wvl}")
    print(f"  resolution = {resolution}")
    print(f"  cell_size  = ({cell_size.x}, {cell_size.y}, {cell_size.z})")
    print(f"  PML thickness = {pml_thickness}")
    print(f"  monitor size  = {monitor_size}")
    print(f"  substrate ε   = {epsilon1}")
    print(f"  number of bumps = {len(bumps)}")
    print("  betas (deg)    =", [round(np.degrees(b), 2) for b in betas])
    print()

print_parameters()

for beta in betas:
    print("beta = " + str(beta))
    cos2 = np.cos(beta)**2
    sin2 = np.sin(beta)**2

    sources_1 = make_source(mp.Ey)
    sources_2 = make_source(mp.Ex)
    

    Qy, flux_1 = run_meep_simulation(sources_1)
    Qx, flux_2 = run_meep_simulation(sources_2)
    

    Q_beta = cos2 * Qx + sin2 * Qy
    scatt_eff_list.append(Q_beta)

    # Combine flux components manually
    flux_combined = {
        "beta": np.degrees(beta),
        "X1": cos2 * flux_1["X1"] + sin2 * flux_2["X1"],
        "X2": cos2 * flux_1["X2"] + sin2 * flux_2["X2"],
        "Y1": cos2 * flux_1["Y1"] + sin2 * flux_2["Y1"],
        "Y2": cos2 * flux_1["Y2"] + sin2 * flux_2["Y2"],
        "Z1": cos2 * flux_1["Z1"] + sin2 * flux_2["Z1"],
        "Z2": cos2 * flux_1["Z2"] + sin2 * flux_2["Z2"],
    }

    flux_results.append(flux_combined)
# Out:
# Simulation Parameters:
#   omega      = 1.0
#   frequency  = 0.15915494309189535
#   wavelength = 6.283185307179586
#   resolution = 10
#   cell_size  = (6.0, 6.0, 8.0)
#   PML thickness = 2
#   monitor size  = 1
#   substrate ε   = 2.56
#   number of bumps = 3
#   betas (deg)    = [0.0, 15.0, 30.0, 45.0, 60.0, 75.0, 90.0]
#
# beta = 0.0
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00627494 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.430395 s
# -----------
# Meep progress: 10.25/70.0 = 14.6% done in 4.0s, 23.4s to go
# on time step 205 (time=10.25), 0.019549 s/step
# Meep progress: 24.650000000000002/70.0 = 35.2% done in 8.0s, 14.7s to go
# on time step 493 (time=24.65), 0.0138921 s/step
# Meep progress: 38.650000000000006/70.0 = 55.2% done in 12.0s, 9.8s to go
# on time step 773 (time=38.65), 0.0143306 s/step
# Meep progress: 52.45/70.0 = 74.9% done in 16.0s, 5.4s to go
# on time step 1049 (time=52.45), 0.0145155 s/step
# Meep progress: 66.05/70.0 = 94.4% done in 20.0s, 1.2s to go
# on time step 1321 (time=66.05), 0.0147212 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000530005 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 13.5975 s
# -----------
# Meep progress: 9.15/70.0 = 13.1% done in 4.0s, 26.7s to go
# on time step 183 (time=9.15), 0.0219666 s/step
# Meep progress: 21.700000000000003/70.0 = 31.0% done in 8.0s, 17.9s to go
# on time step 434 (time=21.7), 0.0159561 s/step
# Meep progress: 34.75/70.0 = 49.6% done in 12.0s, 12.2s to go
# on time step 696 (time=34.8), 0.0153189 s/step
# Meep progress: 47.6/70.0 = 68.0% done in 16.0s, 7.5s to go
# on time step 953 (time=47.65), 0.0155982 s/step
# Meep progress: 60.5/70.0 = 86.4% done in 20.0s, 3.1s to go
# on time step 1211 (time=60.55), 0.0155186 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000338078 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.413616 s
# -----------
# Meep progress: 10.200000000000001/70.0 = 14.6% done in 4.0s, 23.5s to go
# on time step 204 (time=10.2), 0.0196237 s/step
# Meep progress: 22.700000000000003/70.0 = 32.4% done in 8.0s, 16.7s to go
# on time step 454 (time=22.7), 0.0161106 s/step
# Meep progress: 33.0/70.0 = 47.1% done in 12.0s, 13.5s to go
# on time step 660 (time=33), 0.01944 s/step
# Meep progress: 45.25/70.0 = 64.6% done in 16.0s, 8.8s to go
# on time step 905 (time=45.25), 0.0163493 s/step
# Meep progress: 58.45/70.0 = 83.5% done in 20.1s, 4.0s to go
# on time step 1169 (time=58.45), 0.015201 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000477076 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 13.6067 s
# -----------
# Meep progress: 9.3/70.0 = 13.3% done in 4.0s, 26.1s to go
# on time step 186 (time=9.3), 0.0215313 s/step
# Meep progress: 21.55/70.0 = 30.8% done in 8.0s, 18.0s to go
# on time step 432 (time=21.6), 0.0163282 s/step
# Meep progress: 34.4/70.0 = 49.1% done in 12.0s, 12.4s to go
# on time step 689 (time=34.45), 0.0155886 s/step
# Meep progress: 46.900000000000006/70.0 = 67.0% done in 16.0s, 7.9s to go
# on time step 939 (time=46.95), 0.0160443 s/step
# Meep progress: 59.35/70.0 = 84.8% done in 20.0s, 3.6s to go
# on time step 1188 (time=59.4), 0.0160708 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 0.2617993877991494
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000391006 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.506794 s
# -----------
# Meep progress: 9.35/70.0 = 13.4% done in 4.0s, 26.0s to go
# on time step 187 (time=9.35), 0.0214755 s/step
# Meep progress: 21.650000000000002/70.0 = 30.9% done in 8.0s, 17.9s to go
# on time step 433 (time=21.65), 0.0162998 s/step
# Meep progress: 33.2/70.0 = 47.4% done in 12.0s, 13.3s to go
# on time step 664 (time=33.2), 0.0173478 s/step
# Meep progress: 44.900000000000006/70.0 = 64.1% done in 16.0s, 9.0s to go
# on time step 898 (time=44.9), 0.0171501 s/step
# Meep progress: 57.0/70.0 = 81.4% done in 20.1s, 4.6s to go
# on time step 1140 (time=57), 0.0165423 s/step
# Meep progress: 68.65/70.0 = 98.1% done in 24.1s, 0.5s to go
# on time step 1373 (time=68.65), 0.0172147 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00030303 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 17.7468 s
# -----------
# Meep progress: 6.95/70.0 = 9.9% done in 4.0s, 36.3s to go
# on time step 139 (time=6.95), 0.0287822 s/step
# Meep progress: 18.5/70.0 = 26.4% done in 8.0s, 22.3s to go
# on time step 370 (time=18.5), 0.0173331 s/step
# Meep progress: 27.6/70.0 = 39.4% done in 12.0s, 18.5s to go
# on time step 552 (time=27.6), 0.0220455 s/step
# Meep progress: 38.7/70.0 = 55.3% done in 16.0s, 13.0s to go
# on time step 774 (time=38.7), 0.0180434 s/step
# Meep progress: 50.650000000000006/70.0 = 72.4% done in 20.0s, 7.7s to go
# on time step 1013 (time=50.65), 0.0167972 s/step
# Meep progress: 59.1/70.0 = 84.4% done in 24.0s, 4.4s to go
# on time step 1183 (time=59.15), 0.0237287 s/step
# Meep progress: 64.9/70.0 = 92.7% done in 28.0s, 2.2s to go
# on time step 1299 (time=64.95), 0.0347668 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000527143 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.578023 s
# -----------
# Meep progress: 4.4/70.0 = 6.3% done in 4.0s, 59.8s to go
# on time step 88 (time=4.4), 0.0456081 s/step
# Meep progress: 16.05/70.0 = 22.9% done in 8.0s, 27.0s to go
# on time step 321 (time=16.05), 0.0171878 s/step
# Meep progress: 28.0/70.0 = 40.0% done in 12.0s, 18.1s to go
# on time step 560 (time=28), 0.0168035 s/step
# Meep progress: 37.800000000000004/70.0 = 54.0% done in 16.0s, 13.7s to go
# on time step 756 (time=37.8), 0.0204562 s/step
# Meep progress: 49.7/70.0 = 71.0% done in 20.1s, 8.2s to go
# on time step 994 (time=49.7), 0.0168619 s/step
# Meep progress: 61.6/70.0 = 88.0% done in 24.1s, 3.3s to go
# on time step 1232 (time=61.6), 0.0168573 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000774145 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 14.8767 s
# -----------
# Meep progress: 6.65/70.0 = 9.5% done in 4.0s, 38.1s to go
# on time step 133 (time=6.65), 0.0301027 s/step
# Meep progress: 16.7/70.0 = 23.9% done in 8.0s, 25.6s to go
# on time step 334 (time=16.7), 0.0199638 s/step
# Meep progress: 28.0/70.0 = 40.0% done in 12.0s, 18.0s to go
# on time step 560 (time=28), 0.0177615 s/step
# Meep progress: 39.2/70.0 = 56.0% done in 16.0s, 12.6s to go
# on time step 784 (time=39.2), 0.0179219 s/step
# Meep progress: 50.800000000000004/70.0 = 72.6% done in 20.0s, 7.6s to go
# on time step 1016 (time=50.8), 0.0172496 s/step
# Meep progress: 61.0/70.0 = 87.1% done in 24.0s, 3.5s to go
# on time step 1221 (time=61.05), 0.0195862 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 0.5235987755982988
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000436068 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.56717 s
# -----------
# Meep progress: 8.05/70.0 = 11.5% done in 4.0s, 30.8s to go
# on time step 161 (time=8.05), 0.0248492 s/step
# Meep progress: 18.900000000000002/70.0 = 27.0% done in 8.0s, 21.6s to go
# on time step 378 (time=18.9), 0.018436 s/step
# Meep progress: 30.400000000000002/70.0 = 43.4% done in 12.0s, 15.7s to go
# on time step 608 (time=30.4), 0.0174423 s/step
# Meep progress: 42.550000000000004/70.0 = 60.8% done in 16.0s, 10.3s to go
# on time step 851 (time=42.55), 0.0165122 s/step
# Meep progress: 54.400000000000006/70.0 = 77.7% done in 20.0s, 5.7s to go
# on time step 1088 (time=54.4), 0.0169053 s/step
# Meep progress: 64.5/70.0 = 92.1% done in 24.0s, 2.1s to go
# on time step 1290 (time=64.5), 0.0198329 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000378132 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 18.0897 s
# -----------
# Meep progress: 4.45/70.0 = 6.4% done in 4.0s, 59.0s to go
# on time step 89 (time=4.45), 0.0449965 s/step
# Meep progress: 14.8/70.0 = 21.1% done in 8.0s, 29.9s to go
# on time step 297 (time=14.85), 0.0193117 s/step
# Meep progress: 25.150000000000002/70.0 = 35.9% done in 12.0s, 21.4s to go
# on time step 504 (time=25.2), 0.01942 s/step
# Meep progress: 36.25/70.0 = 51.8% done in 16.0s, 14.9s to go
# on time step 726 (time=36.3), 0.0180305 s/step
# Meep progress: 47.300000000000004/70.0 = 67.6% done in 20.0s, 9.6s to go
# on time step 947 (time=47.35), 0.0181309 s/step
# Meep progress: 60.0/70.0 = 85.7% done in 24.1s, 4.0s to go
# on time step 1201 (time=60.05), 0.0157999 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000432014 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.529179 s
# -----------
# Meep progress: 8.25/70.0 = 11.8% done in 4.0s, 30.0s to go
# on time step 165 (time=8.25), 0.0243141 s/step
# Meep progress: 20.35/70.0 = 29.1% done in 8.0s, 19.6s to go
# on time step 407 (time=20.35), 0.0165477 s/step
# Meep progress: 30.400000000000002/70.0 = 43.4% done in 12.0s, 15.7s to go
# on time step 608 (time=30.4), 0.0200433 s/step
# Meep progress: 38.45/70.0 = 54.9% done in 16.1s, 13.2s to go
# on time step 769 (time=38.45), 0.0249621 s/step
# Meep progress: 44.0/70.0 = 62.9% done in 20.1s, 11.9s to go
# on time step 880 (time=44), 0.0363241 s/step
# Meep progress: 48.900000000000006/70.0 = 69.9% done in 24.1s, 10.4s to go
# on time step 978 (time=48.9), 0.0410652 s/step
# Meep progress: 55.95/70.0 = 79.9% done in 28.1s, 7.1s to go
# on time step 1119 (time=55.95), 0.0284857 s/step
# Meep progress: 63.650000000000006/70.0 = 90.9% done in 32.1s, 3.2s to go
# on time step 1273 (time=63.65), 0.0259776 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000296831 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 16.6005 s
# -----------
# Meep progress: 10.100000000000001/70.0 = 14.4% done in 4.0s, 23.7s to go
# on time step 202 (time=10.1), 0.0198143 s/step
# Meep progress: 24.75/70.0 = 35.4% done in 8.0s, 14.6s to go
# on time step 496 (time=24.8), 0.0136512 s/step
# Meep progress: 38.7/70.0 = 55.3% done in 12.0s, 9.7s to go
# on time step 775 (time=38.75), 0.0143404 s/step
# Meep progress: 53.2/70.0 = 76.0% done in 16.0s, 5.1s to go
# on time step 1065 (time=53.25), 0.0137991 s/step
# Meep progress: 67.3/70.0 = 96.1% done in 20.0s, 0.8s to go
# on time step 1347 (time=67.35), 0.0142269 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 0.7853981633974483
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000403166 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.459119 s
# -----------
# Meep progress: 9.15/70.0 = 13.1% done in 4.0s, 26.7s to go
# on time step 183 (time=9.15), 0.0219462 s/step
# Meep progress: 15.3/70.0 = 21.9% done in 8.0s, 28.7s to go
# on time step 306 (time=15.3), 0.0327128 s/step
# Meep progress: 19.75/70.0 = 28.2% done in 12.1s, 30.7s to go
# on time step 395 (time=19.75), 0.045286 s/step
# Meep progress: 26.1/70.0 = 37.3% done in 16.1s, 27.0s to go
# on time step 522 (time=26.1), 0.0315362 s/step
# Meep progress: 38.35/70.0 = 54.8% done in 20.1s, 16.6s to go
# on time step 767 (time=38.35), 0.0163796 s/step
# Meep progress: 49.75/70.0 = 71.1% done in 24.1s, 9.8s to go
# on time step 995 (time=49.75), 0.0176223 s/step
# Meep progress: 62.85/70.0 = 89.8% done in 28.1s, 3.2s to go
# on time step 1257 (time=62.85), 0.0152781 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000340223 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 16.7871 s
# -----------
# Meep progress: 9.450000000000001/70.0 = 13.5% done in 4.0s, 25.7s to go
# on time step 189 (time=9.45), 0.0212196 s/step
# Meep progress: 20.450000000000003/70.0 = 29.2% done in 8.0s, 19.5s to go
# on time step 409 (time=20.45), 0.0183096 s/step
# Meep progress: 25.6/70.0 = 36.6% done in 12.1s, 21.0s to go
# on time step 512 (time=25.6), 0.0392169 s/step
# Meep progress: 32.1/70.0 = 45.9% done in 16.1s, 19.0s to go
# on time step 642 (time=32.1), 0.0308469 s/step
# Meep progress: 40.050000000000004/70.0 = 57.2% done in 20.1s, 15.0s to go
# on time step 801 (time=40.05), 0.0252347 s/step
# Meep progress: 51.35/70.0 = 73.4% done in 24.1s, 8.8s to go
# on time step 1027 (time=51.35), 0.0177166 s/step
# Meep progress: 63.300000000000004/70.0 = 90.4% done in 28.1s, 3.0s to go
# on time step 1266 (time=63.3), 0.0167945 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000344038 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.483099 s
# -----------
# Meep progress: 7.95/70.0 = 11.4% done in 4.0s, 31.3s to go
# on time step 159 (time=7.95), 0.0252109 s/step
# Meep progress: 21.700000000000003/70.0 = 31.0% done in 8.0s, 17.8s to go
# on time step 434 (time=21.7), 0.0145613 s/step
# Meep progress: 35.25/70.0 = 50.4% done in 12.0s, 11.9s to go
# on time step 705 (time=35.25), 0.0148045 s/step
# Meep progress: 48.050000000000004/70.0 = 68.6% done in 16.0s, 7.3s to go
# on time step 961 (time=48.05), 0.0156508 s/step
# Meep progress: 61.300000000000004/70.0 = 87.6% done in 20.0s, 2.8s to go
# on time step 1226 (time=61.3), 0.0151051 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00031209 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 18.0145 s
# -----------
# Meep progress: 8.700000000000001/70.0 = 12.4% done in 4.0s, 28.2s to go
# on time step 174 (time=8.7), 0.0230271 s/step
# Meep progress: 21.05/70.0 = 30.1% done in 8.0s, 18.6s to go
# on time step 421 (time=21.05), 0.0162069 s/step
# Meep progress: 34.25/70.0 = 48.9% done in 12.0s, 12.6s to go
# on time step 685 (time=34.25), 0.0151997 s/step
# Meep progress: 47.050000000000004/70.0 = 67.2% done in 16.0s, 7.8s to go
# on time step 941 (time=47.05), 0.0156812 s/step
# Meep progress: 60.1/70.0 = 85.9% done in 20.0s, 3.3s to go
# on time step 1202 (time=60.1), 0.0153497 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 1.0471975511965976
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000373125 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.503117 s
# -----------
# Meep progress: 9.600000000000001/70.0 = 13.7% done in 4.0s, 25.3s to go
# on time step 192 (time=9.6), 0.0209081 s/step
# Meep progress: 23.700000000000003/70.0 = 33.9% done in 8.0s, 15.7s to go
# on time step 474 (time=23.7), 0.0141883 s/step
# Meep progress: 36.95/70.0 = 52.8% done in 12.0s, 10.7s to go
# on time step 739 (time=36.95), 0.0150948 s/step
# Meep progress: 49.900000000000006/70.0 = 71.3% done in 16.0s, 6.5s to go
# on time step 998 (time=49.9), 0.0154785 s/step
# Meep progress: 61.95/70.0 = 88.5% done in 20.0s, 2.6s to go
# on time step 1239 (time=61.95), 0.0166101 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000329018 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 16.8175 s
# -----------
# Meep progress: 8.1/70.0 = 11.6% done in 4.0s, 30.7s to go
# on time step 162 (time=8.1), 0.0247635 s/step
# Meep progress: 21.3/70.0 = 30.4% done in 8.0s, 18.4s to go
# on time step 426 (time=21.3), 0.0152039 s/step
# Meep progress: 33.1/70.0 = 47.3% done in 12.0s, 13.4s to go
# on time step 662 (time=33.1), 0.0169983 s/step
# Meep progress: 46.45/70.0 = 66.4% done in 16.0s, 8.1s to go
# on time step 930 (time=46.5), 0.014983 s/step
# Meep progress: 59.5/70.0 = 85.0% done in 20.0s, 3.5s to go
# on time step 1191 (time=59.55), 0.0153407 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000333071 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.525422 s
# -----------
# Meep progress: 7.6000000000000005/70.0 = 10.9% done in 4.0s, 32.9s to go
# on time step 152 (time=7.6), 0.0263686 s/step
# Meep progress: 20.150000000000002/70.0 = 28.8% done in 8.0s, 19.8s to go
# on time step 403 (time=20.15), 0.0159429 s/step
# Meep progress: 34.2/70.0 = 48.9% done in 12.0s, 12.6s to go
# on time step 684 (time=34.2), 0.0142835 s/step
# Meep progress: 47.6/70.0 = 68.0% done in 16.0s, 7.5s to go
# on time step 952 (time=47.6), 0.0149425 s/step
# Meep progress: 60.0/70.0 = 85.7% done in 20.0s, 3.3s to go
# on time step 1200 (time=60), 0.0161462 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00029397 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 19.4896 s
# -----------
# Meep progress: 6.8500000000000005/70.0 = 9.8% done in 4.0s, 36.9s to go
# on time step 137 (time=6.85), 0.0292181 s/step
# Meep progress: 15.55/70.0 = 22.2% done in 8.0s, 28.0s to go
# on time step 311 (time=15.55), 0.0230013 s/step
# Meep progress: 25.450000000000003/70.0 = 36.4% done in 12.0s, 21.0s to go
# on time step 509 (time=25.45), 0.020224 s/step
# Meep progress: 36.300000000000004/70.0 = 51.9% done in 16.0s, 14.9s to go
# on time step 726 (time=36.3), 0.0185114 s/step
# Meep progress: 47.050000000000004/70.0 = 67.2% done in 20.0s, 9.8s to go
# on time step 941 (time=47.05), 0.018664 s/step
# Meep progress: 56.5/70.0 = 80.7% done in 24.1s, 5.7s to go
# on time step 1130 (time=56.5), 0.0212143 s/step
# Meep progress: 68.0/70.0 = 97.1% done in 28.1s, 0.8s to go
# on time step 1360 (time=68), 0.017459 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 1.308996938995747
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000316858 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.506675 s
# -----------
# Meep progress: 9.0/70.0 = 12.9% done in 4.0s, 27.2s to go
# on time step 180 (time=9), 0.0222781 s/step
# Meep progress: 21.8/70.0 = 31.1% done in 8.0s, 17.7s to go
# on time step 436 (time=21.8), 0.0156834 s/step
# Meep progress: 34.85/70.0 = 49.8% done in 12.0s, 12.1s to go
# on time step 698 (time=34.9), 0.0153545 s/step
# Meep progress: 46.900000000000006/70.0 = 67.0% done in 16.0s, 7.9s to go
# on time step 940 (time=47), 0.0165716 s/step
# Meep progress: 60.300000000000004/70.0 = 86.1% done in 20.0s, 3.2s to go
# on time step 1208 (time=60.4), 0.0149689 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000398874 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 15.996 s
# -----------
# Meep progress: 8.35/70.0 = 11.9% done in 4.0s, 29.6s to go
# on time step 167 (time=8.35), 0.0240372 s/step
# Meep progress: 21.35/70.0 = 30.5% done in 8.0s, 18.3s to go
# on time step 427 (time=21.35), 0.0154343 s/step
# Meep progress: 34.45/70.0 = 49.2% done in 12.0s, 12.4s to go
# on time step 689 (time=34.45), 0.0152834 s/step
# Meep progress: 48.2/70.0 = 68.9% done in 16.0s, 7.3s to go
# on time step 964 (time=48.2), 0.0145956 s/step
# Meep progress: 61.800000000000004/70.0 = 88.3% done in 20.1s, 2.7s to go
# on time step 1236 (time=61.8), 0.0147348 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000496864 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.586174 s
# -----------
# Meep progress: 8.8/70.0 = 12.6% done in 4.0s, 27.9s to go
# on time step 176 (time=8.8), 0.0228085 s/step
# Meep progress: 21.75/70.0 = 31.1% done in 8.0s, 17.8s to go
# on time step 435 (time=21.75), 0.0154753 s/step
# Meep progress: 34.7/70.0 = 49.6% done in 12.0s, 12.2s to go
# on time step 694 (time=34.7), 0.0154925 s/step
# Meep progress: 46.650000000000006/70.0 = 66.6% done in 16.0s, 8.0s to go
# on time step 933 (time=46.65), 0.0167477 s/step
# Meep progress: 59.900000000000006/70.0 = 85.6% done in 20.1s, 3.4s to go
# on time step 1198 (time=59.9), 0.0151438 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000396013 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 16.3819 s
# -----------
# Meep progress: 9.05/70.0 = 12.9% done in 4.0s, 27.0s to go
# on time step 181 (time=9.05), 0.0221442 s/step
# Meep progress: 22.0/70.0 = 31.4% done in 8.0s, 17.5s to go
# on time step 440 (time=22), 0.0154771 s/step
# Meep progress: 34.050000000000004/70.0 = 48.6% done in 12.0s, 12.7s to go
# on time step 681 (time=34.05), 0.0166513 s/step
# Meep progress: 46.75/70.0 = 66.8% done in 16.0s, 8.0s to go
# on time step 936 (time=46.8), 0.0157426 s/step
# Meep progress: 59.2/70.0 = 84.6% done in 20.0s, 3.7s to go
# on time step 1185 (time=59.25), 0.0160795 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# beta = 1.5707963267948966
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000329971 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.473675 s
# -----------
# Meep progress: 9.25/70.0 = 13.2% done in 4.0s, 26.4s to go
# on time step 185 (time=9.25), 0.0217019 s/step
# Meep progress: 23.05/70.0 = 32.9% done in 8.0s, 16.3s to go
# on time step 461 (time=23.05), 0.0145245 s/step
# Meep progress: 37.050000000000004/70.0 = 52.9% done in 12.0s, 10.7s to go
# on time step 741 (time=37.05), 0.0142892 s/step
# Meep progress: 51.150000000000006/70.0 = 73.1% done in 16.0s, 5.9s to go
# on time step 1023 (time=51.15), 0.0142231 s/step
# Meep progress: 64.2/70.0 = 91.7% done in 20.0s, 1.8s to go
# on time step 1284 (time=64.2), 0.0153554 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000316143 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 15.9483 s
# -----------
# Meep progress: 9.450000000000001/70.0 = 13.5% done in 4.0s, 25.7s to go
# on time step 189 (time=9.45), 0.0212223 s/step
# Meep progress: 22.35/70.0 = 31.9% done in 8.0s, 17.1s to go
# on time step 447 (time=22.35), 0.0155141 s/step
# Meep progress: 35.85/70.0 = 51.2% done in 12.0s, 11.5s to go
# on time step 717 (time=35.85), 0.0148359 s/step
# Meep progress: 49.650000000000006/70.0 = 70.9% done in 16.0s, 6.6s to go
# on time step 994 (time=49.7), 0.0144913 s/step
# Meep progress: 63.400000000000006/70.0 = 90.6% done in 20.0s, 2.1s to go
# on time step 1268 (time=63.4), 0.0146076 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000396967 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 0.497653 s
# -----------
# Meep progress: 8.65/70.0 = 12.4% done in 4.0s, 28.5s to go
# on time step 173 (time=8.65), 0.0232104 s/step
# Meep progress: 20.650000000000002/70.0 = 29.5% done in 8.0s, 19.2s to go
# on time step 413 (time=20.65), 0.0166976 s/step
# Meep progress: 34.050000000000004/70.0 = 48.6% done in 12.0s, 12.7s to go
# on time step 681 (time=34.05), 0.0149557 s/step
# Meep progress: 48.1/70.0 = 68.7% done in 16.0s, 7.3s to go
# on time step 962 (time=48.1), 0.0142579 s/step
# Meep progress: 59.900000000000006/70.0 = 85.6% done in 20.1s, 3.4s to go
# on time step 1198 (time=59.9), 0.0170497 s/step
# run 0 finished at t = 70.0 (1400 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000365019 s
# Working in 3D dimensions.
# Computational cell is 6 x 6 x 8 with resolution 10
# time for set_epsilon = 15.9982 s
# -----------
# Meep progress: 9.5/70.0 = 13.6% done in 4.0s, 25.5s to go
# on time step 190 (time=9.5), 0.021075 s/step
# Meep progress: 21.55/70.0 = 30.8% done in 8.0s, 18.0s to go
# on time step 431 (time=21.55), 0.0166533 s/step
# Meep progress: 34.85/70.0 = 49.8% done in 12.0s, 12.1s to go
# on time step 697 (time=34.85), 0.0150719 s/step
# Meep progress: 47.5/70.0 = 67.9% done in 16.0s, 7.6s to go
# on time step 950 (time=47.5), 0.0158254 s/step
# Meep progress: 59.800000000000004/70.0 = 85.4% done in 20.0s, 3.4s to go
# on time step 1196 (time=59.8), 0.016282 s/step
# run 0 finished at t = 70.0 (1400 timesteps)

# %%
plt.plot([np.degrees(b) for b in betas], scatt_eff_list, marker='o')
plt.xlabel("Polarization angle β (degrees)")
plt.ylabel("Scattering efficiency")
plt.grid(True)
plt.title("Scattering efficiency vs. polarization angle")
plt.show()

# %%
from tabulate import tabulate

def scalar(val):
    return val.item() if isinstance(val, np.ndarray) else val

table_data = [
    [f"{scalar(row['beta']):.1f}°",
     f"{scalar(row['X1']):.5f}",
     f"{scalar(row['X2']):.5f}",
     f"{scalar(row['Y1']):.5f}",
     f"{scalar(row['Y2']):.5f}",
     f"{scalar(row['Z1']):.5f}",
     f"{scalar(row['Z2']):.5f}",
     f"{scalar(row['scatt_total']):.5f}"]
    for row in flux_results
]

headers = ["β (°)", "X1 (−x)", "X2 (+x)", "Y1 (−y)", "Y2 (+y)", "Z1 (−z)", "Z2 (+z)", "Scatt. Total"]
print(tabulate(table_data, headers=headers, tablefmt="github"))
# Out:
# | β (°)   |   X1 (−x) |   X2 (+x) |   Y1 (−y) |   Y2 (+y) |   Z1 (−z) |   Z2 (+z) |   Scatt. Total |
# |---------|-----------|-----------|-----------|-----------|-----------|-----------|----------------|
# | 0.0°    |    -0     |     0     |     4e-05 |     1e-05 |   0.00221 |   0.00224 |              0 |
# | 15.0°   |    -0     |    -0     |     4e-05 |     1e-05 |   0.00221 |   0.00224 |              0 |
# | 30.0°   |     0     |    -1e-05 |     3e-05 |     0     |   0.0022  |   0.00224 |              0 |
# | 45.0°   |     1e-05 |    -2e-05 |     2e-05 |    -0     |   0.00219 |   0.00224 |              0 |
# | 60.0°   |     2e-05 |    -4e-05 |     1e-05 |    -0     |   0.00217 |   0.00224 |              0 |
# | 75.0°   |     2e-05 |    -5e-05 |    -0     |    -1e-05 |   0.00216 |   0.00224 |              0 |
# | 90.0°   |     3e-05 |    -5e-05 |    -0     |    -1e-05 |   0.00216 |   0.00224 |              0 |

# %%
def scalar(val):
    return val.item() if isinstance(val, np.ndarray) else val

for entry in flux_results:
    print(f"\n--- β = {scalar(entry['beta']):.1f}° ---")
    print(f"X1 (−x): {scalar(entry['X1']):.5f}")
    print(f"X2 (+x): {scalar(entry['X2']):.5f}")
    print(f"Y1 (−y): {scalar(entry['Y1']):.5f}")
    print(f"Y2 (+y): {scalar(entry['Y2']):.5f}")
    print(f"Z1 (−z): {scalar(entry['Z1']):.5f}")
    print(f"Z2 (+z): {scalar(entry['Z2']):.5f}")
    print(f"Scattered Total: {scalar(entry['scatt_total']):.5f}")
# Out:
# --- β = 0.0° ---
# X1 (−x): -0.00000
# X2 (+x): 0.00000
# Y1 (−y): 0.00004
# Y2 (+y): 0.00001
# Z1 (−z): 0.00221
# Z2 (+z): 0.00224
# Scattered Total: 0.00000
#
# --- β = 15.0° ---
# X1 (−x): -0.00000
# X2 (+x): -0.00000
# Y1 (−y): 0.00004
# Y2 (+y): 0.00001
# Z1 (−z): 0.00221
# Z2 (+z): 0.00224
# Scattered Total: 0.00000
#
# --- β = 30.0° ---
# X1 (−x): 0.00000
# X2 (+x): -0.00001
# Y1 (−y): 0.00003
# Y2 (+y): 0.00000
# Z1 (−z): 0.00220
# Z2 (+z): 0.00224
# Scattered Total: 0.00000
#
# --- β = 45.0° ---
# X1 (−x): 0.00001
# X2 (+x): -0.00002
# Y1 (−y): 0.00002
# Y2 (+y): -0.00000
# Z1 (−z): 0.00219
# Z2 (+z): 0.00224
# Scattered Total: 0.00000
#
# --- β = 60.0° ---
# X1 (−x): 0.00002
# X2 (+x): -0.00004
# Y1 (−y): 0.00001
# Y2 (+y): -0.00000
# Z1 (−z): 0.00217
# Z2 (+z): 0.00224
# Scattered Total: 0.00000
#
# --- β = 75.0° ---
# X1 (−x): 0.00002
# X2 (+x): -0.00005
# Y1 (−y): -0.00000
# Y2 (+y): -0.00001
# Z1 (−z): 0.00216
# Z2 (+z): 0.00224
# Scattered Total: 0.00000
#
# --- β = 90.0° ---
# X1 (−x): 0.00003
# X2 (+x): -0.00005
# Y1 (−y): -0.00000
# Y2 (+y): -0.00001
# Z1 (−z): 0.00216
# Z2 (+z): 0.00224
# Scattered Total: 0.00000

# %%
import numpy as np
import matplotlib.pyplot as plt

# Convert to scalar values if needed
def scalar(val):
    return val.item() if isinstance(val, np.ndarray) else val

# Extract data
betas = [scalar(entry['beta']) for entry in flux_results]
Z1 = [scalar(entry['Z1']) for entry in flux_results]
Z2 = [scalar(entry['Z2']) for entry in flux_results]
X1 = [scalar(entry['X1']) for entry in flux_results]
X2 = [scalar(entry['X2']) for entry in flux_results]
Y1 = [scalar(entry['Y1']) for entry in flux_results]
Y2 = [scalar(entry['Y2']) for entry in flux_results]


# Set up subplots
fig, axs = plt.subplots(3, 2, figsize=(12, 10))
axs = axs.flatten()

# Plot each component
labels = ['Z1 (−z)', 'Z2 (+z)', 'X1 (−x)', 'X2 (+x)', 'Y1 (−y)', 'Y2 (+y)']
values = [Z1, Z2, X1, X2, Y1, Y2]

for i, (label, val) in enumerate(zip(labels, values)):
    axs[i].plot(betas, val, marker='o')
    axs[i].set_title(label)
    axs[i].set_xlabel("β (degrees)")
    axs[i].set_ylabel("Flux")
    axs[i].grid(True)

# Hide unused subplot if any
if len(axs) > len(labels):
    axs[-1].axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# The incident intensity (`intensity`) is the flux in one of the six monitor planes (the one closest to and facing the planewave source propagating in the $x$ direction) divided by its area. This is why the six sides of the flux box are defined separately. (Otherwise, the entire box could have been defined as a single flux object with different weights ±1 for each side.) The scattered power is multiplied by -1 since it is the *outgoing* power (a positive quantity) rather than the incoming power as defined by the orientation of the flux box. Note that because of the linear $E_z$ polarization of the source, the flux through the $y$ and $z$ planes will *not* be the same. A circularly-polarized source would have produced equal flux in these two monitor planes. The runtime of the scattering run is chosen to be sufficiently long to ensure that the Fourier-transformed fields have [converged](https://meep.readthedocs.io/en/latest/FAQ/checking-convergence).
